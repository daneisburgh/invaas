# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pandas_ta as ta
import re
import requests

from datetime import datetime

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
from invaas.schwab.schwab_task import SchwabTask

task = SchwabTask(env="local")
await task.setup_api_and_get_products()
# Out:
# 2024-01-29 16:40:48 WARNING No DBUtils defined in the runtime
# 2024-01-29 16:40:48 INFO Initializing task for local environment
# 2024-01-29 16:40:48 INFO Historical period used for analysis: 14 days
# 2024-01-29 16:40:48 INFO Min buy amount: $5
# 2024-01-29 16:40:48 INFO Max buy amount: $100
# 2024-01-29 16:40:48 INFO Logging in to Schwab

# %%
def get_options_chains_data(ticker: str):
    options_info = requests.get(f"https://client.schwab.com/symlup/OptionsCwp/Underlying/{ticker}.txt").text
    options_info = re.sub(r"[\n\t\r]*", "", options_info)
    options_info = json.loads(options_info.replace('SuggestionBox.JsonpCallback("option",', "")[:-1])
    expirations = [x["Date"] for x in options_info["Expirations"]]
    options_chain_url = f"https://ausgateway.schwab.com/api/is.CSOptionChainsWeb/v1/OptionChainsPort/OptionChains/chains?Symbol={ticker}&IncludeGreeks=false&{','.join(expirations)}"
    task.schwab_api.update_token("update")
    return json.loads(requests.get(options_chain_url, headers=task.schwab_api.headers).text)


options_chains_data = get_options_chains_data("QQQ")
options_chains_data
# Out:
# {'UnderlyingData': {'Ask': '424.5',
#   'AskSize': '12',
#   'Bid': '424.49',
#   'BidSize': '1',
#   'Close': '423.81',
#   'CumulativeVolume': '11906014',
#   'Description': 'INVSC QQQ TRUST SRS 1',
#   'ErrorCode': 0,
#   'InstrumentType': 'ETF',
#   'Last': '424.5',
#   'NetChange': '0.69',
#   'PercentChange': '0.16',
#   'Open': '424.27',
#   'DailyHigh': '425.12',
#   'DailyLow': '423.61',
#   'High52W': '429.85',
#   'Low52W': '285.19',
#   'Symbol': 'QQQ',
#   'DividendYield': 0.5,
#   'ExchangeName': 'NASDAQ',
#   'IsDelayed': False},
#  'Expirations': [{'ExpirationGroup': {'RootSymbol': 'QQQ',
#     'MonthAndDay': 'Jan 29',
#     'Year': '2024',
#     'Day': 'Mon',
#     'SettlementType': '',
#     'DaysUntil': 0},
#    'AdjustedLabel': {},
#    'AdjustedGroup': '',
#    'Chains': [{'SymbolGroup': 'QQQ20240129353',
#      'Legs': [{'Sym': 'QQQ   240129C00353000',
#        'OptionType': 'C',
#        'Strk': '353',
#        'Chg': '-0.3',
#        'ChgPct': '-0.42',
#        'Bid': '71.42',
#        'Ask': '71.51',
#        'Lst': '71.37',
#        'Vol': '1',
#        'OI': '10',
#        'BidSize': '86',
#        'AskSize': '25'},
#       {'Sym': 'QQQ   240129P00353000',
#        'OptionType': 'P',
#        'Strk': '353',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '5',
#        'OI': '6',
#        'BidSize': '0',
#        'AskSize': '12053'}]},
#     {'SymbolGroup': 'QQQ20240129354',
#      'Legs': [{'Sym': 'QQQ   240129C00354000',
#        'OptionType': 'C',
#        'Strk': '354',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '70.42',
#        'Ask': '70.51',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '87',
#        'AskSize': '25'},
#       {'Sym': 'QQQ   240129P00354000',
#        'OptionType': 'P',
#        'Strk': '354',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '320',
#        'BidSize': '0',
#        'AskSize': '12053'}]},
#     {'SymbolGroup': 'QQQ20240129355',
#      'Legs': [{'Sym': 'QQQ   240129C00355000',
#        'OptionType': 'C',
#        'Strk': '355',
#        'Chg': '-0.3',
#        'ChgPct': '-0.44',
#        'Bid': '69.42',
#        'Ask': '69.51',
#        'Lst': '68.85',
#        'Vol': '13',
#        'OI': '14',
#        'BidSize': '88',
#        'AskSize': '25'},
#       {'Sym': 'QQQ   240129P00355000',
#        'OptionType': 'P',
#        'Strk': '355',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '68',
#        'BidSize': '0',
#        'AskSize': '11929'}]},
#     {'SymbolGroup': 'QQQ20240129356',
#      'Legs': [{'Sym': 'QQQ   240129C00356000',
#        'OptionType': 'C',
#        'Strk': '356',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '68.42',
#        'Ask': '68.51',
#        'Lst': '70.03',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '88',
#        'AskSize': '25'},
#       {'Sym': 'QQQ   240129P00356000',
#        'OptionType': 'P',
#        'Strk': '356',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '39',
#        'BidSize': '0',
#        'AskSize': '12053'}]},
#     {'SymbolGroup': 'QQQ20240129357',
#      'Legs': [{'Sym': 'QQQ   240129C00357000',
#        'OptionType': 'C',
#        'Strk': '357',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '67.42',
#        'Ask': '67.51',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '89',
#        'AskSize': '25'},
#       {'Sym': 'QQQ   240129P00357000',
#        'OptionType': 'P',
#        'Strk': '357',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.03',
#        'Vol': '0',
#        'OI': '10',
#        'BidSize': '0',
#        'AskSize': '12022'}]},
#     {'SymbolGroup': 'QQQ20240129358',
#      'Legs': [{'Sym': 'QQQ   240129C00358000',
#        'OptionType': 'C',
#        'Strk': '358',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '66.42',
#        'Ask': '66.51',
#        'Lst': '69.43',
#        'Vol': '0',
#        'OI': '9',
#        'BidSize': '90',
#        'AskSize': '25'},
#       {'Sym': 'QQQ   240129P00358000',
#        'OptionType': 'P',
#        'Strk': '358',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '20',
#        'BidSize': '0',
#        'AskSize': '12053'}]},
#     {'SymbolGroup': 'QQQ20240129359',
#      'Legs': [{'Sym': 'QQQ   240129C00359000',
#        'OptionType': 'C',
#        'Strk': '359',
#        'Chg': '0.35',
#        'ChgPct': '0.54',
#        'Bid': '65.42',
#        'Ask': '65.51',
#        'Lst': '65.38',
#        'Vol': '1',
#        'OI': '1',
#        'BidSize': '90',
#        'AskSize': '25'},
#       {'Sym': 'QQQ   240129P00359000',
#        'OptionType': 'P',
#        'Strk': '359',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '72',
#        'BidSize': '0',
#        'AskSize': '12095'}]},
#     {'SymbolGroup': 'QQQ20240129360',
#      'Legs': [{'Sym': 'QQQ   240129C00360000',
#        'OptionType': 'C',
#        'Strk': '360',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '64.42',
#        'Ask': '64.51',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '91',
#        'AskSize': '25'},
#       {'Sym': 'QQQ   240129P00360000',
#        'OptionType': 'P',
#        'Strk': '360',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '77',
#        'BidSize': '0',
#        'AskSize': '12066'}]},
#     {'SymbolGroup': 'QQQ20240129361',
#      'Legs': [{'Sym': 'QQQ   240129C00361000',
#        'OptionType': 'C',
#        'Strk': '361',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '63.42',
#        'Ask': '63.51',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '92',
#        'AskSize': '25'},
#       {'Sym': 'QQQ   240129P00361000',
#        'OptionType': 'P',
#        'Strk': '361',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '3',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129362',
#      'Legs': [{'Sym': 'QQQ   240129C00362000',
#        'OptionType': 'C',
#        'Strk': '362',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '62.42',
#        'Ask': '62.53',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '92',
#        'AskSize': '74'},
#       {'Sym': 'QQQ   240129P00362000',
#        'OptionType': 'P',
#        'Strk': '362',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '12053'}]},
#     {'SymbolGroup': 'QQQ20240129363',
#      'Legs': [{'Sym': 'QQQ   240129C00363000',
#        'OptionType': 'C',
#        'Strk': '363',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '61.42',
#        'Ask': '61.53',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '93',
#        'AskSize': '74'},
#       {'Sym': 'QQQ   240129P00363000',
#        'OptionType': 'P',
#        'Strk': '363',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '12053'}]},
#     {'SymbolGroup': 'QQQ20240129364',
#      'Legs': [{'Sym': 'QQQ   240129C00364000',
#        'OptionType': 'C',
#        'Strk': '364',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '60.42',
#        'Ask': '60.54',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '81',
#        'AskSize': '120'},
#       {'Sym': 'QQQ   240129P00364000',
#        'OptionType': 'P',
#        'Strk': '364',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129365',
#      'Legs': [{'Sym': 'QQQ   240129C00365000',
#        'OptionType': 'C',
#        'Strk': '365',
#        'Chg': '-1.48',
#        'ChgPct': '-2.5',
#        'Bid': '59.42',
#        'Ask': '59.54',
#        'Lst': '59.2',
#        'Vol': '2',
#        'OI': '2',
#        'BidSize': '82',
#        'AskSize': '112'},
#       {'Sym': 'QQQ   240129P00365000',
#        'OptionType': 'P',
#        'Strk': '365',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '0',
#        'AskSize': '12053'}]},
#     {'SymbolGroup': 'QQQ20240129366',
#      'Legs': [{'Sym': 'QQQ   240129C00366000',
#        'OptionType': 'C',
#        'Strk': '366',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '58.42',
#        'Ask': '58.53',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '82',
#        'AskSize': '72'},
#       {'Sym': 'QQQ   240129P00366000',
#        'OptionType': 'P',
#        'Strk': '366',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129367',
#      'Legs': [{'Sym': 'QQQ   240129C00367000',
#        'OptionType': 'C',
#        'Strk': '367',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '57.42',
#        'Ask': '57.54',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '83',
#        'AskSize': '118'},
#       {'Sym': 'QQQ   240129P00367000',
#        'OptionType': 'P',
#        'Strk': '367',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '12',
#        'BidSize': '0',
#        'AskSize': '12053'}]},
#     {'SymbolGroup': 'QQQ20240129368',
#      'Legs': [{'Sym': 'QQQ   240129C00368000',
#        'OptionType': 'C',
#        'Strk': '368',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '56.42',
#        'Ask': '56.54',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '84',
#        'AskSize': '111'},
#       {'Sym': 'QQQ   240129P00368000',
#        'OptionType': 'P',
#        'Strk': '368',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '66',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129369',
#      'Legs': [{'Sym': 'QQQ   240129C00369000',
#        'OptionType': 'C',
#        'Strk': '369',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '55.42',
#        'Ask': '55.53',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '97',
#        'AskSize': '66'},
#       {'Sym': 'QQQ   240129P00369000',
#        'OptionType': 'P',
#        'Strk': '369',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129370',
#      'Legs': [{'Sym': 'QQQ   240129C00370000',
#        'OptionType': 'C',
#        'Strk': '370',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '54.42',
#        'Ask': '54.54',
#        'Lst': '57.94',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '98',
#        'AskSize': '117'},
#       {'Sym': 'QQQ   240129P00370000',
#        'OptionType': 'P',
#        'Strk': '370',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '250',
#        'BidSize': '0',
#        'AskSize': '12066'}]},
#     {'SymbolGroup': 'QQQ20240129371',
#      'Legs': [{'Sym': 'QQQ   240129C00371000',
#        'OptionType': 'C',
#        'Strk': '371',
#        'Chg': '-4.08',
#        'ChgPct': '-7.72',
#        'Bid': '53.42',
#        'Ask': '53.54',
#        'Lst': '52.88',
#        'Vol': '14',
#        'OI': '14',
#        'BidSize': '98',
#        'AskSize': '109'},
#       {'Sym': 'QQQ   240129P00371000',
#        'OptionType': 'P',
#        'Strk': '371',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '60',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129372',
#      'Legs': [{'Sym': 'QQQ   240129C00372000',
#        'OptionType': 'C',
#        'Strk': '372',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '52.42',
#        'Ask': '52.53',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '99',
#        'AskSize': '65'},
#       {'Sym': 'QQQ   240129P00372000',
#        'OptionType': 'P',
#        'Strk': '372',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '553',
#        'BidSize': '0',
#        'AskSize': '11972'}]},
#     {'SymbolGroup': 'QQQ20240129373',
#      'Legs': [{'Sym': 'QQQ   240129C00373000',
#        'OptionType': 'C',
#        'Strk': '373',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '51.42',
#        'Ask': '51.54',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '99',
#        'AskSize': '115'},
#       {'Sym': 'QQQ   240129P00373000',
#        'OptionType': 'P',
#        'Strk': '373',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '709',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129374',
#      'Legs': [{'Sym': 'QQQ   240129C00374000',
#        'OptionType': 'C',
#        'Strk': '374',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '50.42',
#        'Ask': '50.54',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '76',
#        'AskSize': '103'},
#       {'Sym': 'QQQ   240129P00374000',
#        'OptionType': 'P',
#        'Strk': '374',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1486',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129375',
#      'Legs': [{'Sym': 'QQQ   240129C00375000',
#        'OptionType': 'C',
#        'Strk': '375',
#        'Chg': '0.29',
#        'ChgPct': '0.59',
#        'Bid': '49.42',
#        'Ask': '49.53',
#        'Lst': '49.28',
#        'Vol': '1',
#        'OI': '2',
#        'BidSize': '101',
#        'AskSize': '63'},
#       {'Sym': 'QQQ   240129P00375000',
#        'OptionType': 'P',
#        'Strk': '375',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '691',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129376',
#      'Legs': [{'Sym': 'QQQ   240129C00376000',
#        'OptionType': 'C',
#        'Strk': '376',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '48.42',
#        'Ask': '48.54',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '101',
#        'AskSize': '106'},
#       {'Sym': 'QQQ   240129P00376000',
#        'OptionType': 'P',
#        'Strk': '376',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '412',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129377',
#      'Legs': [{'Sym': 'QQQ   240129C00377000',
#        'OptionType': 'C',
#        'Strk': '377',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '47.42',
#        'Ask': '47.54',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '101',
#        'AskSize': '102'},
#       {'Sym': 'QQQ   240129P00377000',
#        'OptionType': 'P',
#        'Strk': '377',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1608',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129378',
#      'Legs': [{'Sym': 'QQQ   240129C00378000',
#        'OptionType': 'C',
#        'Strk': '378',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '46.42',
#        'Ask': '46.53',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '103',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   240129P00378000',
#        'OptionType': 'P',
#        'Strk': '378',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '7899',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129379',
#      'Legs': [{'Sym': 'QQQ   240129C00379000',
#        'OptionType': 'C',
#        'Strk': '379',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '45.42',
#        'Ask': '45.54',
#        'Lst': '44.72',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '104',
#        'AskSize': '104'},
#       {'Sym': 'QQQ   240129P00379000',
#        'OptionType': 'P',
#        'Strk': '379',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1530',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129380',
#      'Legs': [{'Sym': 'QQQ   240129C00380000',
#        'OptionType': 'C',
#        'Strk': '380',
#        'Chg': '0.25',
#        'ChgPct': '0.56',
#        'Bid': '44.42',
#        'Ask': '44.54',
#        'Lst': '44.3',
#        'Vol': '1',
#        'OI': '4',
#        'BidSize': '103',
#        'AskSize': '111'},
#       {'Sym': 'QQQ   240129P00380000',
#        'OptionType': 'P',
#        'Strk': '380',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1053',
#        'BidSize': '0',
#        'AskSize': '12066'}]},
#     {'SymbolGroup': 'QQQ20240129381',
#      'Legs': [{'Sym': 'QQQ   240129C00381000',
#        'OptionType': 'C',
#        'Strk': '381',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '43.42',
#        'Ask': '43.53',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '120',
#        'AskSize': '59'},
#       {'Sym': 'QQQ   240129P00381000',
#        'OptionType': 'P',
#        'Strk': '381',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '155',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129382',
#      'Legs': [{'Sym': 'QQQ   240129C00382000',
#        'OptionType': 'C',
#        'Strk': '382',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '42.42',
#        'Ask': '42.54',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '120',
#        'AskSize': '102'},
#       {'Sym': 'QQQ   240129P00382000',
#        'OptionType': 'P',
#        'Strk': '382',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '14',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129383',
#      'Legs': [{'Sym': 'QQQ   240129C00383000',
#        'OptionType': 'C',
#        'Strk': '383',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '41.42',
#        'Ask': '41.51',
#        'Lst': '40.83',
#        'Vol': '0',
#        'OI': '8',
#        'BidSize': '116',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00383000',
#        'OptionType': 'P',
#        'Strk': '383',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129384',
#      'Legs': [{'Sym': 'QQQ   240129C00384000',
#        'OptionType': 'C',
#        'Strk': '384',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '40.42',
#        'Ask': '40.51',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '116',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00384000',
#        'OptionType': 'P',
#        'Strk': '384',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.04',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129385',
#      'Legs': [{'Sym': 'QQQ   240129C00385000',
#        'OptionType': 'C',
#        'Strk': '385',
#        'Chg': '-3.22',
#        'ChgPct': '-8.1',
#        'Bid': '39.42',
#        'Ask': '39.51',
#        'Lst': '39.75',
#        'Vol': '1',
#        'OI': '1',
#        'BidSize': '117',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00385000',
#        'OptionType': 'P',
#        'Strk': '385',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '7',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129386',
#      'Legs': [{'Sym': 'QQQ   240129C00386000',
#        'OptionType': 'C',
#        'Strk': '386',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '38.42',
#        'Ask': '38.51',
#        'Lst': '42',
#        'Vol': '0',
#        'OI': '4',
#        'BidSize': '118',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00386000',
#        'OptionType': 'P',
#        'Strk': '386',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.03',
#        'Vol': '0',
#        'OI': '24',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129387',
#      'Legs': [{'Sym': 'QQQ   240129C00387000',
#        'OptionType': 'C',
#        'Strk': '387',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '37.42',
#        'Ask': '37.51',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '119',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00387000',
#        'OptionType': 'P',
#        'Strk': '387',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '44',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129388',
#      'Legs': [{'Sym': 'QQQ   240129C00388000',
#        'OptionType': 'C',
#        'Strk': '388',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '36.42',
#        'Ask': '36.51',
#        'Lst': '38.02',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '120',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00388000',
#        'OptionType': 'P',
#        'Strk': '388',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '121',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129389',
#      'Legs': [{'Sym': 'QQQ   240129C00389000',
#        'OptionType': 'C',
#        'Strk': '389',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '35.42',
#        'Ask': '35.51',
#        'Lst': '35.82',
#        'Vol': '13',
#        'OI': '0',
#        'BidSize': '140',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00389000',
#        'OptionType': 'P',
#        'Strk': '389',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '492',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129390',
#      'Legs': [{'Sym': 'QQQ   240129C00390000',
#        'OptionType': 'C',
#        'Strk': '390',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '34.42',
#        'Ask': '34.51',
#        'Lst': '34.7',
#        'Vol': '1',
#        'OI': '70',
#        'BidSize': '142',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00390000',
#        'OptionType': 'P',
#        'Strk': '390',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '20',
#        'OI': '2299',
#        'BidSize': '0',
#        'AskSize': '12066'}]},
#     {'SymbolGroup': 'QQQ20240129391',
#      'Legs': [{'Sym': 'QQQ   240129C00391000',
#        'OptionType': 'C',
#        'Strk': '391',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '33.42',
#        'Ask': '33.51',
#        'Lst': '34.83',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '142',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00391000',
#        'OptionType': 'P',
#        'Strk': '391',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129392',
#      'Legs': [{'Sym': 'QQQ   240129C00392000',
#        'OptionType': 'C',
#        'Strk': '392',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '32.42',
#        'Ask': '32.51',
#        'Lst': '31.52',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '143',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00392000',
#        'OptionType': 'P',
#        'Strk': '392',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '333',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129393',
#      'Legs': [{'Sym': 'QQQ   240129C00393000',
#        'OptionType': 'C',
#        'Strk': '393',
#        'Chg': '0.63',
#        'ChgPct': '2.02',
#        'Bid': '31.42',
#        'Ask': '31.51',
#        'Lst': '31.17',
#        'Vol': '1',
#        'OI': '2',
#        'BidSize': '143',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00393000',
#        'OptionType': 'P',
#        'Strk': '393',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1073',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129394',
#      'Legs': [{'Sym': 'QQQ   240129C00394000',
#        'OptionType': 'C',
#        'Strk': '394',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '30.42',
#        'Ask': '30.51',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '150',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00394000',
#        'OptionType': 'P',
#        'Strk': '394',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '995',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129395',
#      'Legs': [{'Sym': 'QQQ   240129C00395000',
#        'OptionType': 'C',
#        'Strk': '395',
#        'Chg': '0.87',
#        'ChgPct': '2.95',
#        'Bid': '29.43',
#        'Ask': '29.51',
#        'Lst': '29.53',
#        'Vol': '1',
#        'OI': '11',
#        'BidSize': '150',
#        'AskSize': '105'},
#       {'Sym': 'QQQ   240129P00395000',
#        'OptionType': 'P',
#        'Strk': '395',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '1199',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129396',
#      'Legs': [{'Sym': 'QQQ   240129C00396000',
#        'OptionType': 'C',
#        'Strk': '396',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '28.43',
#        'Ask': '28.51',
#        'Lst': '28.49',
#        'Vol': '15',
#        'OI': '0',
#        'BidSize': '150',
#        'AskSize': '108'},
#       {'Sym': 'QQQ   240129P00396000',
#        'OptionType': 'P',
#        'Strk': '396',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '15',
#        'BidSize': '0',
#        'AskSize': '12070'}]},
#     {'SymbolGroup': 'QQQ20240129397',
#      'Legs': [{'Sym': 'QQQ   240129C00397000',
#        'OptionType': 'C',
#        'Strk': '397',
#        'Chg': '0.2',
#        'ChgPct': '0.74',
#        'Bid': '27.43',
#        'Ask': '27.51',
#        'Lst': '27.17',
#        'Vol': '7',
#        'OI': '17',
#        'BidSize': '150',
#        'AskSize': '106'},
#       {'Sym': 'QQQ   240129P00397000',
#        'OptionType': 'P',
#        'Strk': '397',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '47',
#        'BidSize': '0',
#        'AskSize': '12026'}]},
#     {'SymbolGroup': 'QQQ20240129398',
#      'Legs': [{'Sym': 'QQQ   240129C00398000',
#        'OptionType': 'C',
#        'Strk': '398',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '26.43',
#        'Ask': '26.51',
#        'Lst': '25.8',
#        'Vol': '0',
#        'OI': '51',
#        'BidSize': '150',
#        'AskSize': '105'},
#       {'Sym': 'QQQ   240129P00398000',
#        'OptionType': 'P',
#        'Strk': '398',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '3736',
#        'BidSize': '0',
#        'AskSize': '12066'}]},
#     {'SymbolGroup': 'QQQ20240129399',
#      'Legs': [{'Sym': 'QQQ   240129C00399000',
#        'OptionType': 'C',
#        'Strk': '399',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '25.43',
#        'Ask': '25.52',
#        'Lst': '26.7',
#        'Vol': '0',
#        'OI': '4',
#        'BidSize': '150',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00399000',
#        'OptionType': 'P',
#        'Strk': '399',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '812',
#        'BidSize': '0',
#        'AskSize': '12066'}]},
#     {'SymbolGroup': 'QQQ20240129400',
#      'Legs': [{'Sym': 'QQQ   240129C00400000',
#        'OptionType': 'C',
#        'Strk': '400',
#        'Chg': '0.69',
#        'ChgPct': '2.82',
#        'Bid': '24.43',
#        'Ask': '24.52',
#        'Lst': '24.45',
#        'Vol': '15',
#        'OI': '25',
#        'BidSize': '150',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00400000',
#        'OptionType': 'P',
#        'Strk': '400',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '10',
#        'OI': '1848',
#        'BidSize': '0',
#        'AskSize': '11993'}]},
#     {'SymbolGroup': 'QQQ20240129401',
#      'Legs': [{'Sym': 'QQQ   240129C00401000',
#        'OptionType': 'C',
#        'Strk': '401',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '23.43',
#        'Ask': '23.52',
#        'Lst': '27.82',
#        'Vol': '0',
#        'OI': '30',
#        'BidSize': '150',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00401000',
#        'OptionType': 'P',
#        'Strk': '401',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '100',
#        'OI': '339',
#        'BidSize': '0',
#        'AskSize': '13279'}]},
#     {'SymbolGroup': 'QQQ20240129402',
#      'Legs': [{'Sym': 'QQQ   240129C00402000',
#        'OptionType': 'C',
#        'Strk': '402',
#        'Chg': '0.79',
#        'ChgPct': '3.53',
#        'Bid': '22.43',
#        'Ask': '22.52',
#        'Lst': '22.35',
#        'Vol': '3',
#        'OI': '18',
#        'BidSize': '150',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00402000',
#        'OptionType': 'P',
#        'Strk': '402',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '26',
#        'OI': '834',
#        'BidSize': '0',
#        'AskSize': '13659'}]},
#     {'SymbolGroup': 'QQQ20240129403',
#      'Legs': [{'Sym': 'QQQ   240129C00403000',
#        'OptionType': 'C',
#        'Strk': '403',
#        'Chg': '0.57',
#        'ChgPct': '2.7',
#        'Bid': '21.43',
#        'Ask': '21.52',
#        'Lst': '21.15',
#        'Vol': '2',
#        'OI': '33',
#        'BidSize': '150',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00403000',
#        'OptionType': 'P',
#        'Strk': '403',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '2',
#        'OI': '304',
#        'BidSize': '0',
#        'AskSize': '11993'}]},
#     {'SymbolGroup': 'QQQ20240129404',
#      'Legs': [{'Sym': 'QQQ   240129C00404000',
#        'OptionType': 'C',
#        'Strk': '404',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '20.43',
#        'Ask': '20.52',
#        'Lst': '22.82',
#        'Vol': '0',
#        'OI': '284',
#        'BidSize': '176',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00404000',
#        'OptionType': 'P',
#        'Strk': '404',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '302',
#        'OI': '1538',
#        'BidSize': '0',
#        'AskSize': '13482'}]},
#     {'SymbolGroup': 'QQQ20240129405',
#      'Legs': [{'Sym': 'QQQ   240129C00405000',
#        'OptionType': 'C',
#        'Strk': '405',
#        'Chg': '0.33',
#        'ChgPct': '1.71',
#        'Bid': '19.43',
#        'Ask': '19.52',
#        'Lst': '19.26',
#        'Vol': '1',
#        'OI': '447',
#        'BidSize': '176',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00405000',
#        'OptionType': 'P',
#        'Strk': '405',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '1',
#        'OI': '1109',
#        'BidSize': '0',
#        'AskSize': '11993'}]},
#     {'SymbolGroup': 'QQQ20240129406',
#      'Legs': [{'Sym': 'QQQ   240129C00406000',
#        'OptionType': 'C',
#        'Strk': '406',
#        'Chg': '0.92',
#        'ChgPct': '4.94',
#        'Bid': '18.43',
#        'Ask': '18.52',
#        'Lst': '18.62',
#        'Vol': '11',
#        'OI': '44',
#        'BidSize': '175',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00406000',
#        'OptionType': 'P',
#        'Strk': '406',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '113',
#        'OI': '550',
#        'BidSize': '0',
#        'AskSize': '11952'}]},
#     {'SymbolGroup': 'QQQ20240129407',
#      'Legs': [{'Sym': 'QQQ   240129C00407000',
#        'OptionType': 'C',
#        'Strk': '407',
#        'Chg': '0.7',
#        'ChgPct': '4.02',
#        'Bid': '17.43',
#        'Ask': '17.52',
#        'Lst': '17.42',
#        'Vol': '5',
#        'OI': '47',
#        'BidSize': '176',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00407000',
#        'OptionType': 'P',
#        'Strk': '407',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '12',
#        'OI': '753',
#        'BidSize': '0',
#        'AskSize': '12772'}]},
#     {'SymbolGroup': 'QQQ20240129408',
#      'Legs': [{'Sym': 'QQQ   240129C00408000',
#        'OptionType': 'C',
#        'Strk': '408',
#        'Chg': '0.96',
#        'ChgPct': '5.85',
#        'Bid': '16.43',
#        'Ask': '16.52',
#        'Lst': '16.42',
#        'Vol': '4',
#        'OI': '58',
#        'BidSize': '175',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00408000',
#        'OptionType': 'P',
#        'Strk': '408',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '8',
#        'OI': '3871',
#        'BidSize': '0',
#        'AskSize': '13334'}]},
#     {'SymbolGroup': 'QQQ20240129409',
#      'Legs': [{'Sym': 'QQQ   240129C00409000',
#        'OptionType': 'C',
#        'Strk': '409',
#        'Chg': '0.57',
#        'ChgPct': '3.68',
#        'Bid': '15.43',
#        'Ask': '15.52',
#        'Lst': '15.49',
#        'Vol': '81',
#        'OI': '294',
#        'BidSize': '176',
#        'AskSize': '100'},
#       {'Sym': 'QQQ   240129P00409000',
#        'OptionType': 'P',
#        'Strk': '409',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '2',
#        'OI': '2478',
#        'BidSize': '0',
#        'AskSize': '12162'}]},
#     {'SymbolGroup': 'QQQ20240129410',
#      'Legs': [{'Sym': 'QQQ   240129C00410000',
#        'OptionType': 'C',
#        'Strk': '410',
#        'Chg': '0.66',
#        'ChgPct': '4.68',
#        'Bid': '14.43',
#        'Ask': '14.52',
#        'Lst': '14.11',
#        'Vol': '140',
#        'OI': '2512',
#        'BidSize': '133',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00410000',
#        'OptionType': 'P',
#        'Strk': '410',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '227',
#        'OI': '3674',
#        'BidSize': '0',
#        'AskSize': '12108'}]},
#     {'SymbolGroup': 'QQQ20240129411',
#      'Legs': [{'Sym': 'QQQ   240129C00411000',
#        'OptionType': 'C',
#        'Strk': '411',
#        'Chg': '0.88',
#        'ChgPct': '6.48',
#        'Bid': '13.43',
#        'Ask': '13.52',
#        'Lst': '13.58',
#        'Vol': '3',
#        'OI': '136',
#        'BidSize': '135',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00411000',
#        'OptionType': 'P',
#        'Strk': '411',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '85',
#        'OI': '909',
#        'BidSize': '0',
#        'AskSize': '12071'}]},
#     {'SymbolGroup': 'QQQ20240129412',
#      'Legs': [{'Sym': 'QQQ   240129C00412000',
#        'OptionType': 'C',
#        'Strk': '412',
#        'Chg': '0.34',
#        'ChgPct': '2.74',
#        'Bid': '12.43',
#        'Ask': '12.52',
#        'Lst': '12.4',
#        'Vol': '198',
#        'OI': '348',
#        'BidSize': '193',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00412000',
#        'OptionType': 'P',
#        'Strk': '412',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '370',
#        'OI': '4411',
#        'BidSize': '0',
#        'AskSize': '14276'}]},
#     {'SymbolGroup': 'QQQ20240129413',
#      'Legs': [{'Sym': 'QQQ   240129C00413000',
#        'OptionType': 'C',
#        'Strk': '413',
#        'Chg': '0.98',
#        'ChgPct': '8.41',
#        'Bid': '11.43',
#        'Ask': '11.52',
#        'Lst': '11.65',
#        'Vol': '11',
#        'OI': '137',
#        'BidSize': '198',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00413000',
#        'OptionType': 'P',
#        'Strk': '413',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '941',
#        'OI': '2888',
#        'BidSize': '0',
#        'AskSize': '14241'}]},
#     {'SymbolGroup': 'QQQ20240129414',
#      'Legs': [{'Sym': 'QQQ   240129C00414000',
#        'OptionType': 'C',
#        'Strk': '414',
#        'Chg': '0.63',
#        'ChgPct': '6.08',
#        'Bid': '10.43',
#        'Ask': '10.55',
#        'Lst': '10.36',
#        'Vol': '18',
#        'OI': '84',
#        'BidSize': '207',
#        'AskSize': '220'},
#       {'Sym': 'QQQ   240129P00414000',
#        'OptionType': 'P',
#        'Strk': '414',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '3225',
#        'OI': '3331',
#        'BidSize': '0',
#        'AskSize': '13074'}]},
#     {'SymbolGroup': 'QQQ20240129415',
#      'Legs': [{'Sym': 'QQQ   240129C00415000',
#        'OptionType': 'C',
#        'Strk': '415',
#        'Chg': '0.67',
#        'ChgPct': '7.35',
#        'Bid': '9.43',
#        'Ask': '9.54',
#        'Lst': '9.11',
#        'Vol': '24',
#        'OI': '827',
#        'BidSize': '216',
#        'AskSize': '157'},
#       {'Sym': 'QQQ   240129P00415000',
#        'OptionType': 'P',
#        'Strk': '415',
#        'Chg': '-0.04',
#        'ChgPct': '-400',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '5219',
#        'OI': '5677',
#        'BidSize': '97',
#        'AskSize': '9271'}]},
#     {'SymbolGroup': 'QQQ20240129416',
#      'Legs': [{'Sym': 'QQQ   240129C00416000',
#        'OptionType': 'C',
#        'Strk': '416',
#        'Chg': '0.98',
#        'ChgPct': '11.53',
#        'Bid': '8.44',
#        'Ask': '8.54',
#        'Lst': '8.5',
#        'Vol': '877',
#        'OI': '883',
#        'BidSize': '220',
#        'AskSize': '155'},
#       {'Sym': 'QQQ   240129P00416000',
#        'OptionType': 'P',
#        'Strk': '416',
#        'Chg': '-0.05',
#        'ChgPct': '-500',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '1827',
#        'OI': '3954',
#        'BidSize': '6423',
#        'AskSize': '10336'}]},
#     {'SymbolGroup': 'QQQ20240129417',
#      'Legs': [{'Sym': 'QQQ   240129C00417000',
#        'OptionType': 'C',
#        'Strk': '417',
#        'Chg': '0.9',
#        'ChgPct': '12.18',
#        'Bid': '7.44',
#        'Ask': '7.53',
#        'Lst': '7.39',
#        'Vol': '10',
#        'OI': '1589',
#        'BidSize': '220',
#        'AskSize': '102'},
#       {'Sym': 'QQQ   240129P00417000',
#        'OptionType': 'P',
#        'Strk': '417',
#        'Chg': '-0.07',
#        'ChgPct': '-700',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '3440',
#        'OI': '5824',
#        'BidSize': '8896',
#        'AskSize': '8871'}]},
#     {'SymbolGroup': 'QQQ20240129418',
#      'Legs': [{'Sym': 'QQQ   240129C00418000',
#        'OptionType': 'C',
#        'Strk': '418',
#        'Chg': '0.81',
#        'ChgPct': '12.27',
#        'Bid': '6.44',
#        'Ask': '6.53',
#        'Lst': '6.6',
#        'Vol': '81',
#        'OI': '352',
#        'BidSize': '176',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00418000',
#        'OptionType': 'P',
#        'Strk': '418',
#        'Chg': '-0.11',
#        'ChgPct': '-550',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.02',
#        'Vol': '5127',
#        'OI': '6002',
#        'BidSize': '7034',
#        'AskSize': '6823'}]},
#     {'SymbolGroup': 'QQQ20240129419',
#      'Legs': [{'Sym': 'QQQ   240129C00419000',
#        'OptionType': 'C',
#        'Strk': '419',
#        'Chg': '0.9',
#        'ChgPct': '16.36',
#        'Bid': '5.45',
#        'Ask': '5.54',
#        'Lst': '5.5',
#        'Vol': '85',
#        'OI': '483',
#        'BidSize': '269',
#        'AskSize': '100'},
#       {'Sym': 'QQQ   240129P00419000',
#        'OptionType': 'P',
#        'Strk': '419',
#        'Chg': '-0.2',
#        'ChgPct': '-1000',
#        'Bid': '0.02',
#        'Ask': '0.03',
#        'Lst': '0.02',
#        'Vol': '12158',
#        'OI': '3589',
#        'BidSize': '3729',
#        'AskSize': '4806'}]},
#     {'SymbolGroup': 'QQQ20240129420',
#      'Legs': [{'Sym': 'QQQ   240129C00420000',
#        'OptionType': 'C',
#        'Strk': '420',
#        'Chg': '0.93',
#        'ChgPct': '19.79',
#        'Bid': '4.47',
#        'Ask': '4.55',
#        'Lst': '4.7',
#        'Vol': '1577',
#        'OI': '2285',
#        'BidSize': '218',
#        'AskSize': '100'},
#       {'Sym': 'QQQ   240129P00420000',
#        'OptionType': 'P',
#        'Strk': '420',
#        'Chg': '-0.34',
#        'ChgPct': '-1133.33',
#        'Bid': '0.03',
#        'Ask': '0.04',
#        'Lst': '0.03',
#        'Vol': '17364',
#        'OI': '8551',
#        'BidSize': '6207',
#        'AskSize': '4388'}]},
#     {'SymbolGroup': 'QQQ20240129421',
#      'Legs': [{'Sym': 'QQQ   240129C00421000',
#        'OptionType': 'C',
#        'Strk': '421',
#        'Chg': '0.53',
#        'ChgPct': '15.23',
#        'Bid': '3.5',
#        'Ask': '3.58',
#        'Lst': '3.48',
#        'Vol': '715',
#        'OI': '843',
#        'BidSize': '264',
#        'AskSize': '150'},
#       {'Sym': 'QQQ   240129P00421000',
#        'OptionType': 'P',
#        'Strk': '421',
#        'Chg': '-0.51',
#        'ChgPct': '-728.57',
#        'Bid': '0.06',
#        'Ask': '0.07',
#        'Lst': '0.07',
#        'Vol': '19020',
#        'OI': '5309',
#        'BidSize': '4376',
#        'AskSize': '2198'}]},
#     {'SymbolGroup': 'QQQ20240129422',
#      'Legs': [{'Sym': 'QQQ   240129C00422000',
#        'OptionType': 'C',
#        'Strk': '422',
#        'Chg': '0.52',
#        'ChgPct': '18.84',
#        'Bid': '2.59',
#        'Ask': '2.66',
#        'Lst': '2.76',
#        'Vol': '3863',
#        'OI': '6166',
#        'BidSize': '242',
#        'AskSize': '151'},
#       {'Sym': 'QQQ   240129P00422000',
#        'OptionType': 'P',
#        'Strk': '422',
#        'Chg': '-0.74',
#        'ChgPct': '-493.33',
#        'Bid': '0.15',
#        'Ask': '0.16',
#        'Lst': '0.15',
#        'Vol': '42538',
#        'OI': '12979',
#        'BidSize': '723',
#        'AskSize': '3079'}]},
#     {'SymbolGroup': 'QQQ20240129423',
#      'Legs': [{'Sym': 'QQQ   240129C00423000',
#        'OptionType': 'C',
#        'Strk': '423',
#        'Chg': '0.12',
#        'ChgPct': '6.78',
#        'Bid': '1.78',
#        'Ask': '1.83',
#        'Lst': '1.77',
#        'Vol': '10639',
#        'OI': '3000',
#        'BidSize': '193',
#        'AskSize': '153'},
#       {'Sym': 'QQQ   240129P00423000',
#        'OptionType': 'P',
#        'Strk': '423',
#        'Chg': '-0.93',
#        'ChgPct': '-273.53',
#        'Bid': '0.32',
#        'Ask': '0.33',
#        'Lst': '0.34',
#        'Vol': '69630',
#        'OI': '7833',
#        'BidSize': '594',
#        'AskSize': '224'}]},
#     {'SymbolGroup': 'QQQ20240129424',
#      'Legs': [{'Sym': 'QQQ   240129C00424000',
#        'OptionType': 'C',
#        'Strk': '424',
#        'Chg': '-0.07',
#        'ChgPct': '-6.42',
#        'Bid': '1.1',
#        'Ask': '1.11',
#        'Lst': '1.09',
#        'Vol': '66794',
#        'OI': '5206',
#        'BidSize': '217',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240129P00424000',
#        'OptionType': 'P',
#        'Strk': '424',
#        'Chg': '-1.15',
#        'ChgPct': '-182.54',
#        'Bid': '0.63',
#        'Ask': '0.64',
#        'Lst': '0.63',
#        'Vol': '84809',
#        'OI': '7360',
#        'BidSize': '2',
#        'AskSize': '625'}]},
#     {'SymbolGroup': 'QQQ20240129425',
#      'Legs': [{'Sym': 'QQQ   240129C00425000',
#        'OptionType': 'C',
#        'Strk': '425',
#        'Chg': '-0.2',
#        'ChgPct': '-35.09',
#        'Bid': '0.57',
#        'Ask': '0.59',
#        'Lst': '0.57',
#        'Vol': '104496',
#        'OI': '8347',
#        'BidSize': '733',
#        'AskSize': '612'},
#       {'Sym': 'QQQ   240129P00425000',
#        'OptionType': 'P',
#        'Strk': '425',
#        'Chg': '-1.32',
#        'ChgPct': '-118.92',
#        'Bid': '1.09',
#        'Ask': '1.1',
#        'Lst': '1.11',
#        'Vol': '32811',
#        'OI': '4472',
#        'BidSize': '21',
#        'AskSize': '88'}]},
#     {'SymbolGroup': 'QQQ20240129426',
#      'Legs': [{'Sym': 'QQQ   240129C00426000',
#        'OptionType': 'C',
#        'Strk': '426',
#        'Chg': '-0.22',
#        'ChgPct': '-84.62',
#        'Bid': '0.25',
#        'Ask': '0.26',
#        'Lst': '0.26',
#        'Vol': '70593',
#        'OI': '6977',
#        'BidSize': '535',
#        'AskSize': '660'},
#       {'Sym': 'QQQ   240129P00426000',
#        'OptionType': 'P',
#        'Strk': '426',
#        'Chg': '-1.33',
#        'ChgPct': '-75.57',
#        'Bid': '1.74',
#        'Ask': '1.79',
#        'Lst': '1.76',
#        'Vol': '4992',
#        'OI': '5056',
#        'BidSize': '209',
#        'AskSize': '103'}]},
#     {'SymbolGroup': 'QQQ20240129427',
#      'Legs': [{'Sym': 'QQQ   240129C00427000',
#        'OptionType': 'C',
#        'Strk': '427',
#        'Chg': '-0.19',
#        'ChgPct': '-190',
#        'Bid': '0.09',
#        'Ask': '0.1',
#        'Lst': '0.1',
#        'Vol': '24857',
#        'OI': '4626',
#        'BidSize': '1780',
#        'AskSize': '3295'},
#       {'Sym': 'QQQ   240129P00427000',
#        'OptionType': 'P',
#        'Strk': '427',
#        'Chg': '-1.43',
#        'ChgPct': '-56.75',
#        'Bid': '2.58',
#        'Ask': '2.65',
#        'Lst': '2.52',
#        'Vol': '2330',
#        'OI': '1818',
#        'BidSize': '88',
#        'AskSize': '195'}]},
#     {'SymbolGroup': 'QQQ20240129428',
#      'Legs': [{'Sym': 'QQQ   240129C00428000',
#        'OptionType': 'C',
#        'Strk': '428',
#        'Chg': '-0.15',
#        'ChgPct': '-500',
#        'Bid': '0.03',
#        'Ask': '0.04',
#        'Lst': '0.03',
#        'Vol': '31793',
#        'OI': '7178',
#        'BidSize': '5992',
#        'AskSize': '4300'},
#       {'Sym': 'QQQ   240129P00428000',
#        'OptionType': 'P',
#        'Strk': '428',
#        'Chg': '-1.38',
#        'ChgPct': '-40.59',
#        'Bid': '3.5',
#        'Ask': '3.6',
#        'Lst': '3.4',
#        'Vol': '711',
#        'OI': '2208',
#        'BidSize': '150',
#        'AskSize': '189'}]},
#     {'SymbolGroup': 'QQQ20240129429',
#      'Legs': [{'Sym': 'QQQ   240129C00429000',
#        'OptionType': 'C',
# ...
#        'OI': '0',
#        'BidSize': '108',
#        'AskSize': '24'},
#       {'Sym': 'QQQ   261218P00514780',
#        'OptionType': 'P',
#        'Strk': '514.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '90.36',
#        'Ask': '95',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '25',
#        'AskSize': '61'}]},
#     {'SymbolGroup': 'QQQ20261218519.78',
#      'Legs': [{'Sym': 'QQQ   261218C00519780',
#        'OptionType': 'C',
#        'Strk': '519.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '35',
#        'Ask': '39.5',
#        'Lst': '27.5',
#        'Vol': '0',
#        'OI': '3',
#        'BidSize': '26',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00519780',
#        'OptionType': 'P',
#        'Strk': '519.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '94.36',
#        'Ask': '99',
#        'Lst': '93.69',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '25',
#        'AskSize': '61'}]},
#     {'SymbolGroup': 'QQQ20261218524.78',
#      'Legs': [{'Sym': 'QQQ   261218C00524780',
#        'OptionType': 'C',
#        'Strk': '524.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '33',
#        'Ask': '37.92',
#        'Lst': '36.81',
#        'Vol': '0',
#        'OI': '8',
#        'BidSize': '80',
#        'AskSize': '24'},
#       {'Sym': 'QQQ   261218P00524780',
#        'OptionType': 'P',
#        'Strk': '524.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '98.6',
#        'Ask': '103.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '25',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218529.78',
#      'Legs': [{'Sym': 'QQQ   261218C00529780',
#        'OptionType': 'C',
#        'Strk': '529.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '31.5',
#        'Ask': '36.25',
#        'Lst': '35',
#        'Vol': '0',
#        'OI': '10',
#        'BidSize': '102',
#        'AskSize': '24'},
#       {'Sym': 'QQQ   261218P00529780',
#        'OptionType': 'P',
#        'Strk': '529.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '103.04',
#        'Ask': '108',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '25',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218534.78',
#      'Legs': [{'Sym': 'QQQ   261218C00534780',
#        'OptionType': 'C',
#        'Strk': '534.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '30',
#        'Ask': '34.5',
#        'Lst': '32.25',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '60',
#        'AskSize': '54'},
#       {'Sym': 'QQQ   261218P00534780',
#        'OptionType': 'P',
#        'Strk': '534.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '108',
#        'Ask': '112.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218539.78',
#      'Legs': [{'Sym': 'QQQ   261218C00539780',
#        'OptionType': 'C',
#        'Strk': '539.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '28.5',
#        'Ask': '33',
#        'Lst': '31.58',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '60',
#        'AskSize': '54'},
#       {'Sym': 'QQQ   261218P00539780',
#        'OptionType': 'P',
#        'Strk': '539.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '113',
#        'Ask': '117.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218544.78',
#      'Legs': [{'Sym': 'QQQ   261218C00544780',
#        'OptionType': 'C',
#        'Strk': '544.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '27',
#        'Ask': '31.5',
#        'Lst': '30.8',
#        'Vol': '0',
#        'OI': '21',
#        'BidSize': '60',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00544780',
#        'OptionType': 'P',
#        'Strk': '544.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '118',
#        'Ask': '122.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218549.78',
#      'Legs': [{'Sym': 'QQQ   261218C00549780',
#        'OptionType': 'C',
#        'Strk': '549.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '25.5',
#        'Ask': '30.14',
#        'Lst': '26.82',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '108',
#        'AskSize': '24'},
#       {'Sym': 'QQQ   261218P00549780',
#        'OptionType': 'P',
#        'Strk': '549.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '123',
#        'Ask': '127.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218554.78',
#      'Legs': [{'Sym': 'QQQ   261218C00554780',
#        'OptionType': 'C',
#        'Strk': '554.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '24.5',
#        'Ask': '28.77',
#        'Lst': '20.08',
#        'Vol': '0',
#        'OI': '51',
#        'BidSize': '1',
#        'AskSize': '24'},
#       {'Sym': 'QQQ   261218P00554780',
#        'OptionType': 'P',
#        'Strk': '554.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '128',
#        'Ask': '132.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218559.78',
#      'Legs': [{'Sym': 'QQQ   261218C00559780',
#        'OptionType': 'C',
#        'Strk': '559.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '23',
#        'Ask': '27.44',
#        'Lst': '23.17',
#        'Vol': '0',
#        'OI': '11',
#        'BidSize': '60',
#        'AskSize': '24'},
#       {'Sym': 'QQQ   261218P00559780',
#        'OptionType': 'P',
#        'Strk': '559.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '133',
#        'Ask': '137.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218564.78',
#      'Legs': [{'Sym': 'QQQ   261218C00564780',
#        'OptionType': 'C',
#        'Strk': '564.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '21.5',
#        'Ask': '26.16',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '98',
#        'AskSize': '24'},
#       {'Sym': 'QQQ   261218P00564780',
#        'OptionType': 'P',
#        'Strk': '564.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '138',
#        'Ask': '142.69',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218569.78',
#      'Legs': [{'Sym': 'QQQ   261218C00569780',
#        'OptionType': 'C',
#        'Strk': '569.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '20.5',
#        'Ask': '24.94',
#        'Lst': '18.29',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '60',
#        'AskSize': '24'},
#       {'Sym': 'QQQ   261218P00569780',
#        'OptionType': 'P',
#        'Strk': '569.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '143',
#        'Ask': '147.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218574.78',
#      'Legs': [{'Sym': 'QQQ   261218C00574780',
#        'OptionType': 'C',
#        'Strk': '574.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '19',
#        'Ask': '23.77',
#        'Lst': '20.2',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '98',
#        'AskSize': '24'},
#       {'Sym': 'QQQ   261218P00574780',
#        'OptionType': 'P',
#        'Strk': '574.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '148',
#        'Ask': '152.68',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218579.78',
#      'Legs': [{'Sym': 'QQQ   261218C00579780',
#        'OptionType': 'C',
#        'Strk': '579.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '18',
#        'Ask': '22.5',
#        'Lst': '20.75',
#        'Vol': '0',
#        'OI': '9',
#        'BidSize': '60',
#        'AskSize': '54'},
#       {'Sym': 'QQQ   261218P00579780',
#        'OptionType': 'P',
#        'Strk': '579.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '153',
#        'Ask': '157.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218584.78',
#      'Legs': [{'Sym': 'QQQ   261218C00584780',
#        'OptionType': 'C',
#        'Strk': '584.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '17',
#        'Ask': '21.5',
#        'Lst': '19.5',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '60',
#        'AskSize': '162'},
#       {'Sym': 'QQQ   261218P00584780',
#        'OptionType': 'P',
#        'Strk': '584.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '158',
#        'Ask': '162.68',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218589.78',
#      'Legs': [{'Sym': 'QQQ   261218C00589780',
#        'OptionType': 'C',
#        'Strk': '589.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '16',
#        'Ask': '20.5',
#        'Lst': '16.28',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '1',
#        'AskSize': '126'},
#       {'Sym': 'QQQ   261218P00589780',
#        'OptionType': 'P',
#        'Strk': '589.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '163',
#        'Ask': '167.5',
#        'Lst': '171.94',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218594.78',
#      'Legs': [{'Sym': 'QQQ   261218C00594780',
#        'OptionType': 'C',
#        'Strk': '594.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '15',
#        'Ask': '19.5',
#        'Lst': '14.72',
#        'Vol': '0',
#        'OI': '55',
#        'BidSize': '60',
#        'AskSize': '172'},
#       {'Sym': 'QQQ   261218P00594780',
#        'OptionType': 'P',
#        'Strk': '594.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '168',
#        'Ask': '172.68',
#        'Lst': '176.82',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218599.78',
#      'Legs': [{'Sym': 'QQQ   261218C00599780',
#        'OptionType': 'C',
#        'Strk': '599.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '14',
#        'Ask': '18.5',
#        'Lst': '17.2',
#        'Vol': '0',
#        'OI': '60',
#        'BidSize': '60',
#        'AskSize': '170'},
#       {'Sym': 'QQQ   261218P00599780',
#        'OptionType': 'P',
#        'Strk': '599.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '173',
#        'Ask': '177.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218604.78',
#      'Legs': [{'Sym': 'QQQ   261218C00604780',
#        'OptionType': 'C',
#        'Strk': '604.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '13',
#        'Ask': '17.79',
#        'Lst': '13.53',
#        'Vol': '0',
#        'OI': '3',
#        'BidSize': '61',
#        'AskSize': '84'},
#       {'Sym': 'QQQ   261218P00604780',
#        'OptionType': 'P',
#        'Strk': '604.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '178',
#        'Ask': '182.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '3'}]},
#     {'SymbolGroup': 'QQQ20261218609.78',
#      'Legs': [{'Sym': 'QQQ   261218C00609780',
#        'OptionType': 'C',
#        'Strk': '609.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '12',
#        'Ask': '16.91',
#        'Lst': '13.58',
#        'Vol': '0',
#        'OI': '31',
#        'BidSize': '116',
#        'AskSize': '60'},
#       {'Sym': 'QQQ   261218P00609780',
#        'OptionType': 'P',
#        'Strk': '609.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '183',
#        'Ask': '187.68',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218615',
#      'Legs': [{'Sym': 'QQQ   261218C00615000',
#        'OptionType': 'C',
#        'Strk': '615',
#        'Chg': '0.11',
#        'ChgPct': '0.83',
#        'Bid': '11.14',
#        'Ask': '16',
#        'Lst': '13.25',
#        'Vol': '2',
#        'OI': '869',
#        'BidSize': '85',
#        'AskSize': '122'},
#       {'Sym': 'QQQ   261218P00615000',
#        'OptionType': 'P',
#        'Strk': '615',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '188',
#        'Ask': '192.9',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218620',
#      'Legs': [{'Sym': 'QQQ   261218C00620000',
#        'OptionType': 'C',
#        'Strk': '620',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '10.36',
#        'Ask': '15',
#        'Lst': '13.38',
#        'Vol': '0',
#        'OI': '18',
#        'BidSize': '85',
#        'AskSize': '185'},
#       {'Sym': 'QQQ   261218P00620000',
#        'OptionType': 'P',
#        'Strk': '620',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '193',
#        'Ask': '197.9',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218625',
#      'Legs': [{'Sym': 'QQQ   261218C00625000',
#        'OptionType': 'C',
#        'Strk': '625',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '9.62',
#        'Ask': '14.5',
#        'Lst': '11.89',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '60',
#        'AskSize': '122'},
#       {'Sym': 'QQQ   261218P00625000',
#        'OptionType': 'P',
#        'Strk': '625',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '198',
#        'Ask': '202.9',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218630',
#      'Legs': [{'Sym': 'QQQ   261218C00630000',
#        'OptionType': 'C',
#        'Strk': '630',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '9',
#        'Ask': '13.5',
#        'Lst': '10.94',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '275',
#        'AskSize': '297'},
#       {'Sym': 'QQQ   261218P00630000',
#        'OptionType': 'P',
#        'Strk': '630',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '203',
#        'Ask': '207.9',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218635',
#      'Legs': [{'Sym': 'QQQ   261218C00635000',
#        'OptionType': 'C',
#        'Strk': '635',
#        'Chg': '0.48',
#        'ChgPct': '4.48',
#        'Bid': '10.65',
#        'Ask': '11',
#        'Lst': '10.71',
#        'Vol': '30',
#        'OI': '36',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   261218P00635000',
#        'OptionType': 'P',
#        'Strk': '635',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '208',
#        'Ask': '212.89',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218640',
#      'Legs': [{'Sym': 'QQQ   261218C00640000',
#        'OptionType': 'C',
#        'Strk': '640',
#        'Chg': '0.02',
#        'ChgPct': '0.21',
#        'Bid': '7.71',
#        'Ask': '11.5',
#        'Lst': '9.75',
#        'Vol': '2',
#        'OI': '34',
#        'BidSize': '247',
#        'AskSize': '225'},
#       {'Sym': 'QQQ   261218P00640000',
#        'OptionType': 'P',
#        'Strk': '640',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '213',
#        'Ask': '217.89',
#        'Lst': '216.6',
#        'Vol': '1',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]}]}],
#  'CurrentDateTime': '11:40:54 AM ET, 01/29/2024',
#  'InterestRate': '0.05203',
#  'IsDelayed': False,
#  'IsPartialData': False,
#  'ContractSpecs': {'UnderlyingType': 'ETF',
#   'ExerStyle': 'American',
#   'SetType': 'PM',
#   'Multi': '100',
#   'Deliverable': '100 QQQ',
#   'Cash': ''},
#  'Provider': 'SchwabMDS'}

# %%
data = []
underlying_last = float(options_chains_data["UnderlyingData"]["Last"])

for expiration in options_chains_data["Expirations"]:
    days_until_expiration = expiration["ExpirationGroup"]["DaysUntil"]
    expiration_month_day = expiration["ExpirationGroup"]["MonthAndDay"].split(" ")
    expiration_month = expiration_month_day[0]
    expiration_day = expiration_month_day[1]
    expiration_year = expiration["ExpirationGroup"]["Year"]
    expiration_date = datetime.strptime(f"{expiration_month} {expiration_day} {expiration_year}", "%b %d %Y")

    for chain in expiration["Chains"]:
        data_obj = {}
        data_obj["OPTION_ID"] = chain["SymbolGroup"]
        data_obj["UNDERLYING_LAST"] = underlying_last
        data_obj["EXPIRE_DATE"] = expiration_date
        data_obj["DTE"] = days_until_expiration

        for leg in chain["Legs"]:
            data_obj["STRIKE"] = float(leg["Strk"])
            data_obj["STRIKE_DISTANCE"] = abs(data_obj["STRIKE"] - underlying_last)
            data_obj["STRIKE_DISTANCE_PCT"] = data_obj["STRIKE_DISTANCE"] / underlying_last
            leg_prefix = leg["OptionType"] + "_"
            data_obj[leg_prefix + "ID"] = leg["Sym"]
            data_obj[leg_prefix + "BID"] = float(leg["Bid"])
            data_obj[leg_prefix + "ASK"] = float(leg["Ask"])
            data_obj[leg_prefix + "VOLUME"] = int(leg["Vol"])

        data.append(data_obj)

df_options_chains = pd.DataFrame(data=data)
df_options_chains
# Out:
#            OPTION_ID  UNDERLYING_LAST EXPIRE_DATE   DTE  STRIKE  \
# 0     QQQ20240129353            424.5  2024-01-29     0   353.0
# 1     QQQ20240129354            424.5  2024-01-29     0   354.0
# 2     QQQ20240129355            424.5  2024-01-29     0   355.0
# 3     QQQ20240129356            424.5  2024-01-29     0   356.0
# 4     QQQ20240129357            424.5  2024-01-29     0   357.0
# ...              ...              ...         ...   ...     ...
# 4183  QQQ20261218620            424.5  2026-12-18  1054   620.0
# 4184  QQQ20261218625            424.5  2026-12-18  1054   625.0
# 4185  QQQ20261218630            424.5  2026-12-18  1054   630.0
# 4186  QQQ20261218635            424.5  2026-12-18  1054   635.0
# 4187  QQQ20261218640            424.5  2026-12-18  1054   640.0
#
#       STRIKE_DISTANCE  STRIKE_DISTANCE_PCT                   C_ID  C_BID  \
# 0                71.5             0.168433  QQQ   240129C00353000  71.42
# 1                70.5             0.166078  QQQ   240129C00354000  70.42
# 2                69.5             0.163722  QQQ   240129C00355000  69.42
# 3                68.5             0.161366  QQQ   240129C00356000  68.42
# 4                67.5             0.159011  QQQ   240129C00357000  67.42
# ...               ...                  ...                    ...    ...
# 4183            195.5             0.460542  QQQ   261218C00620000  10.36
# 4184            200.5             0.472320  QQQ   261218C00625000   9.62
# 4185            205.5             0.484099  QQQ   261218C00630000   9.00
# 4186            210.5             0.495878  QQQ   261218C00635000  10.65
# 4187            215.5             0.507656  QQQ   261218C00640000   7.71
#
#       C_ASK  C_VOLUME                   P_ID  P_BID   P_ASK  P_VOLUME
# 0     71.51         1  QQQ   240129P00353000    0.0    0.01         5
# 1     70.51         0  QQQ   240129P00354000    0.0    0.01         0
# 2     69.51        13  QQQ   240129P00355000    0.0    0.01         0
# 3     68.51         0  QQQ   240129P00356000    0.0    0.01         0
# 4     67.51         0  QQQ   240129P00357000    0.0    0.01         0
# ...     ...       ...                    ...    ...     ...       ...
# 4183  15.00         0  QQQ   261218P00620000  193.0  197.90         0
# 4184  14.50         0  QQQ   261218P00625000  198.0  202.90         0
# 4185  13.50         0  QQQ   261218P00630000  203.0  207.90         0
# 4186  11.00        30  QQQ   261218P00635000  208.0  212.89         0
# 4187  11.50         2  QQQ   261218P00640000  213.0  217.89         1
#
# [4188 rows x 15 columns]

# %%
from invaas.schwab.cnn_fear_greed_index import get_historical_cnn_fear_greed_index


def get_fear_greed_index_data():
    historical_period = 14
    df = pd.DataFrame(data=get_historical_cnn_fear_greed_index()["data"])
    df.set_index(
        pd.DatetimeIndex([pd.Timestamp(x, unit="ms", tz="UTC") for x in df.x]),
        inplace=True,
    )
    df.rename(columns={"y": "fear_greed_index"}, inplace=True)
    df.sort_index(inplace=True)
    df["fear_greed_index"] = df.fear_greed_index.fillna(method="ffill").astype(float)
    df["previous_max_fear_greed_index"] = (
        df["fear_greed_index"].rolling(window=historical_period, min_periods=historical_period).max()
    )
    df["previous_min_fear_greed_index"] = (
        df["fear_greed_index"].rolling(window=historical_period, min_periods=historical_period).min()
    )
    return (
        int(df.fear_greed_index.values[-1]),
        int(df.previous_max_fear_greed_index.values[-1]),
        int(df.previous_min_fear_greed_index.values[-1]),
    )


current_fear_greed_index, previous_max_fear_greed_index, previous_min_fear_greed_index = get_fear_greed_index_data()

print(f"Current fear greed index: {current_fear_greed_index}")
print(f"Previous max fear greed index: {previous_max_fear_greed_index}")
print(f"Previous min fear greed index: {previous_min_fear_greed_index}")
print()

good_call_buy = current_fear_greed_index >= previous_max_fear_greed_index - 2
good_put_buy = current_fear_greed_index <= previous_min_fear_greed_index + 2

print(f"Buy call: {good_call_buy}")
print(f"Buy put: {good_put_buy}")
# Out:
# Current fear greed index: 75
# Previous max fear greed index: 77
# Previous min fear greed index: 61
#
# Buy call: True
# Buy put: False

# %%
min_dte = 14
min_volume = 100
max_strike_distance_pct = 0.1
max_buy_price = 100

df_options_to_buy = df_options_chains.loc[
    (df_options_chains.DTE > min_dte)
    & (df_options_chains.STRIKE_DISTANCE_PCT < max_strike_distance_pct)
    & (
        (good_call_buy & (df_options_chains.C_VOLUME > min_volume) & (df_options_chains.C_ASK * 100 < max_buy_price))
        | (good_put_buy & (df_options_chains.P_VOLUME > min_volume) & (df_options_chains.P_ASK * 100 < max_buy_price))
    )
].sort_values(by="STRIKE_DISTANCE_PCT")
df_options_to_buy
# Out:
#               OPTION_ID  UNDERLYING_LAST EXPIRE_DATE  DTE  STRIKE  \
# 1514  QQQ20240216444.78            424.5  2024-02-16   18  444.78
# 1515     QQQ20240216445            424.5  2024-02-16   18  445.00
# 1517     QQQ20240216450            424.5  2024-02-16   18  450.00
# 2026     QQQ20240315460            424.5  2024-03-15   46  460.00
# 1725     QQQ20240301465            424.5  2024-03-01   32  465.00
#
#       STRIKE_DISTANCE  STRIKE_DISTANCE_PCT                   C_ID  C_BID  \
# 1514            20.28             0.047774  QQQ   240216C00444780   0.86
# 1515            20.50             0.048292  QQQ   240216C00445000   0.83
# 1517            25.50             0.060071  QQQ   240216C00450000   0.44
# 2026            35.50             0.083628  QQQ   240315C00460000   0.94
# 1725            40.50             0.095406  QQQ   240301C00465000   0.24
#
#       C_ASK  C_VOLUME                   P_ID  P_BID  P_ASK  P_VOLUME
# 1514   0.87       201  QQQ   240216P00444780  20.45  20.56         0
# 1515   0.84       113  QQQ   240216P00445000  20.64  20.77         0
# 1517   0.45       272  QQQ   240216P00450000  25.48  25.60         2
# 2026   0.95       124  QQQ   240315P00460000  35.39  35.60         0
# 1725   0.25       205  QQQ   240301P00465000  40.39  40.58         0

# %%
positions = task.schwab_api.get_balance_positions_v2()
owned_option_positions = [
    x for x in positions["positionDetails"]["positions"] if x["securityType"] == "Option" and x["shares"] > 0
]
owned_call_options = [x["symbol"] for x in owned_option_positions if x["displaySymbol"].endswith("C")]
owned_put_options = [x["symbol"] for x in owned_option_positions if x["displaySymbol"].endswith("P")]
print(owned_call_options)
print(owned_put_options)
positions
# Out:
# []
# []
# {'brokerageAccountId': 47004171,
#  'accountType': 0,
#  'dayTradeCount': 1,
#  'isPatternDayTrader': False,
#  'pendingPurchasesEnabled': True,
#  'showPendingPurchasesBanner': False,
#  'openOrdersIncluded': True,
#  'balanceDetails': {'availableToTradeBalances': {'cash': 504.79,
#    'settledFunds': 504.79,
#    'cashWithBorrow': 504.79,
#    'sma': 47.0,
#    'netWorth': 598.66},
#   'marginableSecurityBalances': {'equitiesAndEtfs': 504.79,
#    'mutualFunds': 504.79,
#    'shortSelling': 504.79},
#   'nonMarginableSecurityBalances': {'equitiesAndEtfs': 504.79,
#    'mutualFunds': 504.79,
#    'pennyStocks': 504.79},
#   'optionsBalances': {'longOptions': 504.79, 'shortOptions': 555.43}},
#  'positionDetails': {'positions': [{'symbol': 'AAPL',
#     'displaySymbol': None,
#     'symbolDescription': 'APPLE INC',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1973757747,
#     'shares': 0.0973,
#     'shortShares': 0.0,
#     'totalShares': 0.0973,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'ADBE',
#     'displaySymbol': None,
#     'symbolDescription': 'ADOBE INC',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1670511108,
#     'shares': 0.0223,
#     'shortShares': 0.0,
#     'totalShares': 0.0223,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'AMAT',
#     'displaySymbol': None,
#     'symbolDescription': 'APPLIED MATERIALS',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1444854003,
#     'shares': 0.0813,
#     'shortShares': 0.0,
#     'totalShares': 0.0813,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'AMD',
#     'displaySymbol': None,
#     'symbolDescription': 'ADVANCED MICRO DEVICE IN',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1449199007,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'reinvestCapitalGains': False},
#    {'symbol': 'INTU',
#     'displaySymbol': None,
#     'symbolDescription': 'INTUIT INC',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1417191240,
#     'shares': 0.0202,
#     'shortShares': 0.0,
#     'totalShares': 0.0202,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'KLAC',
#     'displaySymbol': None,
#     'symbolDescription': 'KLA CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 630948079,
#     'shares': 0.0114,
#     'shortShares': 0.0,
#     'totalShares': 0.0114,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'LRCX',
#     'displaySymbol': None,
#     'symbolDescription': 'LAM RESEARCH CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1778968234,
#     'shares': 0.0082,
#     'shortShares': 0.0,
#     'totalShares': 0.0082,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'MSFT',
#     'displaySymbol': None,
#     'symbolDescription': 'MICROSOFT CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1688643765,
#     'shares': 0.0517,
#     'shortShares': 0.0,
#     'totalShares': 0.0517,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'NVDA',
#     'displaySymbol': None,
#     'symbolDescription': 'NVIDIA CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 382397811,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'reinvestCapitalGains': False},
#    {'symbol': 'TXN',
#     'displaySymbol': None,
#     'symbolDescription': 'TEXAS INSTRUMENTS',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 753664080,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'reinvestCapitalGains': False},
#    {'symbol': 'QQQ   240301C00465000',
#     'displaySymbol': 'QQQ 03/01/2024 465.00 C',
#     'symbolDescription': 'CALL INVESCO QQQ TR     $465        EXP 03/01/24',
#     'securityType': 'Option',
#     'itemIssueId': 96225729,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'underlying': 'QQQ',
#     'underlyingDescription': 'INVSC QQQ TRUST SRS 1   ETF IV',
#     'underlyingType': 'Stock/ETF',
#     'underlyingId': 48644470,
#     'reinvestCapitalGains': False}]}}

# %%
df_owned_options_chains = df_options_chains.loc[
    (df_options_chains.C_ID.isin(owned_call_options)) | (df_options_chains.P_ID.isin(owned_put_options))
]
df_owned_options_chains
# Out:
# Empty DataFrame
# Columns: [OPTION_ID, UNDERLYING_LAST, EXPIRE_DATE, DTE, STRIKE, STRIKE_DISTANCE, STRIKE_DISTANCE_PCT, C_ID, C_BID, C_ASK, C_VOLUME, P_ID, P_BID, P_ASK, P_VOLUME]
# Index: []

# %%
task.schwab_api.trade_v2(
    ticker=df_owned_options_chains.C_ID.values[0], asset_class="Option", side="Sell", qty=1, dry_run=False
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 task.schwab_api.trade_v2(
# ----> 2     ticker=df_owned_options_chains.C_ID.values[0],
#       3     asset_class="Option",
#       4     side="Sell",
#       5     qty=1,
#       6     dry_run=False
#       7 )
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
