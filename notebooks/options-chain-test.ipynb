# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pandas_ta as ta
import re
import requests

from datetime import datetime

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
from invaas.schwab.schwab_task import SchwabTask

task = SchwabTask(env="local")
await task.setup_api()
# Out:
# 2024-01-29 22:05:29 WARNING No DBUtils defined in the runtime
# 2024-01-29 22:05:29 INFO Initializing task for local environment
# 2024-01-29 22:05:29 INFO Preparing to trade QQQ
# 2024-01-29 22:05:29 INFO Logging in to Schwab

# %%
def get_options_chains_data(ticker: str):
    options_info = requests.get(f"https://client.schwab.com/symlup/OptionsCwp/Underlying/{ticker}.txt").text
    options_info = re.sub(r"[\n\t\r]*", "", options_info)
    options_info = json.loads(options_info.replace('SuggestionBox.JsonpCallback("option",', "")[:-1])
    expirations = [x["Date"] for x in options_info["Expirations"]]
    options_chain_url = f"https://ausgateway.schwab.com/api/is.CSOptionChainsWeb/v1/OptionChainsPort/OptionChains/chains?Symbol={ticker}&IncludeGreeks=false&{','.join(expirations)}"
    task.schwab_api.update_token("update")
    return json.loads(requests.get(options_chain_url, headers=task.schwab_api.headers).text)


options_chains_data = get_options_chains_data("QQQ")
options_chains_data
# Out:
# {'UnderlyingData': {'Ask': '428.69',
#   'AskSize': '6',
#   'Bid': '428.65',
#   'BidSize': '6',
#   'Close': '423.81',
#   'CumulativeVolume': '38694724',
#   'Description': 'INVSC QQQ TRUST SRS 1',
#   'ErrorCode': 0,
#   'InstrumentType': 'ETF',
#   'Last': '428.15',
#   'NetChange': '4.34',
#   'PercentChange': '1.02',
#   'Open': '424.27',
#   'DailyHigh': '428.35',
#   'DailyLow': '423.61',
#   'High52W': '429.85',
#   'Low52W': '285.19',
#   'Symbol': 'QQQ',
#   'DividendYield': 0.5,
#   'ExchangeName': 'NASDAQ',
#   'IsDelayed': False},
#  'Expirations': [{'ExpirationGroup': {'RootSymbol': 'QQQ',
#     'MonthAndDay': 'Jan 29',
#     'Year': '2024',
#     'Day': 'Mon',
#     'SettlementType': '',
#     'DaysUntil': 0},
#    'AdjustedLabel': {},
#    'AdjustedGroup': '',
#    'Chains': [{'SymbolGroup': 'QQQ20240129353',
#      'Legs': [{'Sym': 'QQQ   240129C00353000',
#        'OptionType': 'C',
#        'Strk': '353',
#        'Chg': '0.55',
#        'ChgPct': '0.76',
#        'Bid': '73.73',
#        'Ask': '76.06',
#        'Lst': '72.22',
#        'Vol': '18',
#        'OI': '10',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00353000',
#        'OptionType': 'P',
#        'Strk': '353',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '5',
#        'OI': '6',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129354',
#      'Legs': [{'Sym': 'QQQ   240129C00354000',
#        'OptionType': 'C',
#        'Strk': '354',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '72.73',
#        'Ask': '75.06',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00354000',
#        'OptionType': 'P',
#        'Strk': '354',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '320',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129355',
#      'Legs': [{'Sym': 'QQQ   240129C00355000',
#        'OptionType': 'C',
#        'Strk': '355',
#        'Chg': '1.05',
#        'ChgPct': '1.5',
#        'Bid': '71.73',
#        'Ask': '74.06',
#        'Lst': '70.2',
#        'Vol': '14',
#        'OI': '14',
#        'BidSize': '1',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00355000',
#        'OptionType': 'P',
#        'Strk': '355',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '68',
#        'BidSize': '0',
#        'AskSize': '471'}]},
#     {'SymbolGroup': 'QQQ20240129356',
#      'Legs': [{'Sym': 'QQQ   240129C00356000',
#        'OptionType': 'C',
#        'Strk': '356',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '70.73',
#        'Ask': '73.06',
#        'Lst': '70.03',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00356000',
#        'OptionType': 'P',
#        'Strk': '356',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '39',
#        'BidSize': '0',
#        'AskSize': '471'}]},
#     {'SymbolGroup': 'QQQ20240129357',
#      'Legs': [{'Sym': 'QQQ   240129C00357000',
#        'OptionType': 'C',
#        'Strk': '357',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '69.73',
#        'Ask': '72.06',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00357000',
#        'OptionType': 'P',
#        'Strk': '357',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.03',
#        'Vol': '0',
#        'OI': '10',
#        'BidSize': '0',
#        'AskSize': '471'}]},
#     {'SymbolGroup': 'QQQ20240129358',
#      'Legs': [{'Sym': 'QQQ   240129C00358000',
#        'OptionType': 'C',
#        'Strk': '358',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '68.73',
#        'Ask': '71.06',
#        'Lst': '69.43',
#        'Vol': '0',
#        'OI': '9',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00358000',
#        'OptionType': 'P',
#        'Strk': '358',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '20',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129359',
#      'Legs': [{'Sym': 'QQQ   240129C00359000',
#        'OptionType': 'C',
#        'Strk': '359',
#        'Chg': '0.35',
#        'ChgPct': '0.54',
#        'Bid': '67.73',
#        'Ask': '70.06',
#        'Lst': '65.38',
#        'Vol': '1',
#        'OI': '1',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00359000',
#        'OptionType': 'P',
#        'Strk': '359',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '72',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129360',
#      'Legs': [{'Sym': 'QQQ   240129C00360000',
#        'OptionType': 'C',
#        'Strk': '360',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '66.73',
#        'Ask': '69.06',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00360000',
#        'OptionType': 'P',
#        'Strk': '360',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '77',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129361',
#      'Legs': [{'Sym': 'QQQ   240129C00361000',
#        'OptionType': 'C',
#        'Strk': '361',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '65.73',
#        'Ask': '68.06',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00361000',
#        'OptionType': 'P',
#        'Strk': '361',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '3',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129362',
#      'Legs': [{'Sym': 'QQQ   240129C00362000',
#        'OptionType': 'C',
#        'Strk': '362',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '64.73',
#        'Ask': '67.06',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00362000',
#        'OptionType': 'P',
#        'Strk': '362',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129363',
#      'Legs': [{'Sym': 'QQQ   240129C00363000',
#        'OptionType': 'C',
#        'Strk': '363',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '63.73',
#        'Ask': '66.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00363000',
#        'OptionType': 'P',
#        'Strk': '363',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129364',
#      'Legs': [{'Sym': 'QQQ   240129C00364000',
#        'OptionType': 'C',
#        'Strk': '364',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '62.73',
#        'Ask': '65.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00364000',
#        'OptionType': 'P',
#        'Strk': '364',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129365',
#      'Legs': [{'Sym': 'QQQ   240129C00365000',
#        'OptionType': 'C',
#        'Strk': '365',
#        'Chg': '-1.48',
#        'ChgPct': '-2.5',
#        'Bid': '61.73',
#        'Ask': '64.07',
#        'Lst': '59.2',
#        'Vol': '2',
#        'OI': '2',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00365000',
#        'OptionType': 'P',
#        'Strk': '365',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129366',
#      'Legs': [{'Sym': 'QQQ   240129C00366000',
#        'OptionType': 'C',
#        'Strk': '366',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '60.73',
#        'Ask': '63.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00366000',
#        'OptionType': 'P',
#        'Strk': '366',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129367',
#      'Legs': [{'Sym': 'QQQ   240129C00367000',
#        'OptionType': 'C',
#        'Strk': '367',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '59.73',
#        'Ask': '62.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00367000',
#        'OptionType': 'P',
#        'Strk': '367',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '12',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129368',
#      'Legs': [{'Sym': 'QQQ   240129C00368000',
#        'OptionType': 'C',
#        'Strk': '368',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '58.73',
#        'Ask': '61.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00368000',
#        'OptionType': 'P',
#        'Strk': '368',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '66',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129369',
#      'Legs': [{'Sym': 'QQQ   240129C00369000',
#        'OptionType': 'C',
#        'Strk': '369',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '57.73',
#        'Ask': '60.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00369000',
#        'OptionType': 'P',
#        'Strk': '369',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129370',
#      'Legs': [{'Sym': 'QQQ   240129C00370000',
#        'OptionType': 'C',
#        'Strk': '370',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '56.73',
#        'Ask': '59.07',
#        'Lst': '57.94',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00370000',
#        'OptionType': 'P',
#        'Strk': '370',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '250',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129371',
#      'Legs': [{'Sym': 'QQQ   240129C00371000',
#        'OptionType': 'C',
#        'Strk': '371',
#        'Chg': '-4.08',
#        'ChgPct': '-7.72',
#        'Bid': '55.73',
#        'Ask': '58.07',
#        'Lst': '52.88',
#        'Vol': '14',
#        'OI': '14',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00371000',
#        'OptionType': 'P',
#        'Strk': '371',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '60',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129372',
#      'Legs': [{'Sym': 'QQQ   240129C00372000',
#        'OptionType': 'C',
#        'Strk': '372',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '54.73',
#        'Ask': '57.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00372000',
#        'OptionType': 'P',
#        'Strk': '372',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '553',
#        'BidSize': '0',
#        'AskSize': '471'}]},
#     {'SymbolGroup': 'QQQ20240129373',
#      'Legs': [{'Sym': 'QQQ   240129C00373000',
#        'OptionType': 'C',
#        'Strk': '373',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '53.73',
#        'Ask': '56.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00373000',
#        'OptionType': 'P',
#        'Strk': '373',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '709',
#        'BidSize': '0',
#        'AskSize': '471'}]},
#     {'SymbolGroup': 'QQQ20240129374',
#      'Legs': [{'Sym': 'QQQ   240129C00374000',
#        'OptionType': 'C',
#        'Strk': '374',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '52.73',
#        'Ask': '55.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00374000',
#        'OptionType': 'P',
#        'Strk': '374',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1486',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129375',
#      'Legs': [{'Sym': 'QQQ   240129C00375000',
#        'OptionType': 'C',
#        'Strk': '375',
#        'Chg': '3.6',
#        'ChgPct': '6.85',
#        'Bid': '51.73',
#        'Ask': '54.07',
#        'Lst': '52.59',
#        'Vol': '2',
#        'OI': '2',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00375000',
#        'OptionType': 'P',
#        'Strk': '375',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '691',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129376',
#      'Legs': [{'Sym': 'QQQ   240129C00376000',
#        'OptionType': 'C',
#        'Strk': '376',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '50.73',
#        'Ask': '53.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00376000',
#        'OptionType': 'P',
#        'Strk': '376',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '412',
#        'BidSize': '0',
#        'AskSize': '471'}]},
#     {'SymbolGroup': 'QQQ20240129377',
#      'Legs': [{'Sym': 'QQQ   240129C00377000',
#        'OptionType': 'C',
#        'Strk': '377',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '49.73',
#        'Ask': '52.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00377000',
#        'OptionType': 'P',
#        'Strk': '377',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1608',
#        'BidSize': '0',
#        'AskSize': '470'}]},
#     {'SymbolGroup': 'QQQ20240129378',
#      'Legs': [{'Sym': 'QQQ   240129C00378000',
#        'OptionType': 'C',
#        'Strk': '378',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '48.73',
#        'Ask': '51.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00378000',
#        'OptionType': 'P',
#        'Strk': '378',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '7899',
#        'BidSize': '0',
#        'AskSize': '459'}]},
#     {'SymbolGroup': 'QQQ20240129379',
#      'Legs': [{'Sym': 'QQQ   240129C00379000',
#        'OptionType': 'C',
#        'Strk': '379',
#        'Chg': '3.65',
#        'ChgPct': '7.55',
#        'Bid': '47.73',
#        'Ask': '50.07',
#        'Lst': '48.37',
#        'Vol': '1',
#        'OI': '1',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00379000',
#        'OptionType': 'P',
#        'Strk': '379',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1530',
#        'BidSize': '0',
#        'AskSize': '460'}]},
#     {'SymbolGroup': 'QQQ20240129380',
#      'Legs': [{'Sym': 'QQQ   240129C00380000',
#        'OptionType': 'C',
#        'Strk': '380',
#        'Chg': '1.11',
#        'ChgPct': '2.46',
#        'Bid': '46.73',
#        'Ask': '49.07',
#        'Lst': '45.16',
#        'Vol': '4',
#        'OI': '4',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00380000',
#        'OptionType': 'P',
#        'Strk': '380',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '200',
#        'OI': '1053',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129381',
#      'Legs': [{'Sym': 'QQQ   240129C00381000',
#        'OptionType': 'C',
#        'Strk': '381',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '45.73',
#        'Ask': '48.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00381000',
#        'OptionType': 'P',
#        'Strk': '381',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '155',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129382',
#      'Legs': [{'Sym': 'QQQ   240129C00382000',
#        'OptionType': 'C',
#        'Strk': '382',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '44.73',
#        'Ask': '47.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00382000',
#        'OptionType': 'P',
#        'Strk': '382',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '14',
#        'BidSize': '0',
#        'AskSize': '471'}]},
#     {'SymbolGroup': 'QQQ20240129383',
#      'Legs': [{'Sym': 'QQQ   240129C00383000',
#        'OptionType': 'C',
#        'Strk': '383',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '43.73',
#        'Ask': '46.07',
#        'Lst': '40.83',
#        'Vol': '0',
#        'OI': '8',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00383000',
#        'OptionType': 'P',
#        'Strk': '383',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129384',
#      'Legs': [{'Sym': 'QQQ   240129C00384000',
#        'OptionType': 'C',
#        'Strk': '384',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '42.73',
#        'Ask': '45.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00384000',
#        'OptionType': 'P',
#        'Strk': '384',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.04',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129385',
#      'Legs': [{'Sym': 'QQQ   240129C00385000',
#        'OptionType': 'C',
#        'Strk': '385',
#        'Chg': '-3.22',
#        'ChgPct': '-8.1',
#        'Bid': '41.73',
#        'Ask': '44.07',
#        'Lst': '39.75',
#        'Vol': '1',
#        'OI': '1',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00385000',
#        'OptionType': 'P',
#        'Strk': '385',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '3',
#        'OI': '7',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129386',
#      'Legs': [{'Sym': 'QQQ   240129C00386000',
#        'OptionType': 'C',
#        'Strk': '386',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '40.73',
#        'Ask': '43.11',
#        'Lst': '42',
#        'Vol': '0',
#        'OI': '4',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00386000',
#        'OptionType': 'P',
#        'Strk': '386',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.03',
#        'Vol': '0',
#        'OI': '24',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129387',
#      'Legs': [{'Sym': 'QQQ   240129C00387000',
#        'OptionType': 'C',
#        'Strk': '387',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '39.73',
#        'Ask': '42.11',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00387000',
#        'OptionType': 'P',
#        'Strk': '387',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '44',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129388',
#      'Legs': [{'Sym': 'QQQ   240129C00388000',
#        'OptionType': 'C',
#        'Strk': '388',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '38.73',
#        'Ask': '41.07',
#        'Lst': '38.02',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00388000',
#        'OptionType': 'P',
#        'Strk': '388',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '121',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129389',
#      'Legs': [{'Sym': 'QQQ   240129C00389000',
#        'OptionType': 'C',
#        'Strk': '389',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '37.73',
#        'Ask': '40.07',
#        'Lst': '35.82',
#        'Vol': '13',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00389000',
#        'OptionType': 'P',
#        'Strk': '389',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '492',
#        'BidSize': '0',
#        'AskSize': '471'}]},
#     {'SymbolGroup': 'QQQ20240129390',
#      'Legs': [{'Sym': 'QQQ   240129C00390000',
#        'OptionType': 'C',
#        'Strk': '390',
#        'Chg': '3.39',
#        'ChgPct': '8.9',
#        'Bid': '36.73',
#        'Ask': '39.07',
#        'Lst': '38.09',
#        'Vol': '51',
#        'OI': '70',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00390000',
#        'OptionType': 'P',
#        'Strk': '390',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '20',
#        'OI': '2299',
#        'BidSize': '0',
#        'AskSize': '1760'}]},
#     {'SymbolGroup': 'QQQ20240129391',
#      'Legs': [{'Sym': 'QQQ   240129C00391000',
#        'OptionType': 'C',
#        'Strk': '391',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '35.73',
#        'Ask': '38.07',
#        'Lst': '34.83',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00391000',
#        'OptionType': 'P',
#        'Strk': '391',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129392',
#      'Legs': [{'Sym': 'QQQ   240129C00392000',
#        'OptionType': 'C',
#        'Strk': '392',
#        'Chg': '1.7',
#        'ChgPct': '5.12',
#        'Bid': '34.73',
#        'Ask': '37.07',
#        'Lst': '33.22',
#        'Vol': '47',
#        'OI': '1',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00392000',
#        'OptionType': 'P',
#        'Strk': '392',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '333',
#        'BidSize': '0',
#        'AskSize': '461'}]},
#     {'SymbolGroup': 'QQQ20240129393',
#      'Legs': [{'Sym': 'QQQ   240129C00393000',
#        'OptionType': 'C',
#        'Strk': '393',
#        'Chg': '0.63',
#        'ChgPct': '2.02',
#        'Bid': '33.73',
#        'Ask': '36.07',
#        'Lst': '31.17',
#        'Vol': '1',
#        'OI': '2',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00393000',
#        'OptionType': 'P',
#        'Strk': '393',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '1073',
#        'BidSize': '0',
#        'AskSize': '471'}]},
#     {'SymbolGroup': 'QQQ20240129394',
#      'Legs': [{'Sym': 'QQQ   240129C00394000',
#        'OptionType': 'C',
#        'Strk': '394',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '32.73',
#        'Ask': '35.07',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00394000',
#        'OptionType': 'P',
#        'Strk': '394',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '995',
#        'BidSize': '0',
#        'AskSize': '460'}]},
#     {'SymbolGroup': 'QQQ20240129395',
#      'Legs': [{'Sym': 'QQQ   240129C00395000',
#        'OptionType': 'C',
#        'Strk': '395',
#        'Chg': '4.4',
#        'ChgPct': '13.31',
#        'Bid': '31.73',
#        'Ask': '34.07',
#        'Lst': '33.06',
#        'Vol': '2',
#        'OI': '11',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00395000',
#        'OptionType': 'P',
#        'Strk': '395',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '1199',
#        'BidSize': '0',
#        'AskSize': '1360'}]},
#     {'SymbolGroup': 'QQQ20240129396',
#      'Legs': [{'Sym': 'QQQ   240129C00396000',
#        'OptionType': 'C',
#        'Strk': '396',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '30.74',
#        'Ask': '33.07',
#        'Lst': '28.49',
#        'Vol': '15',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00396000',
#        'OptionType': 'P',
#        'Strk': '396',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '15',
#        'BidSize': '0',
#        'AskSize': '1160'}]},
#     {'SymbolGroup': 'QQQ20240129397',
#      'Legs': [{'Sym': 'QQQ   240129C00397000',
#        'OptionType': 'C',
#        'Strk': '397',
#        'Chg': '0.2',
#        'ChgPct': '0.74',
#        'Bid': '29.74',
#        'Ask': '32.07',
#        'Lst': '27.17',
#        'Vol': '7',
#        'OI': '17',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00397000',
#        'OptionType': 'P',
#        'Strk': '397',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '47',
#        'BidSize': '0',
#        'AskSize': '1160'}]},
#     {'SymbolGroup': 'QQQ20240129398',
#      'Legs': [{'Sym': 'QQQ   240129C00398000',
#        'OptionType': 'C',
#        'Strk': '398',
#        'Chg': '3.98',
#        'ChgPct': '13.36',
#        'Bid': '28.74',
#        'Ask': '31.07',
#        'Lst': '29.78',
#        'Vol': '42',
#        'OI': '51',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00398000',
#        'OptionType': 'P',
#        'Strk': '398',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '3736',
#        'BidSize': '0',
#        'AskSize': '1160'}]},
#     {'SymbolGroup': 'QQQ20240129399',
#      'Legs': [{'Sym': 'QQQ   240129C00399000',
#        'OptionType': 'C',
#        'Strk': '399',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '27.74',
#        'Ask': '30.07',
#        'Lst': '26.7',
#        'Vol': '0',
#        'OI': '4',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00399000',
#        'OptionType': 'P',
#        'Strk': '399',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '812',
#        'BidSize': '0',
#        'AskSize': '961'}]},
#     {'SymbolGroup': 'QQQ20240129400',
#      'Legs': [{'Sym': 'QQQ   240129C00400000',
#        'OptionType': 'C',
#        'Strk': '400',
#        'Chg': '4.2',
#        'ChgPct': '15.02',
#        'Bid': '26.74',
#        'Ask': '29.07',
#        'Lst': '27.96',
#        'Vol': '25',
#        'OI': '25',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00400000',
#        'OptionType': 'P',
#        'Strk': '400',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '31',
#        'OI': '1848',
#        'BidSize': '0',
#        'AskSize': '937'}]},
#     {'SymbolGroup': 'QQQ20240129401',
#      'Legs': [{'Sym': 'QQQ   240129C00401000',
#        'OptionType': 'C',
#        'Strk': '401',
#        'Chg': '-3',
#        'ChgPct': '-12.09',
#        'Bid': '25.74',
#        'Ask': '28.07',
#        'Lst': '24.82',
#        'Vol': '28',
#        'OI': '30',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00401000',
#        'OptionType': 'P',
#        'Strk': '401',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '100',
#        'OI': '339',
#        'BidSize': '0',
#        'AskSize': '1360'}]},
#     {'SymbolGroup': 'QQQ20240129402',
#      'Legs': [{'Sym': 'QQQ   240129C00402000',
#        'OptionType': 'C',
#        'Strk': '402',
#        'Chg': '0.79',
#        'ChgPct': '3.53',
#        'Bid': '24.74',
#        'Ask': '27.07',
#        'Lst': '22.35',
#        'Vol': '3',
#        'OI': '18',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00402000',
#        'OptionType': 'P',
#        'Strk': '402',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '26',
#        'OI': '834',
#        'BidSize': '0',
#        'AskSize': '1360'}]},
#     {'SymbolGroup': 'QQQ20240129403',
#      'Legs': [{'Sym': 'QQQ   240129C00403000',
#        'OptionType': 'C',
#        'Strk': '403',
#        'Chg': '3.91',
#        'ChgPct': '15.97',
#        'Bid': '23.74',
#        'Ask': '26.11',
#        'Lst': '24.49',
#        'Vol': '23',
#        'OI': '33',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00403000',
#        'OptionType': 'P',
#        'Strk': '403',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '2',
#        'OI': '304',
#        'BidSize': '0',
#        'AskSize': '1160'}]},
#     {'SymbolGroup': 'QQQ20240129404',
#      'Legs': [{'Sym': 'QQQ   240129C00404000',
#        'OptionType': 'C',
#        'Strk': '404',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '22.73',
#        'Ask': '24.24',
#        'Lst': '22.82',
#        'Vol': '0',
#        'OI': '284',
#        'BidSize': '1',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00404000',
#        'OptionType': 'P',
#        'Strk': '404',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '302',
#        'OI': '1538',
#        'BidSize': '0',
#        'AskSize': '1160'}]},
#     {'SymbolGroup': 'QQQ20240129405',
#      'Legs': [{'Sym': 'QQQ   240129C00405000',
#        'OptionType': 'C',
#        'Strk': '405',
#        'Chg': '3.81',
#        'ChgPct': '16.75',
#        'Bid': '21.73',
#        'Ask': '23.22',
#        'Lst': '22.74',
#        'Vol': '6',
#        'OI': '447',
#        'BidSize': '1',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00405000',
#        'OptionType': 'P',
#        'Strk': '405',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '2',
#        'OI': '1109',
#        'BidSize': '0',
#        'AskSize': '1160'}]},
#     {'SymbolGroup': 'QQQ20240129406',
#      'Legs': [{'Sym': 'QQQ   240129C00406000',
#        'OptionType': 'C',
#        'Strk': '406',
#        'Chg': '4.34',
#        'ChgPct': '19.69',
#        'Bid': '20.73',
#        'Ask': '23.12',
#        'Lst': '22.04',
#        'Vol': '24',
#        'OI': '44',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00406000',
#        'OptionType': 'P',
#        'Strk': '406',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '114',
#        'OI': '550',
#        'BidSize': '0',
#        'AskSize': '850'}]},
#     {'SymbolGroup': 'QQQ20240129407',
#      'Legs': [{'Sym': 'QQQ   240129C00407000',
#        'OptionType': 'C',
#        'Strk': '407',
#        'Chg': '4.34',
#        'ChgPct': '20.61',
#        'Bid': '19.73',
#        'Ask': '21.21',
#        'Lst': '21.06',
#        'Vol': '9',
#        'OI': '47',
#        'BidSize': '1',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00407000',
#        'OptionType': 'P',
#        'Strk': '407',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '28',
#        'OI': '753',
#        'BidSize': '0',
#        'AskSize': '960'}]},
#     {'SymbolGroup': 'QQQ20240129408',
#      'Legs': [{'Sym': 'QQQ   240129C00408000',
#        'OptionType': 'C',
#        'Strk': '408',
#        'Chg': '4.51',
#        'ChgPct': '22.58',
#        'Bid': '18.73',
#        'Ask': '21.12',
#        'Lst': '19.97',
#        'Vol': '19',
#        'OI': '58',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00408000',
#        'OptionType': 'P',
#        'Strk': '408',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '33',
#        'OI': '3871',
#        'BidSize': '0',
#        'AskSize': '959'}]},
#     {'SymbolGroup': 'QQQ20240129409',
#      'Legs': [{'Sym': 'QQQ   240129C00409000',
#        'OptionType': 'C',
#        'Strk': '409',
#        'Chg': '3.77',
#        'ChgPct': '20.17',
#        'Bid': '17.73',
#        'Ask': '20.12',
#        'Lst': '18.69',
#        'Vol': '156',
#        'OI': '294',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00409000',
#        'OptionType': 'P',
#        'Strk': '409',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '6',
#        'OI': '2478',
#        'BidSize': '0',
#        'AskSize': '960'}]},
#     {'SymbolGroup': 'QQQ20240129410',
#      'Legs': [{'Sym': 'QQQ   240129C00410000',
#        'OptionType': 'C',
#        'Strk': '410',
#        'Chg': '4.2',
#        'ChgPct': '23.8',
#        'Bid': '16.73',
#        'Ask': '19.08',
#        'Lst': '17.65',
#        'Vol': '315',
#        'OI': '2512',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00410000',
#        'OptionType': 'P',
#        'Strk': '410',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '254',
#        'OI': '3674',
#        'BidSize': '0',
#        'AskSize': '960'}]},
#     {'SymbolGroup': 'QQQ20240129411',
#      'Legs': [{'Sym': 'QQQ   240129C00411000',
#        'OptionType': 'C',
#        'Strk': '411',
#        'Chg': '4.18',
#        'ChgPct': '24.76',
#        'Bid': '15.73',
#        'Ask': '18.08',
#        'Lst': '16.88',
#        'Vol': '10',
#        'OI': '136',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00411000',
#        'OptionType': 'P',
#        'Strk': '411',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '97',
#        'OI': '909',
#        'BidSize': '0',
#        'AskSize': '961'}]},
#     {'SymbolGroup': 'QQQ20240129412',
#      'Legs': [{'Sym': 'QQQ   240129C00412000',
#        'OptionType': 'C',
#        'Strk': '412',
#        'Chg': '4.15',
#        'ChgPct': '25.6',
#        'Bid': '14.73',
#        'Ask': '17.08',
#        'Lst': '16.21',
#        'Vol': '220',
#        'OI': '348',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00412000',
#        'OptionType': 'P',
#        'Strk': '412',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '389',
#        'OI': '4411',
#        'BidSize': '0',
#        'AskSize': '965'}]},
#     {'SymbolGroup': 'QQQ20240129413',
#      'Legs': [{'Sym': 'QQQ   240129C00413000',
#        'OptionType': 'C',
#        'Strk': '413',
#        'Chg': '4.12',
#        'ChgPct': '27.86',
#        'Bid': '13.73',
#        'Ask': '16.08',
#        'Lst': '14.79',
#        'Vol': '25',
#        'OI': '137',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00413000',
#        'OptionType': 'P',
#        'Strk': '413',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '991',
#        'OI': '2888',
#        'BidSize': '0',
#        'AskSize': '954'}]},
#     {'SymbolGroup': 'QQQ20240129414',
#      'Legs': [{'Sym': 'QQQ   240129C00414000',
#        'OptionType': 'C',
#        'Strk': '414',
#        'Chg': '4.24',
#        'ChgPct': '30.35',
#        'Bid': '12.73',
#        'Ask': '15.08',
#        'Lst': '13.97',
#        'Vol': '55',
#        'OI': '84',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00414000',
#        'OptionType': 'P',
#        'Strk': '414',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '3457',
#        'OI': '3331',
#        'BidSize': '0',
#        'AskSize': '950'}]},
#     {'SymbolGroup': 'QQQ20240129415',
#      'Legs': [{'Sym': 'QQQ   240129C00415000',
#        'OptionType': 'C',
#        'Strk': '415',
#        'Chg': '4.15',
#        'ChgPct': '32.96',
#        'Bid': '11.73',
#        'Ask': '14.08',
#        'Lst': '12.59',
#        'Vol': '97',
#        'OI': '827',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00415000',
#        'OptionType': 'P',
#        'Strk': '415',
#        'Chg': '-0.04',
#        'ChgPct': '-400',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '6031',
#        'OI': '5677',
#        'BidSize': '0',
#        'AskSize': '960'}]},
#     {'SymbolGroup': 'QQQ20240129416',
#      'Legs': [{'Sym': 'QQQ   240129C00416000',
#        'OptionType': 'C',
#        'Strk': '416',
#        'Chg': '4.38',
#        'ChgPct': '36.81',
#        'Bid': '11.71',
#        'Ask': '12.12',
#        'Lst': '11.9',
#        'Vol': '1194',
#        'OI': '883',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00416000',
#        'OptionType': 'P',
#        'Strk': '416',
#        'Chg': '-0.05',
#        'ChgPct': '-500',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '2334',
#        'OI': '3954',
#        'BidSize': '0',
#        'AskSize': '960'}]},
#     {'SymbolGroup': 'QQQ20240129417',
#      'Legs': [{'Sym': 'QQQ   240129C00417000',
#        'OptionType': 'C',
#        'Strk': '417',
#        'Chg': '4.2',
#        'ChgPct': '39.29',
#        'Bid': '10.71',
#        'Ask': '11.12',
#        'Lst': '10.69',
#        'Vol': '60',
#        'OI': '1589',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00417000',
#        'OptionType': 'P',
#        'Strk': '417',
#        'Chg': '-0.07',
#        'ChgPct': '-700',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '5564',
#        'OI': '5824',
#        'BidSize': '0',
#        'AskSize': '960'}]},
#     {'SymbolGroup': 'QQQ20240129418',
#      'Legs': [{'Sym': 'QQQ   240129C00418000',
#        'OptionType': 'C',
#        'Strk': '418',
#        'Chg': '4.21',
#        'ChgPct': '42.1',
#        'Bid': '9.71',
#        'Ask': '10.12',
#        'Lst': '10',
#        'Vol': '137',
#        'OI': '352',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00418000',
#        'OptionType': 'P',
#        'Strk': '418',
#        'Chg': '-0.12',
#        'ChgPct': '-1200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '13530',
#        'OI': '6002',
#        'BidSize': '0',
#        'AskSize': '965'}]},
#     {'SymbolGroup': 'QQQ20240129419',
#      'Legs': [{'Sym': 'QQQ   240129C00419000',
#        'OptionType': 'C',
#        'Strk': '419',
#        'Chg': '4.19',
#        'ChgPct': '47.67',
#        'Bid': '8.71',
#        'Ask': '9.12',
#        'Lst': '8.79',
#        'Vol': '206',
#        'OI': '483',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00419000',
#        'OptionType': 'P',
#        'Strk': '419',
#        'Chg': '-0.21',
#        'ChgPct': '-2100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '17103',
#        'OI': '3589',
#        'BidSize': '0',
#        'AskSize': '1360'}]},
#     {'SymbolGroup': 'QQQ20240129420',
#      'Legs': [{'Sym': 'QQQ   240129C00420000',
#        'OptionType': 'C',
#        'Strk': '420',
#        'Chg': '4.03',
#        'ChgPct': '51.67',
#        'Bid': '7.71',
#        'Ask': '8.12',
#        'Lst': '7.8',
#        'Vol': '1954',
#        'OI': '2285',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00420000',
#        'OptionType': 'P',
#        'Strk': '420',
#        'Chg': '-0.36',
#        'ChgPct': '-3600',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '29486',
#        'OI': '8551',
#        'BidSize': '0',
#        'AskSize': '970'}]},
#     {'SymbolGroup': 'QQQ20240129421',
#      'Legs': [{'Sym': 'QQQ   240129C00421000',
#        'OptionType': 'C',
#        'Strk': '421',
#        'Chg': '3.95',
#        'ChgPct': '57.25',
#        'Bid': '6.71',
#        'Ask': '7.12',
#        'Lst': '6.9',
#        'Vol': '1443',
#        'OI': '843',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00421000',
#        'OptionType': 'P',
#        'Strk': '421',
#        'Chg': '-0.57',
#        'ChgPct': '-5700',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '36254',
#        'OI': '5309',
#        'BidSize': '0',
#        'AskSize': '970'}]},
#     {'SymbolGroup': 'QQQ20240129422',
#      'Legs': [{'Sym': 'QQQ   240129C00422000',
#        'OptionType': 'C',
#        'Strk': '422',
#        'Chg': '3.86',
#        'ChgPct': '63.28',
#        'Bid': '5.71',
#        'Ask': '6.12',
#        'Lst': '6.1',
#        'Vol': '5176',
#        'OI': '6166',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00422000',
#        'OptionType': 'P',
#        'Strk': '422',
#        'Chg': '-0.88',
#        'ChgPct': '-8800',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '71922',
#        'OI': '12979',
#        'BidSize': '0',
#        'AskSize': '548'}]},
#     {'SymbolGroup': 'QQQ20240129423',
#      'Legs': [{'Sym': 'QQQ   240129C00423000',
#        'OptionType': 'C',
#        'Strk': '423',
#        'Chg': '3.15',
#        'ChgPct': '65.62',
#        'Bid': '4.71',
#        'Ask': '5.12',
#        'Lst': '4.8',
#        'Vol': '13756',
#        'OI': '3000',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00423000',
#        'OptionType': 'P',
#        'Strk': '423',
#        'Chg': '-1.26',
#        'ChgPct': '-12600',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '109475',
#        'OI': '7833',
#        'BidSize': '0',
#        'AskSize': '551'}]},
#     {'SymbolGroup': 'QQQ20240129424',
#      'Legs': [{'Sym': 'QQQ   240129C00424000',
#        'OptionType': 'C',
#        'Strk': '424',
#        'Chg': '2.68',
#        'ChgPct': '69.79',
#        'Bid': '3.71',
#        'Ask': '4.12',
#        'Lst': '3.84',
#        'Vol': '87459',
#        'OI': '5206',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00424000',
#        'OptionType': 'P',
#        'Strk': '424',
#        'Chg': '-1.77',
#        'ChgPct': '-17700',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '313896',
#        'OI': '7360',
#        'BidSize': '0',
#        'AskSize': '2256'}]},
#     {'SymbolGroup': 'QQQ20240129425',
#      'Legs': [{'Sym': 'QQQ   240129C00425000',
#        'OptionType': 'C',
#        'Strk': '425',
#        'Chg': '2.18',
#        'ChgPct': '73.9',
#        'Bid': '2.88',
#        'Ask': '4.08',
#        'Lst': '2.95',
#        'Vol': '173475',
#        'OI': '8347',
#        'BidSize': '2',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00425000',
#        'OptionType': 'P',
#        'Strk': '425',
#        'Chg': '-2.42',
#        'ChgPct': '-24200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '135154',
#        'OI': '4472',
#        'BidSize': '0',
#        'AskSize': '2385'}]},
#     {'SymbolGroup': 'QQQ20240129426',
#      'Legs': [{'Sym': 'QQQ   240129C00426000',
#        'OptionType': 'C',
#        'Strk': '426',
#        'Chg': '1.44',
#        'ChgPct': '75',
#        'Bid': '1.8',
#        'Ask': '2.12',
#        'Lst': '1.92',
#        'Vol': '168552',
#        'OI': '6977',
#        'BidSize': '1',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240129P00426000',
#        'OptionType': 'P',
#        'Strk': '426',
#        'Chg': '-3.08',
#        'ChgPct': '-30800',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '96496',
#        'OI': '5056',
#        'BidSize': '0',
#        'AskSize': '1522'}]},
#     {'SymbolGroup': 'QQQ20240129427',
#      'Legs': [{'Sym': 'QQQ   240129C00427000',
#        'OptionType': 'C',
#        'Strk': '427',
#        'Chg': '0.67',
#        'ChgPct': '69.79',
#        'Bid': '0.91',
#        'Ask': '1.67',
#        'Lst': '0.96',
#        'Vol': '101186',
#        'OI': '4626',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240129P00427000',
#        'OptionType': 'P',
#        'Strk': '427',
#        'Chg': '-3.94',
#        'ChgPct': '-39400',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '54587',
#        'OI': '1818',
#        'BidSize': '0',
#        'AskSize': '571'}]},
#     {'SymbolGroup': 'QQQ20240129428',
#      'Legs': [{'Sym': 'QQQ   240129C00428000',
#        'OptionType': 'C',
#        'Strk': '428',
#        'Chg': '-0.12',
#        'ChgPct': '-200',
#        'Bid': '0.05',
#        'Ask': '0.08',
#        'Lst': '0.06',
#        'Vol': '107751',
#        'OI': '7178',
#        'BidSize': '121',
#        'AskSize': '76'},
#       {'Sym': 'QQQ   240129P00428000',
#        'OptionType': 'P',
#        'Strk': '428',
#        'Chg': '-4.62',
#        'ChgPct': '-2887.5',
#        'Bid': '0.1',
#        'Ask': '0.29',
#        'Lst': '0.16',
#        'Vol': '42625',
#        'OI': '2208',
#        'BidSize': '1',
#        'AskSize': '11'}]},
#     {'SymbolGroup': 'QQQ20240129429',
#      'Legs': [{'Sym': 'QQQ   240129C00429000',
#        'OptionType': 'C',
#        'Strk': '429',
#        'Chg': '-0.1',
#        'ChgPct': '-1000',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '41648',
#        'OI': '4716',
#        'BidSize': '0',
#        'AskSize': '1821'},
#       {'Sym': 'QQQ   240129P00429000',
#        'OptionType': 'P',
#        'Strk': '429',
#        'Chg': '-4.7',
#        'ChgPct': '-443.4',
#        'Bid': '0.08',
# ...
#       {'Sym': 'QQQ   261218P00514780',
#        'OptionType': 'P',
#        'Strk': '514.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '87.89',
#        'Ask': '92.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '25',
#        'AskSize': '61'}]},
#     {'SymbolGroup': 'QQQ20261218519.78',
#      'Legs': [{'Sym': 'QQQ   261218C00519780',
#        'OptionType': 'C',
#        'Strk': '519.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '36',
#        'Ask': '41',
#        'Lst': '27.5',
#        'Vol': '0',
#        'OI': '3',
#        'BidSize': '173',
#        'AskSize': '173'},
#       {'Sym': 'QQQ   261218P00519780',
#        'OptionType': 'P',
#        'Strk': '519.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '91.75',
#        'Ask': '96',
#        'Lst': '93.69',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '25',
#        'AskSize': '61'}]},
#     {'SymbolGroup': 'QQQ20261218524.78',
#      'Legs': [{'Sym': 'QQQ   261218C00524780',
#        'OptionType': 'C',
#        'Strk': '524.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '34.5',
#        'Ask': '39.5',
#        'Lst': '36.81',
#        'Vol': '0',
#        'OI': '8',
#        'BidSize': '83',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00524780',
#        'OptionType': 'P',
#        'Strk': '524.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '95.81',
#        'Ask': '100.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '60',
#        'AskSize': '61'}]},
#     {'SymbolGroup': 'QQQ20261218529.78',
#      'Legs': [{'Sym': 'QQQ   261218C00529780',
#        'OptionType': 'C',
#        'Strk': '529.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '32.5',
#        'Ask': '37.5',
#        'Lst': '35',
#        'Vol': '0',
#        'OI': '10',
#        'BidSize': '83',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00529780',
#        'OptionType': 'P',
#        'Strk': '529.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '100.06',
#        'Ask': '105',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '25',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218534.78',
#      'Legs': [{'Sym': 'QQQ   261218C00534780',
#        'OptionType': 'C',
#        'Strk': '534.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '31',
#        'Ask': '36',
#        'Lst': '32.25',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '83',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00534780',
#        'OptionType': 'P',
#        'Strk': '534.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '104.57',
#        'Ask': '109.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '25',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218539.78',
#      'Legs': [{'Sym': 'QQQ   261218C00539780',
#        'OptionType': 'C',
#        'Strk': '539.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '29.5',
#        'Ask': '34.5',
#        'Lst': '31.58',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '83',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00539780',
#        'OptionType': 'P',
#        'Strk': '539.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '109.5',
#        'Ask': '114.33',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218544.78',
#      'Legs': [{'Sym': 'QQQ   261218C00544780',
#        'OptionType': 'C',
#        'Strk': '544.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '28',
#        'Ask': '33',
#        'Lst': '30.8',
#        'Vol': '0',
#        'OI': '21',
#        'BidSize': '83',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00544780',
#        'OptionType': 'P',
#        'Strk': '544.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '114.5',
#        'Ask': '119.33',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218549.78',
#      'Legs': [{'Sym': 'QQQ   261218C00549780',
#        'OptionType': 'C',
#        'Strk': '549.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '26.5',
#        'Ask': '31.5',
#        'Lst': '26.82',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '172',
#        'AskSize': '187'},
#       {'Sym': 'QQQ   261218P00549780',
#        'OptionType': 'P',
#        'Strk': '549.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '119.5',
#        'Ask': '124.33',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218554.78',
#      'Legs': [{'Sym': 'QQQ   261218C00554780',
#        'OptionType': 'C',
#        'Strk': '554.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '25',
#        'Ask': '30',
#        'Lst': '20.08',
#        'Vol': '0',
#        'OI': '51',
#        'BidSize': '81',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00554780',
#        'OptionType': 'P',
#        'Strk': '554.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '124.5',
#        'Ask': '129.33',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218559.78',
#      'Legs': [{'Sym': 'QQQ   261218C00559780',
#        'OptionType': 'C',
#        'Strk': '559.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '24',
#        'Ask': '28.5',
#        'Lst': '23.17',
#        'Vol': '0',
#        'OI': '11',
#        'BidSize': '60',
#        'AskSize': '161'},
#       {'Sym': 'QQQ   261218P00559780',
#        'OptionType': 'P',
#        'Strk': '559.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '129.5',
#        'Ask': '134.33',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218564.78',
#      'Legs': [{'Sym': 'QQQ   261218C00564780',
#        'OptionType': 'C',
#        'Strk': '564.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '22.5',
#        'Ask': '27.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '81',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00564780',
#        'OptionType': 'P',
#        'Strk': '564.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '134.5',
#        'Ask': '139.33',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218569.78',
#      'Legs': [{'Sym': 'QQQ   261218C00569780',
#        'OptionType': 'C',
#        'Strk': '569.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '21',
#        'Ask': '26',
#        'Lst': '18.29',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '183',
#        'AskSize': '183'},
#       {'Sym': 'QQQ   261218P00569780',
#        'OptionType': 'P',
#        'Strk': '569.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '139.5',
#        'Ask': '144.33',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218574.78',
#      'Legs': [{'Sym': 'QQQ   261218C00574780',
#        'OptionType': 'C',
#        'Strk': '574.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '20',
#        'Ask': '25',
#        'Lst': '20.2',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '183',
#        'AskSize': '183'},
#       {'Sym': 'QQQ   261218P00574780',
#        'OptionType': 'P',
#        'Strk': '574.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '144.5',
#        'Ask': '149.33',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218579.78',
#      'Legs': [{'Sym': 'QQQ   261218C00579780',
#        'OptionType': 'C',
#        'Strk': '579.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '19',
#        'Ask': '23.5',
#        'Lst': '20.75',
#        'Vol': '0',
#        'OI': '9',
#        'BidSize': '60',
#        'AskSize': '161'},
#       {'Sym': 'QQQ   261218P00579780',
#        'OptionType': 'P',
#        'Strk': '579.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '149.5',
#        'Ask': '154.33',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218584.78',
#      'Legs': [{'Sym': 'QQQ   261218C00584780',
#        'OptionType': 'C',
#        'Strk': '584.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '17.5',
#        'Ask': '22.5',
#        'Lst': '19.5',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '183',
#        'AskSize': '183'},
#       {'Sym': 'QQQ   261218P00584780',
#        'OptionType': 'P',
#        'Strk': '584.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '154.5',
#        'Ask': '159.33',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218589.78',
#      'Legs': [{'Sym': 'QQQ   261218C00589780',
#        'OptionType': 'C',
#        'Strk': '589.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '16.5',
#        'Ask': '21.48',
#        'Lst': '16.28',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '175',
#        'AskSize': '60'},
#       {'Sym': 'QQQ   261218P00589780',
#        'OptionType': 'P',
#        'Strk': '589.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '159.5',
#        'Ask': '164.32',
#        'Lst': '171.94',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218594.78',
#      'Legs': [{'Sym': 'QQQ   261218C00594780',
#        'OptionType': 'C',
#        'Strk': '594.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '15.5',
#        'Ask': '20.5',
#        'Lst': '14.72',
#        'Vol': '0',
#        'OI': '55',
#        'BidSize': '81',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00594780',
#        'OptionType': 'P',
#        'Strk': '594.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '164.5',
#        'Ask': '169.32',
#        'Lst': '176.82',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218599.78',
#      'Legs': [{'Sym': 'QQQ   261218C00599780',
#        'OptionType': 'C',
#        'Strk': '599.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '14.5',
#        'Ask': '19.5',
#        'Lst': '17.2',
#        'Vol': '0',
#        'OI': '60',
#        'BidSize': '81',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00599780',
#        'OptionType': 'P',
#        'Strk': '599.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '169.5',
#        'Ask': '174.32',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218604.78',
#      'Legs': [{'Sym': 'QQQ   261218C00604780',
#        'OptionType': 'C',
#        'Strk': '604.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '13.5',
#        'Ask': '18.5',
#        'Lst': '13.53',
#        'Vol': '0',
#        'OI': '3',
#        'BidSize': '81',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00604780',
#        'OptionType': 'P',
#        'Strk': '604.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '174.5',
#        'Ask': '179.32',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218609.78',
#      'Legs': [{'Sym': 'QQQ   261218C00609780',
#        'OptionType': 'C',
#        'Strk': '609.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '12.5',
#        'Ask': '17.5',
#        'Lst': '13.58',
#        'Vol': '0',
#        'OI': '31',
#        'BidSize': '81',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00609780',
#        'OptionType': 'P',
#        'Strk': '609.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '179.5',
#        'Ask': '184.32',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218615',
#      'Legs': [{'Sym': 'QQQ   261218C00615000',
#        'OptionType': 'C',
#        'Strk': '615',
#        'Chg': '0.11',
#        'ChgPct': '0.83',
#        'Bid': '12',
#        'Ask': '17',
#        'Lst': '13.25',
#        'Vol': '2',
#        'OI': '869',
#        'BidSize': '190',
#        'AskSize': '190'},
#       {'Sym': 'QQQ   261218P00615000',
#        'OptionType': 'P',
#        'Strk': '615',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '184.55',
#        'Ask': '189.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218620',
#      'Legs': [{'Sym': 'QQQ   261218C00620000',
#        'OptionType': 'C',
#        'Strk': '620',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '11',
#        'Ask': '16',
#        'Lst': '13.38',
#        'Vol': '0',
#        'OI': '18',
#        'BidSize': '81',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00620000',
#        'OptionType': 'P',
#        'Strk': '620',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '189.55',
#        'Ask': '194.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218625',
#      'Legs': [{'Sym': 'QQQ   261218C00625000',
#        'OptionType': 'C',
#        'Strk': '625',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '10.5',
#        'Ask': '15',
#        'Lst': '11.89',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '161',
#        'AskSize': '60'},
#       {'Sym': 'QQQ   261218P00625000',
#        'OptionType': 'P',
#        'Strk': '625',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '194.55',
#        'Ask': '199.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218630',
#      'Legs': [{'Sym': 'QQQ   261218C00630000',
#        'OptionType': 'C',
#        'Strk': '630',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '9.5',
#        'Ask': '14.5',
#        'Lst': '10.94',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '81',
#        'AskSize': '80'},
#       {'Sym': 'QQQ   261218P00630000',
#        'OptionType': 'P',
#        'Strk': '630',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '199.55',
#        'Ask': '204.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218635',
#      'Legs': [{'Sym': 'QQQ   261218C00635000',
#        'OptionType': 'C',
#        'Strk': '635',
#        'Chg': '1.02',
#        'ChgPct': '9.07',
#        'Bid': '10.77',
#        'Ask': '13.5',
#        'Lst': '11.25',
#        'Vol': '120',
#        'OI': '36',
#        'BidSize': '1',
#        'AskSize': '60'},
#       {'Sym': 'QQQ   261218P00635000',
#        'OptionType': 'P',
#        'Strk': '635',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '204.55',
#        'Ask': '209.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218640',
#      'Legs': [{'Sym': 'QQQ   261218C00640000',
#        'OptionType': 'C',
#        'Strk': '640',
#        'Chg': '0.77',
#        'ChgPct': '7.33',
#        'Bid': '8.31',
#        'Ask': '13',
#        'Lst': '10.5',
#        'Vol': '4',
#        'OI': '34',
#        'BidSize': '60',
#        'AskSize': '191'},
#       {'Sym': 'QQQ   261218P00640000',
#        'OptionType': 'P',
#        'Strk': '640',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '209.55',
#        'Ask': '214.5',
#        'Lst': '216.6',
#        'Vol': '1',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]}]}],
#  'CurrentDateTime': '10:05:42 PM ET, 01/29/2024',
#  'InterestRate': '0.052',
#  'IsDelayed': False,
#  'IsPartialData': False,
#  'ContractSpecs': {'UnderlyingType': 'ETF',
#   'ExerStyle': 'American',
#   'SetType': 'PM',
#   'Multi': '100',
#   'Deliverable': '100 QQQ',
#   'Cash': ''},
#  'Provider': 'SchwabMDS'}

# %%
data = []
underlying_last = float(options_chains_data["UnderlyingData"]["Last"])

for expiration in options_chains_data["Expirations"]:
    days_until_expiration = expiration["ExpirationGroup"]["DaysUntil"]
    expiration_month_day = expiration["ExpirationGroup"]["MonthAndDay"].split(" ")
    expiration_month = expiration_month_day[0]
    expiration_day = expiration_month_day[1]
    expiration_year = expiration["ExpirationGroup"]["Year"]
    expiration_date = datetime.strptime(f"{expiration_month} {expiration_day} {expiration_year}", "%b %d %Y")

    for chain in expiration["Chains"]:
        data_obj = {}
        data_obj["OPTION_ID"] = chain["SymbolGroup"]
        data_obj["UNDERLYING_LAST"] = underlying_last
        data_obj["EXPIRE_DATE"] = expiration_date
        data_obj["DTE"] = days_until_expiration

        for leg in chain["Legs"]:
            data_obj["STRIKE"] = float(leg["Strk"])
            data_obj["STRIKE_DISTANCE"] = abs(data_obj["STRIKE"] - underlying_last)
            data_obj["STRIKE_DISTANCE_PCT"] = data_obj["STRIKE_DISTANCE"] / underlying_last
            leg_prefix = leg["OptionType"] + "_"
            data_obj[leg_prefix + "ID"] = leg["Sym"]
            data_obj[leg_prefix + "BID"] = float(leg["Bid"])
            data_obj[leg_prefix + "ASK"] = float(leg["Ask"])
            data_obj[leg_prefix + "VOLUME"] = int(leg["Vol"])

        data.append(data_obj)

df_options_chains = pd.DataFrame(data=data)
df_options_chains
# Out:
#            OPTION_ID  UNDERLYING_LAST EXPIRE_DATE   DTE  STRIKE  \
# 0     QQQ20240129353           428.15  2024-01-29     0   353.0
# 1     QQQ20240129354           428.15  2024-01-29     0   354.0
# 2     QQQ20240129355           428.15  2024-01-29     0   355.0
# 3     QQQ20240129356           428.15  2024-01-29     0   356.0
# 4     QQQ20240129357           428.15  2024-01-29     0   357.0
# ...              ...              ...         ...   ...     ...
# 4183  QQQ20261218620           428.15  2026-12-18  1054   620.0
# 4184  QQQ20261218625           428.15  2026-12-18  1054   625.0
# 4185  QQQ20261218630           428.15  2026-12-18  1054   630.0
# 4186  QQQ20261218635           428.15  2026-12-18  1054   635.0
# 4187  QQQ20261218640           428.15  2026-12-18  1054   640.0
#
#       STRIKE_DISTANCE  STRIKE_DISTANCE_PCT                   C_ID  C_BID  \
# 0               75.15             0.175523  QQQ   240129C00353000  73.73
# 1               74.15             0.173187  QQQ   240129C00354000  72.73
# 2               73.15             0.170851  QQQ   240129C00355000  71.73
# 3               72.15             0.168516  QQQ   240129C00356000  70.73
# 4               71.15             0.166180  QQQ   240129C00357000  69.73
# ...               ...                  ...                    ...    ...
# 4183           191.85             0.448091  QQQ   261218C00620000  11.00
# 4184           196.85             0.459769  QQQ   261218C00625000  10.50
# 4185           201.85             0.471447  QQQ   261218C00630000   9.50
# 4186           206.85             0.483125  QQQ   261218C00635000  10.77
# 4187           211.85             0.494803  QQQ   261218C00640000   8.31
#
#       C_ASK  C_VOLUME                   P_ID   P_BID   P_ASK  P_VOLUME
# 0     76.06        18  QQQ   240129P00353000    0.00    0.01         5
# 1     75.06         0  QQQ   240129P00354000    0.00    0.01         0
# 2     74.06        14  QQQ   240129P00355000    0.00    0.01         0
# 3     73.06         0  QQQ   240129P00356000    0.00    0.01         0
# 4     72.06         0  QQQ   240129P00357000    0.00    0.01         0
# ...     ...       ...                    ...     ...     ...       ...
# 4183  16.00         0  QQQ   261218P00620000  189.55  194.50         0
# 4184  15.00         0  QQQ   261218P00625000  194.55  199.50         0
# 4185  14.50         0  QQQ   261218P00630000  199.55  204.50         0
# 4186  13.50       120  QQQ   261218P00635000  204.55  209.50         0
# 4187  13.00         4  QQQ   261218P00640000  209.55  214.50         1
#
# [4188 rows x 15 columns]

# %%
from invaas.schwab.cnn_fear_greed_index import get_historical_cnn_fear_greed_index


def get_fear_greed_index_data():
    historical_period = 14
    df = pd.DataFrame(data=get_historical_cnn_fear_greed_index()["data"])
    df.set_index(
        pd.DatetimeIndex([pd.Timestamp(x, unit="ms", tz="UTC") for x in df.x]),
        inplace=True,
    )
    df.rename(columns={"y": "fear_greed_index"}, inplace=True)
    df.sort_index(inplace=True)
    df["fear_greed_index"] = df.fear_greed_index.fillna(method="ffill").astype(float)
    df["previous_max_fear_greed_index"] = (
        df["fear_greed_index"].rolling(window=historical_period, min_periods=historical_period).max()
    )
    df["previous_min_fear_greed_index"] = (
        df["fear_greed_index"].rolling(window=historical_period, min_periods=historical_period).min()
    )
    return (
        int(df.fear_greed_index.values[-1]),
        int(df.previous_max_fear_greed_index.values[-1]),
        int(df.previous_min_fear_greed_index.values[-1]),
    )


current_fear_greed_index, previous_max_fear_greed_index, previous_min_fear_greed_index = get_fear_greed_index_data()

print(f"Current fear greed index: {current_fear_greed_index}")
print(f"Previous max fear greed index: {previous_max_fear_greed_index}")
print(f"Previous min fear greed index: {previous_min_fear_greed_index}")
print()

good_call_buy = current_fear_greed_index >= previous_max_fear_greed_index - 2
good_put_buy = current_fear_greed_index <= previous_min_fear_greed_index + 2

print(f"Buy call: {good_call_buy}")
print(f"Buy put: {good_put_buy}")
# Out:
# Current fear greed index: 76
# Previous max fear greed index: 77
# Previous min fear greed index: 61
#
# Buy call: True
# Buy put: False

# %%
min_dte = 14
min_volume = 100
max_strike_distance_pct = 0.1
max_buy_price = 100

df_options_to_buy = df_options_chains.loc[
    (df_options_chains.DTE > min_dte)
    & (df_options_chains.STRIKE_DISTANCE_PCT < max_strike_distance_pct)
    & (
        (good_call_buy & (df_options_chains.C_VOLUME > min_volume) & (df_options_chains.C_ASK * 100 < max_buy_price))
        | (good_put_buy & (df_options_chains.P_VOLUME > min_volume) & (df_options_chains.P_ASK * 100 < max_buy_price))
    )
].sort_values(by="STRIKE_DISTANCE_PCT")
df_options_to_buy
# Out:
#               OPTION_ID  UNDERLYING_LAST EXPIRE_DATE  DTE  STRIKE  \
# 1516  QQQ20240216449.78           428.15  2024-02-16   18  449.78
# 1517     QQQ20240216450           428.15  2024-02-16   18  450.00
# 1519     QQQ20240216455           428.15  2024-02-16   18  455.00
# 1723     QQQ20240301455           428.15  2024-03-01   32  455.00
# 1628     QQQ20240223460           428.15  2024-02-23   25  460.00
# 1725     QQQ20240301465           428.15  2024-03-01   32  465.00
# 2028     QQQ20240315465           428.15  2024-03-15   46  465.00
# 2029  QQQ20240315469.78           428.15  2024-03-15   46  469.78
# 2030     QQQ20240315470           428.15  2024-03-15   46  470.00
#
#       STRIKE_DISTANCE  STRIKE_DISTANCE_PCT                   C_ID  C_BID  \
# 1516            21.63             0.050520  QQQ   240216C00449780   0.69
# 1517            21.85             0.051034  QQQ   240216C00450000   0.68
# 1519            26.85             0.062712  QQQ   240216C00455000   0.35
# 1723            26.85             0.062712  QQQ   240301C00455000   0.96
# 1628            31.85             0.074390  QQQ   240223C00460000   0.33
# 1725            36.85             0.086068  QQQ   240301C00465000   0.34
# 2028            36.85             0.086068  QQQ   240315C00465000   0.84
# 2029            41.63             0.097232  QQQ   240315C00469780   0.55
# 2030            41.85             0.097746  QQQ   240315C00470000   0.54
#
#       C_ASK  C_VOLUME                   P_ID  P_BID  P_ASK  P_VOLUME
# 1516   0.71       324  QQQ   240216P00449780  21.80  22.07         0
# 1517   0.69      6275  QQQ   240216P00450000  22.08  22.23         6
# 1519   0.36      4688  QQQ   240216P00455000  26.92  27.25         0
# 1723   0.98       115  QQQ   240301P00455000  26.92  27.24         0
# 1628   0.34       842  QQQ   240223P00460000  31.92  32.24         9
# 1725   0.37       331  QQQ   240301P00465000  36.92  37.24         0
# 2028   0.85       374  QQQ   240315P00465000  36.92  37.24         0
# 2029   0.57       311  QQQ   240315P00469780  41.70  42.02         0
# 2030   0.56       123  QQQ   240315P00470000  41.92  42.24         0

# %%
positions = task.schwab_api.get_balance_positions()
owned_option_positions = [
    x for x in positions["positionDetails"]["positions"] if x["securityType"] == "Option" and x["shares"] > 0
]
owned_call_options = [x for x in owned_option_positions if x["symbolDescription"].startswith("CALL")]
owned_put_options = [x for x in owned_option_positions if x["symbolDescription"].startswith("PUT")]
print(owned_call_options)
print(owned_put_options)
positions
# Out:
# []
# []
# {'brokerageAccountId': 47004171,
#  'accountType': 0,
#  'dayTradeCount': 1,
#  'isPatternDayTrader': False,
#  'pendingPurchasesEnabled': True,
#  'showPendingPurchasesBanner': False,
#  'openOrdersIncluded': True,
#  'balanceDetails': {'availableToTradeBalances': {'cash': 504.79,
#    'settledFunds': 504.79,
#    'cashWithBorrow': 504.79,
#    'sma': 47.0,
#    'netWorth': 599.35},
#   'marginableSecurityBalances': {'equitiesAndEtfs': 504.79,
#    'mutualFunds': 504.79,
#    'shortSelling': 504.79},
#   'nonMarginableSecurityBalances': {'equitiesAndEtfs': 504.79,
#    'mutualFunds': 504.79,
#    'pennyStocks': 504.79},
#   'optionsBalances': {'longOptions': 504.79, 'shortOptions': 555.43}},
#  'positionDetails': {'positions': [{'symbol': 'AAPL',
#     'displaySymbol': None,
#     'symbolDescription': 'APPLE INC',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1973757747,
#     'shares': 0.0973,
#     'shortShares': 0.0,
#     'totalShares': 0.0973,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'ADBE',
#     'displaySymbol': None,
#     'symbolDescription': 'ADOBE INC',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1670511108,
#     'shares': 0.0223,
#     'shortShares': 0.0,
#     'totalShares': 0.0223,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'AMAT',
#     'displaySymbol': None,
#     'symbolDescription': 'APPLIED MATERIALS',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1444854003,
#     'shares': 0.0813,
#     'shortShares': 0.0,
#     'totalShares': 0.0813,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'AMD',
#     'displaySymbol': None,
#     'symbolDescription': 'ADVANCED MICRO DEVICE IN',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1449199007,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'reinvestCapitalGains': False},
#    {'symbol': 'INTU',
#     'displaySymbol': None,
#     'symbolDescription': 'INTUIT INC',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1417191240,
#     'shares': 0.0202,
#     'shortShares': 0.0,
#     'totalShares': 0.0202,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'KLAC',
#     'displaySymbol': None,
#     'symbolDescription': 'KLA CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 630948079,
#     'shares': 0.0114,
#     'shortShares': 0.0,
#     'totalShares': 0.0114,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'LRCX',
#     'displaySymbol': None,
#     'symbolDescription': 'LAM RESEARCH CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1778968234,
#     'shares': 0.0082,
#     'shortShares': 0.0,
#     'totalShares': 0.0082,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'MSFT',
#     'displaySymbol': None,
#     'symbolDescription': 'MICROSOFT CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1688643765,
#     'shares': 0.0517,
#     'shortShares': 0.0,
#     'totalShares': 0.0517,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'NVDA',
#     'displaySymbol': None,
#     'symbolDescription': 'NVIDIA CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 382397811,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'reinvestCapitalGains': False},
#    {'symbol': 'TXN',
#     'displaySymbol': None,
#     'symbolDescription': 'TEXAS INSTRUMENTS',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 753664080,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'reinvestCapitalGains': False},
#    {'symbol': 'QQQ   240301C00465000',
#     'displaySymbol': 'QQQ 03/01/2024 465.00 C',
#     'symbolDescription': 'CALL INVESCO QQQ TR     $465        EXP 03/01/24',
#     'securityType': 'Option',
#     'itemIssueId': 96225729,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'underlying': 'QQQ',
#     'underlyingDescription': 'INVSC QQQ TRUST SRS 1   ETF IV',
#     'underlyingType': 'Stock/ETF',
#     'underlyingId': 48644470,
#     'reinvestCapitalGains': False}]}}

# %%
df_owned_options_chains = df_options_chains.loc[
    (df_options_chains.C_ID.isin(owned_call_options)) | (df_options_chains.P_ID.isin(owned_put_options))
]
df_owned_options_chains
# Out:
# Empty DataFrame
# Columns: [OPTION_ID, UNDERLYING_LAST, EXPIRE_DATE, DTE, STRIKE, STRIKE_DISTANCE, STRIKE_DISTANCE_PCT, C_ID, C_BID, C_ASK, C_VOLUME, P_ID, P_BID, P_ASK, P_VOLUME]
# Index: []

# %%
task.schwab_api.get_balance_positions()
# task.schwab_api.trade(
#     ticker=df_owned_options_chains.C_ID.values[0], asset_class="Option", side="Sell", qty=1, dry_run=False
# )
# Out:
# {'brokerageAccountId': 47004171,
#  'accountType': 0,
#  'dayTradeCount': 1,
#  'isPatternDayTrader': False,
#  'pendingPurchasesEnabled': True,
#  'showPendingPurchasesBanner': False,
#  'openOrdersIncluded': True,
#  'balanceDetails': {'availableToTradeBalances': {'cash': 504.79,
#    'settledFunds': 504.79,
#    'cashWithBorrow': 504.79,
#    'sma': 47.0,
#    'netWorth': 599.35},
#   'marginableSecurityBalances': {'equitiesAndEtfs': 504.79,
#    'mutualFunds': 504.79,
#    'shortSelling': 504.79},
#   'nonMarginableSecurityBalances': {'equitiesAndEtfs': 504.79,
#    'mutualFunds': 504.79,
#    'pennyStocks': 504.79},
#   'optionsBalances': {'longOptions': 504.79, 'shortOptions': 555.43}},
#  'positionDetails': {'positions': [{'symbol': 'AAPL',
#     'displaySymbol': None,
#     'symbolDescription': 'APPLE INC',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1973757747,
#     'shares': 0.0973,
#     'shortShares': 0.0,
#     'totalShares': 0.0973,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'ADBE',
#     'displaySymbol': None,
#     'symbolDescription': 'ADOBE INC',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1670511108,
#     'shares': 0.0223,
#     'shortShares': 0.0,
#     'totalShares': 0.0223,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'AMAT',
#     'displaySymbol': None,
#     'symbolDescription': 'APPLIED MATERIALS',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1444854003,
#     'shares': 0.0813,
#     'shortShares': 0.0,
#     'totalShares': 0.0813,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'AMD',
#     'displaySymbol': None,
#     'symbolDescription': 'ADVANCED MICRO DEVICE IN',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1449199007,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'reinvestCapitalGains': False},
#    {'symbol': 'INTU',
#     'displaySymbol': None,
#     'symbolDescription': 'INTUIT INC',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1417191240,
#     'shares': 0.0202,
#     'shortShares': 0.0,
#     'totalShares': 0.0202,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'KLAC',
#     'displaySymbol': None,
#     'symbolDescription': 'KLA CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 630948079,
#     'shares': 0.0114,
#     'shortShares': 0.0,
#     'totalShares': 0.0114,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'LRCX',
#     'displaySymbol': None,
#     'symbolDescription': 'LAM RESEARCH CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1778968234,
#     'shares': 0.0082,
#     'shortShares': 0.0,
#     'totalShares': 0.0082,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'MSFT',
#     'displaySymbol': None,
#     'symbolDescription': 'MICROSOFT CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 1688643765,
#     'shares': 0.0517,
#     'shortShares': 0.0,
#     'totalShares': 0.0517,
#     'totalOptions': 0.0,
#     'reinvestDividend': True,
#     'reinvestCapitalGains': False},
#    {'symbol': 'NVDA',
#     'displaySymbol': None,
#     'symbolDescription': 'NVIDIA CORP',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 382397811,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'reinvestCapitalGains': False},
#    {'symbol': 'TXN',
#     'displaySymbol': None,
#     'symbolDescription': 'TEXAS INSTRUMENTS',
#     'securityType': 'Stock/ETF',
#     'itemIssueId': 753664080,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'reinvestCapitalGains': False},
#    {'symbol': 'QQQ   240301C00465000',
#     'displaySymbol': 'QQQ 03/01/2024 465.00 C',
#     'symbolDescription': 'CALL INVESCO QQQ TR     $465        EXP 03/01/24',
#     'securityType': 'Option',
#     'itemIssueId': 96225729,
#     'shares': 0.0,
#     'shortShares': 0.0,
#     'totalShares': 0.0,
#     'totalOptions': 0.0,
#     'reinvestDividend': False,
#     'underlying': 'QQQ',
#     'underlyingDescription': 'INVSC QQQ TRUST SRS 1   ETF IV',
#     'underlyingType': 'Stock/ETF',
#     'underlyingId': 48644470,
#     'reinvestCapitalGains': False}]}}

# %%
task.schwab_api.get_transaction_history()
# Out:
# {'fromDate': '01/29/2020',
#  'toDate': '01/29/2024',
#  'totalTransactionsAmount': '-$1,495.71',
#  'brokerageTransactions': [{'transactionDate': '01/29/2024',
#    'action': 'Sell to Close',
#    'symbol': 'QQQ 03/01/2024 465.00 C',
#    'description': 'CALL INVESCO QQQ TR $465 EXP 03/01/24',
#    'executionPrice': '$0.25',
#    'shareQuantity': '1',
#    'feesAndCommission': '$0.66',
#    'amount': '$24.34',
#    'sourceCode': '',
#    'effectiveDate': '01/29/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '',
#     'securityNumber': '4078115',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.65',
#     'primeBrokerAmount': '',
#     'principal': '$25.00',
#     'total': '$24.34',
#     'exchangeProcessingFee': '$0.01',
#     'secondaryFee': '$0.01',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/29/2024',
#     'overlaySubtitle': 'QQQ 03/01/2024 465.00 C'}},
#   {'transactionDate': '01/29/2024',
#    'action': 'Buy to Open',
#    'symbol': 'QQQ 03/01/2024 465.00 C',
#    'description': 'CALL INVESCO QQQ TR $465 EXP 03/01/24',
#    'executionPrice': '$0.24',
#    'shareQuantity': '1',
#    'feesAndCommission': '$0.66',
#    'amount': '-$24.66',
#    'sourceCode': '',
#    'effectiveDate': '01/29/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '',
#     'securityNumber': '4078115',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.65',
#     'primeBrokerAmount': '',
#     'principal': '-$24.00',
#     'total': '-$24.66',
#     'exchangeProcessingFee': '$0.01',
#     'secondaryFee': '$0.01',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/29/2024',
#     'overlaySubtitle': 'QQQ 03/01/2024 465.00 C'}},
#   {'transactionDate': '01/26/2024',
#    'action': 'Buy',
#    'symbol': 'KLAC',
#    'description': 'KLA CORP',
#    'executionPrice': '$610.00',
#    'shareQuantity': '0.0114',
#    'feesAndCommission': '',
#    'amount': '-$6.95',
#    'sourceCode': '',
#    'effectiveDate': '01/26/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '482480100',
#     'securityNumber': '2345553',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.95',
#     'total': '-$6.95',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/26/2024',
#     'overlaySubtitle': 'KLAC - KLA CORP'}},
#   {'transactionDate': '01/26/2024',
#    'action': 'Buy',
#    'symbol': 'ADBE',
#    'description': 'ADOBE INC',
#    'executionPrice': '$620.0218',
#    'shareQuantity': '0.0112',
#    'feesAndCommission': '',
#    'amount': '-$6.94',
#    'sourceCode': '',
#    'effectiveDate': '01/26/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '00724F101',
#     'securityNumber': '1030714',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.94',
#     'total': '-$6.94',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/26/2024',
#     'overlaySubtitle': 'ADBE - ADOBE INC'}},
#   {'transactionDate': '01/26/2024',
#    'action': 'Buy',
#    'symbol': 'MSFT',
#    'description': 'MICROSOFT CORP',
#    'executionPrice': '$403.39',
#    'shareQuantity': '0.0173',
#    'feesAndCommission': '',
#    'amount': '-$6.98',
#    'sourceCode': '',
#    'effectiveDate': '01/26/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '594918104',
#     'securityNumber': '2609588',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.98',
#     'total': '-$6.98',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/26/2024',
#     'overlaySubtitle': 'MSFT - MICROSOFT CORP'}},
#   {'transactionDate': '01/26/2024',
#    'action': 'Buy',
#    'symbol': 'AAPL',
#    'description': 'APPLE INC',
#    'executionPrice': '$193.97',
#    'shareQuantity': '0.036',
#    'feesAndCommission': '',
#    'amount': '-$6.98',
#    'sourceCode': '',
#    'effectiveDate': '01/26/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '037833100',
#     'securityNumber': '1180932',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.98',
#     'total': '-$6.98',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/26/2024',
#     'overlaySubtitle': 'AAPL - APPLE INC'}},
#   {'transactionDate': '01/26/2024',
#    'action': 'Buy',
#    'symbol': 'INTU',
#    'description': 'INTUIT INC',
#    'executionPrice': '$641.617',
#    'shareQuantity': '0.0093',
#    'feesAndCommission': '',
#    'amount': '-$5.97',
#    'sourceCode': '',
#    'effectiveDate': '01/26/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '461202103',
#     'securityNumber': '2300647',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$5.97',
#     'total': '-$5.97',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/26/2024',
#     'overlaySubtitle': 'INTU - INTUIT INC'}},
#   {'transactionDate': '01/26/2024',
#    'action': 'Buy',
#    'symbol': 'AMAT',
#    'description': 'APPLIED MATERIALS',
#    'executionPrice': '$168.4854',
#    'shareQuantity': '0.0415',
#    'feesAndCommission': '',
#    'amount': '-$6.99',
#    'sourceCode': '',
#    'effectiveDate': '01/26/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '038222105',
#     'securityNumber': '1184105',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.99',
#     'total': '-$6.99',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/26/2024',
#     'overlaySubtitle': 'AMAT - APPLIED MATERIALS'}},
#   {'transactionDate': '01/26/2024',
#    'action': 'Buy',
#    'symbol': 'LRCX',
#    'description': 'LAM RESEARCH CORP',
#    'executionPrice': '$852.2815',
#    'shareQuantity': '0.0082',
#    'feesAndCommission': '',
#    'amount': '-$6.99',
#    'sourceCode': '',
#    'effectiveDate': '01/26/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '512807108',
#     'securityNumber': '2416506',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.99',
#     'total': '-$6.99',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/26/2024',
#     'overlaySubtitle': 'LRCX - LAM RESEARCH CORP'}},
#   {'transactionDate': '01/26/2024',
#    'action': 'Sell',
#    'symbol': 'TXN',
#    'description': 'TEXAS INSTRUMENTS',
#    'executionPrice': '$165.54',
#    'shareQuantity': '0.0414',
#    'feesAndCommission': '',
#    'amount': '$6.85',
#    'sourceCode': '',
#    'effectiveDate': '01/26/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '882508104',
#     'securityNumber': '3510409',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '$6.85',
#     'total': '$6.85',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/26/2024',
#     'overlaySubtitle': 'TXN - TEXAS INSTRUMENTS'}},
#   {'transactionDate': '01/26/2024',
#    'action': 'Sell',
#    'symbol': 'NVDA',
#    'description': 'NVIDIA CORP',
#    'executionPrice': '$610.81',
#    'shareQuantity': '0.0113',
#    'feesAndCommission': '',
#    'amount': '$6.90',
#    'sourceCode': '',
#    'effectiveDate': '01/26/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '67066G104',
#     'securityNumber': '2822980',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '$6.90',
#     'total': '$6.90',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/26/2024',
#     'overlaySubtitle': 'NVDA - NVIDIA CORP'}},
#   {'transactionDate': '01/26/2024',
#    'action': 'Sell',
#    'symbol': 'AMD',
#    'description': 'ADVANCED MICRO DEVICE IN',
#    'executionPrice': '$176.68',
#    'shareQuantity': '0.077',
#    'feesAndCommission': '',
#    'amount': '$13.60',
#    'sourceCode': '',
#    'effectiveDate': '01/26/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/30/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '007903107',
#     'securityNumber': '1034200',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '$13.60',
#     'total': '$13.60',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/30/2024',
#     'tradeTransactionDate': '01/26/2024',
#     'overlaySubtitle': 'AMD - ADVANCED MICRO DEVICE IN'}},
#   {'transactionDate': '01/25/2024',
#    'action': 'Buy',
#    'symbol': 'INTU',
#    'description': 'INTUIT INC',
#    'executionPrice': '$642.0318',
#    'shareQuantity': '0.0109',
#    'feesAndCommission': '',
#    'amount': '-$7.00',
#    'sourceCode': '',
#    'effectiveDate': '01/25/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '461202103',
#     'securityNumber': '2300647',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$7.00',
#     'total': '-$7.00',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/29/2024',
#     'tradeTransactionDate': '01/25/2024',
#     'overlaySubtitle': 'INTU - INTUIT INC'}},
#   {'transactionDate': '01/25/2024',
#    'action': 'Buy',
#    'symbol': 'AMD',
#    'description': 'ADVANCED MICRO DEVICE IN',
#    'executionPrice': '$181.78',
#    'shareQuantity': '0.0385',
#    'feesAndCommission': '',
#    'amount': '-$7.00',
#    'sourceCode': '',
#    'effectiveDate': '01/25/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '007903107',
#     'securityNumber': '1034200',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$7.00',
#     'total': '-$7.00',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/29/2024',
#     'tradeTransactionDate': '01/25/2024',
#     'overlaySubtitle': 'AMD - ADVANCED MICRO DEVICE IN'}},
#   {'transactionDate': '01/25/2024',
#    'action': 'Buy',
#    'symbol': 'TXN',
#    'description': 'TEXAS INSTRUMENTS',
#    'executionPrice': '$168.79',
#    'shareQuantity': '0.0414',
#    'feesAndCommission': '',
#    'amount': '-$6.99',
#    'sourceCode': '',
#    'effectiveDate': '01/25/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '882508104',
#     'securityNumber': '3510409',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.99',
#     'total': '-$6.99',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/29/2024',
#     'tradeTransactionDate': '01/25/2024',
#     'overlaySubtitle': 'TXN - TEXAS INSTRUMENTS'}},
#   {'transactionDate': '01/25/2024',
#    'action': 'Buy',
#    'symbol': 'MSFT',
#    'description': 'MICROSOFT CORP',
#    'executionPrice': '$405.83',
#    'shareQuantity': '0.0172',
#    'feesAndCommission': '',
#    'amount': '-$6.98',
#    'sourceCode': '',
#    'effectiveDate': '01/25/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '594918104',
#     'securityNumber': '2609588',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.98',
#     'total': '-$6.98',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/29/2024',
#     'tradeTransactionDate': '01/25/2024',
#     'overlaySubtitle': 'MSFT - MICROSOFT CORP'}},
#   {'transactionDate': '01/25/2024',
#    'action': 'Buy',
#    'symbol': 'AAPL',
#    'description': 'APPLE INC',
#    'executionPrice': '$195.91',
#    'shareQuantity': '0.0357',
#    'feesAndCommission': '',
#    'amount': '-$6.99',
#    'sourceCode': '',
#    'effectiveDate': '01/25/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '037833100',
#     'securityNumber': '1180932',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.99',
#     'total': '-$6.99',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/29/2024',
#     'tradeTransactionDate': '01/25/2024',
#     'overlaySubtitle': 'AAPL - APPLE INC'}},
#   {'transactionDate': '01/25/2024',
#    'action': 'Buy',
#    'symbol': 'ADBE',
#    'description': 'ADOBE INC',
#    'executionPrice': '$625.5366',
#    'shareQuantity': '0.0111',
#    'feesAndCommission': '',
#    'amount': '-$6.94',
#    'sourceCode': '',
#    'effectiveDate': '01/25/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '00724F101',
#     'securityNumber': '1030714',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.94',
#     'total': '-$6.94',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/29/2024',
#     'tradeTransactionDate': '01/25/2024',
#     'overlaySubtitle': 'ADBE - ADOBE INC'}},
#   {'transactionDate': '01/25/2024',
#    'action': 'Buy',
#    'symbol': 'NVDA',
#    'description': 'NVIDIA CORP',
#    'executionPrice': '$619.2638',
#    'shareQuantity': '0.0113',
#    'feesAndCommission': '',
#    'amount': '-$7.00',
#    'sourceCode': '',
#    'effectiveDate': '01/25/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '67066G104',
#     'securityNumber': '2822980',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$7.00',
#     'total': '-$7.00',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/29/2024',
#     'tradeTransactionDate': '01/25/2024',
#     'overlaySubtitle': 'NVDA - NVIDIA CORP'}},
#   {'transactionDate': '01/25/2024',
#    'action': 'Buy',
#    'symbol': 'AMAT',
#    'description': 'APPLIED MATERIALS',
#    'executionPrice': '$175.7632',
#    'shareQuantity': '0.0398',
#    'feesAndCommission': '',
#    'amount': '-$7.00',
#    'sourceCode': '',
#    'effectiveDate': '01/25/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '038222105',
#     'securityNumber': '1184105',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$7.00',
#     'total': '-$7.00',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/29/2024',
#     'tradeTransactionDate': '01/25/2024',
#     'overlaySubtitle': 'AMAT - APPLIED MATERIALS'}},
#   {'transactionDate': '01/25/2024',
#    'action': 'Buy',
#    'symbol': 'AMD',
#    'description': 'ADVANCED MICRO DEVICE IN',
#    'executionPrice': '$181.6474',
#    'shareQuantity': '0.0385',
#    'feesAndCommission': '',
#    'amount': '-$6.99',
#    'sourceCode': '',
#    'effectiveDate': '01/25/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '007903107',
#     'securityNumber': '1034200',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.99',
#     'total': '-$6.99',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/29/2024',
#     'tradeTransactionDate': '01/25/2024',
#     'overlaySubtitle': 'AMD - ADVANCED MICRO DEVICE IN'}},
#   {'transactionDate': '01/25/2024',
#    'action': 'Buy',
#    'symbol': 'MSFT',
#    'description': 'MICROSOFT CORP',
#    'executionPrice': '$405.72',
#    'shareQuantity': '0.0172',
#    'feesAndCommission': '',
#    'amount': '-$6.98',
#    'sourceCode': '',
#    'effectiveDate': '01/25/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '594918104',
#     'securityNumber': '2609588',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$6.98',
#     'total': '-$6.98',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/29/2024',
#     'tradeTransactionDate': '01/25/2024',
#     'overlaySubtitle': 'MSFT - MICROSOFT CORP'}},
#   {'transactionDate': '01/23/2024',
#    'action': 'Buy',
#    'symbol': 'AAPL',
#    'description': 'APPLE INC',
#    'executionPrice': '$194.6558',
#    'shareQuantity': '0.0256',
#    'feesAndCommission': '',
#    'amount': '-$4.98',
#    'sourceCode': '',
#    'effectiveDate': '01/23/2024',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/25/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': True,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': {'cusipId': '037833100',
#     'securityNumber': '1180932',
#     'accruedInterest': '',
#     'redemptionFee': '',
#     'stateTaxes': '',
#     'withHoldingTaxes': '',
#     'otherAmount': '',
#     'commission': '$0.00',
#     'primeBrokerAmount': '',
#     'principal': '-$4.98',
#     'total': '-$4.98',
#     'exchangeProcessingFee': '',
#     'secondaryFee': '',
#     'settleDate': '01/25/2024',
#     'tradeTransactionDate': '01/23/2024',
#     'overlaySubtitle': 'AAPL - APPLE INC'}},
#   {'transactionDate': '01/16/2024 as of 01/15/2024',
#    'action': 'Bank Interest',
#    'symbol': '',
#    'description': 'BANK INT 121623-011524 TD BANK NA',
#    'executionPrice': '',
#    'shareQuantity': '',
#    'feesAndCommission': '',
#    'amount': '$0.15',
#    'sourceCode': 'BKINT',
#    'effectiveDate': '01/15/2024',
#    'depositSequenceId': '8345762',
#    'checkNumber': '',
#    'checkDate': '01/15/2024',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '12/27/2023 as of 12/26/2023',
#    'action': 'MoneyLink Transfer',
#    'symbol': '',
#    'description': 'Tfr Fifth Third Bank N, MR DANE ISBURGH',
#    'executionPrice': '',
#    'shareQuantity': '',
#    'feesAndCommission': '',
#    'amount': '$500.00',
#    'sourceCode': 'PDEFT',
#    'effectiveDate': '12/26/2023',
#    'depositSequenceId': '216438549',
#    'checkNumber': '',
#    'checkDate': '12/27/2023',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '12/18/2023 as of 12/15/2023',
#    'action': 'Bank Interest',
#    'symbol': '',
#    'description': 'BANK INT 111623-121523 TD BANK NA',
#    'executionPrice': '',
#    'shareQuantity': '',
#    'feesAndCommission': '',
#    'amount': '$0.01',
#    'sourceCode': 'BKINT',
#    'effectiveDate': '12/15/2023',
#    'depositSequenceId': '1992634',
#    'checkNumber': '',
#    'checkDate': '12/15/2023',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '12/07/2023 as of 12/06/2023',
#    'action': 'MoneyLink Transfer',
#    'symbol': '',
#    'description': 'Tfr Fifth Third Bank N, MR DANE ISBURGH',
#    'executionPrice': '',
#    'shareQuantity': '',
#    'feesAndCommission': '',
#    'amount': '$100.00',
#    'sourceCode': 'PDEFT',
#    'effectiveDate': '12/06/2023',
#    'depositSequenceId': '658878960',
#    'checkNumber': '',
#    'checkDate': '12/07/2023',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '05/30/2023',
#    'action': 'Journaled Shares',
#    'symbol': '',
#    'description': 'TDA TRAN - CASH MOVEMENT OF OUTGOING ACCOUNT TRANSFER',
#    'executionPrice': '',
#    'shareQuantity': '',
#    'feesAndCommission': '',
#    'amount': '-$0.25',
#    'sourceCode': 'JNL',
#    'effectiveDate': '05/30/2023',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '05/30/2023',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '05/30/2023',
#    'action': 'Internal Transfer',
#    'symbol': '',
#    'description': 'TDA TO CS&CO TRANSFER',
#    'executionPrice': '',
#    'shareQuantity': '',
#    'feesAndCommission': '',
#    'amount': '$0.25',
#    'sourceCode': 'TRFIN',
#    'effectiveDate': '05/30/2023',
#    'depositSequenceId': '1',
#    'checkNumber': '',
#    'checkDate': '05/30/2023',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '05/30/2023',
#    'action': 'Journaled Shares',
#    'symbol': '',
#    'description': 'TDA TRAN - CASH ALTERNATIVES REDEMPTION (MMDA1) BANK SWEEP WITHDRAWAL',
#    'executionPrice': '',
#    'shareQuantity': '',
#    'feesAndCommission': '',
#    'amount': '-$0.25',
#    'sourceCode': 'JNL',
#    'effectiveDate': '05/30/2023',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '05/30/2023',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '02/09/2022',
#    'action': 'Journaled Shares',
#    'symbol': '',
#    'description': 'TDA TRAN - CASH ALTERNATIVES PURCHASE (MMDA1) BANK SWEEP DEPOSIT',
#    'executionPrice': '',
#    'shareQuantity': '',
#    'feesAndCommission': '',
#    'amount': '$0.25',
#    'sourceCode': 'JNL',
#    'effectiveDate': '02/09/2022',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '02/09/2022',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '02/08/2022',
#    'action': 'Journaled Shares',
#    'symbol': '',
#    'description': 'TDA TRAN - CASH ALTERNATIVES REDEMPTION (MMDA1) BANK SWEEP WITHDRAWAL',
#    'executionPrice': '',
#    'shareQuantity': '',
#    'feesAndCommission': '',
#    'amount': '-$1,000.25',
#    'sourceCode': 'JNL',
#    'effectiveDate': '02/08/2022',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '02/08/2022',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '02/07/2022',
#    'action': 'MoneyLink Transfer',
#    'symbol': '',
#    'description': 'TDA TRAN - CLIENT REQUESTED ELECTRONIC FUNDING DISBURSEMENT (FUNDS NOW)',
#    'executionPrice': '',
#    'shareQuantity': '',
#    'feesAndCommission': '',
#    'amount': '-$1,000.00',
#    'sourceCode': 'PDEFT',
#    'effectiveDate': '02/07/2022',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '02/08/2022',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '01/31/2022',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '01/31/2022',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/31/2022',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '12/31/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '12/31/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '12/31/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '11/30/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '11/30/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '11/30/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '10/29/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '10/29/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '10/29/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '09/30/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '09/30/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '09/30/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '08/31/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '08/31/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '08/31/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '07/30/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '07/30/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '07/30/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '06/30/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '06/30/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '06/30/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '05/28/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '05/28/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '05/28/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '04/30/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '04/30/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '04/30/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '03/31/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '03/31/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '03/31/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '02/26/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '02/26/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '02/26/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '01/29/2021',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '01/29/2021',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/29/2021',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '12/31/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '12/31/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '12/31/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '11/30/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '11/30/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '11/30/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '10/30/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '10/30/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '10/30/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '09/30/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '09/30/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '09/30/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '08/31/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '08/31/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '08/31/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '07/31/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '07/31/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '07/31/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '06/30/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '06/30/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '06/30/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '05/29/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '05/29/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '05/29/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '04/30/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '04/30/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '04/30/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '03/31/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '03/31/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '03/31/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '02/28/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '02/28/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '02/28/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None},
#   {'transactionDate': '01/31/2020',
#    'action': 'Journaled Shares',
#    'symbol': 'MMDA1',
#    'description': 'TDA TRAN - CASH ALTERNATIVES INTEREST (MMDA1)',
#    'executionPrice': '',
#    'shareQuantity': '0.01',
#    'feesAndCommission': '',
#    'amount': '',
#    'sourceCode': 'JNL',
#    'effectiveDate': '01/31/2020',
#    'depositSequenceId': '0',
#    'checkNumber': '',
#    'checkDate': '01/31/2020',
#    'showWireDetailsLink': False,
#    'showCheckDetailsLink': False,
#    'showDepositDetailsLink': False,
#    'showTradeDetailsLink': False,
#    'showAdvisoryProgramCreditDetailsLink': False,
#    'transactionDetail': None}],
#  'bookmark': None}
