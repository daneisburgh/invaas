# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pandas_ta as ta
import re
import requests

from datetime import datetime

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
from invaas.schwab.schwab_task import SchwabTask

task = SchwabTask(env="local")
await task.setup_api()
# Out:
# 2024-05-11 23:32:06 WARNING No DBUtils defined in the runtime
# 2024-05-11 23:32:06 INFO Initializing task for local environment
# 2024-05-11 23:32:06 INFO Logging in to Schwab
# 2024-05-11 23:32:43 INFO Net worth: 1130.48
# 2024-05-11 23:32:44 INFO Available cash to buy stocks: 1130.48
# 2024-05-11 23:32:45 INFO Available cash to buy options: 1130.48

# %%
def get_options_chains_data(ticker: str):
    options_info = requests.get(f"https://client.schwab.com/symlup/OptionsCwp/Underlying/{ticker}.txt").text
    options_info = re.sub(r"[\n\t\r]*", "", options_info)
    options_info = json.loads(options_info.replace('SuggestionBox.JsonpCallback("option",', "")[:-1])
    expirations = [x["Date"] for x in options_info["Expirations"]]
    options_chain_url = f"https://ausgateway.schwab.com/api/is.CSOptionChainsWeb/v1/OptionChainsPort/OptionChains/chains?Symbol={ticker}&IncludeGreeks=false&{','.join(expirations)}"
    task.schwab_api.update_token("update")
    return json.loads(requests.get(options_chain_url, headers=task.schwab_api.headers).text)


options_chains_data = get_options_chains_data("QQQ")
options_chains_data
# Out:
# {'UnderlyingData': {'Ask': '441.25',
#   'AskSize': '1',
#   'Bid': '441.22',
#   'BidSize': '1',
#   'Close': '441.02',
#   'CumulativeVolume': '27116566',
#   'Description': 'INVSC QQQ TRUST SRS 1',
#   'ErrorCode': 0,
#   'InstrumentType': 'ETF',
#   'Last': '442.06',
#   'NetChange': '1.04',
#   'PercentChange': '0.24',
#   'Open': '442.54',
#   'DailyHigh': '444.31',
#   'DailyLow': '440.499',
#   'High52W': '449.34',
#   'Low52W': '322.94',
#   'Symbol': 'QQQ',
#   'DividendYield': 0.52,
#   'ExchangeName': 'NASDAQ',
#   'IsDelayed': False},
#  'Expirations': [{'ExpirationGroup': {'RootSymbol': 'QQQ',
#     'MonthAndDay': 'May 13',
#     'Year': '2024',
#     'Day': 'Mon',
#     'SettlementType': '',
#     'DaysUntil': 2},
#    'AdjustedLabel': {},
#    'AdjustedGroup': '',
#    'Chains': [{'SymbolGroup': 'QQQ20240513359',
#      'Legs': [{'Sym': 'QQQ   240513C00359000',
#        'OptionType': 'C',
#        'Strk': '359',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '82.77',
#        'Ask': '83.16',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00359000',
#        'OptionType': 'P',
#        'Strk': '359',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '26',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '532'}]},
#     {'SymbolGroup': 'QQQ20240513360',
#      'Legs': [{'Sym': 'QQQ   240513C00360000',
#        'OptionType': 'C',
#        'Strk': '360',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '81.77',
#        'Ask': '82.17',
#        'Lst': '81.9',
#        'Vol': '4',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00360000',
#        'OptionType': 'P',
#        'Strk': '360',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '528'}]},
#     {'SymbolGroup': 'QQQ20240513361',
#      'Legs': [{'Sym': 'QQQ   240513C00361000',
#        'OptionType': 'C',
#        'Strk': '361',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '80.77',
#        'Ask': '81.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00361000',
#        'OptionType': 'P',
#        'Strk': '361',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '524'}]},
#     {'SymbolGroup': 'QQQ20240513362',
#      'Legs': [{'Sym': 'QQQ   240513C00362000',
#        'OptionType': 'C',
#        'Strk': '362',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '79.77',
#        'Ask': '80.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00362000',
#        'OptionType': 'P',
#        'Strk': '362',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '521'}]},
#     {'SymbolGroup': 'QQQ20240513363',
#      'Legs': [{'Sym': 'QQQ   240513C00363000',
#        'OptionType': 'C',
#        'Strk': '363',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '78.77',
#        'Ask': '79.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00363000',
#        'OptionType': 'P',
#        'Strk': '363',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.03',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '0',
#        'AskSize': '517'}]},
#     {'SymbolGroup': 'QQQ20240513364',
#      'Legs': [{'Sym': 'QQQ   240513C00364000',
#        'OptionType': 'C',
#        'Strk': '364',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '77.77',
#        'Ask': '78.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00364000',
#        'OptionType': 'P',
#        'Strk': '364',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '510'}]},
#     {'SymbolGroup': 'QQQ20240513365',
#      'Legs': [{'Sym': 'QQQ   240513C00365000',
#        'OptionType': 'C',
#        'Strk': '365',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '76.77',
#        'Ask': '77.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00365000',
#        'OptionType': 'P',
#        'Strk': '365',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '506'}]},
#     {'SymbolGroup': 'QQQ20240513366',
#      'Legs': [{'Sym': 'QQQ   240513C00366000',
#        'OptionType': 'C',
#        'Strk': '366',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '75.77',
#        'Ask': '76.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00366000',
#        'OptionType': 'P',
#        'Strk': '366',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '502'}]},
#     {'SymbolGroup': 'QQQ20240513367',
#      'Legs': [{'Sym': 'QQQ   240513C00367000',
#        'OptionType': 'C',
#        'Strk': '367',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '74.77',
#        'Ask': '75.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00367000',
#        'OptionType': 'P',
#        'Strk': '367',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '498'}]},
#     {'SymbolGroup': 'QQQ20240513368',
#      'Legs': [{'Sym': 'QQQ   240513C00368000',
#        'OptionType': 'C',
#        'Strk': '368',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '73.77',
#        'Ask': '74.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00368000',
#        'OptionType': 'P',
#        'Strk': '368',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '494'}]},
#     {'SymbolGroup': 'QQQ20240513369',
#      'Legs': [{'Sym': 'QQQ   240513C00369000',
#        'OptionType': 'C',
#        'Strk': '369',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '72.77',
#        'Ask': '73.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00369000',
#        'OptionType': 'P',
#        'Strk': '369',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '40',
#        'BidSize': '0',
#        'AskSize': '490'}]},
#     {'SymbolGroup': 'QQQ20240513370',
#      'Legs': [{'Sym': 'QQQ   240513C00370000',
#        'OptionType': 'C',
#        'Strk': '370',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '71.77',
#        'Ask': '72.16',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '2'},
#       {'Sym': 'QQQ   240513P00370000',
#        'OptionType': 'P',
#        'Strk': '370',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '30',
#        'BidSize': '0',
#        'AskSize': '486'}]},
#     {'SymbolGroup': 'QQQ20240513371',
#      'Legs': [{'Sym': 'QQQ   240513C00371000',
#        'OptionType': 'C',
#        'Strk': '371',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '70.77',
#        'Ask': '71.16',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '2'},
#       {'Sym': 'QQQ   240513P00371000',
#        'OptionType': 'P',
#        'Strk': '371',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '481'}]},
#     {'SymbolGroup': 'QQQ20240513372',
#      'Legs': [{'Sym': 'QQQ   240513C00372000',
#        'OptionType': 'C',
#        'Strk': '372',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '69.77',
#        'Ask': '70.16',
#        'Lst': '52.85',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '10',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00372000',
#        'OptionType': 'P',
#        'Strk': '372',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '477'}]},
#     {'SymbolGroup': 'QQQ20240513373',
#      'Legs': [{'Sym': 'QQQ   240513C00373000',
#        'OptionType': 'C',
#        'Strk': '373',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '68.77',
#        'Ask': '69.17',
#        'Lst': '70.15',
#        'Vol': '2',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00373000',
#        'OptionType': 'P',
#        'Strk': '373',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '473'}]},
#     {'SymbolGroup': 'QQQ20240513374',
#      'Legs': [{'Sym': 'QQQ   240513C00374000',
#        'OptionType': 'C',
#        'Strk': '374',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '67.77',
#        'Ask': '68.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00374000',
#        'OptionType': 'P',
#        'Strk': '374',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '20',
#        'BidSize': '0',
#        'AskSize': '468'}]},
#     {'SymbolGroup': 'QQQ20240513375',
#      'Legs': [{'Sym': 'QQQ   240513C00375000',
#        'OptionType': 'C',
#        'Strk': '375',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '66.77',
#        'Ask': '67.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00375000',
#        'OptionType': 'P',
#        'Strk': '375',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '40',
#        'BidSize': '0',
#        'AskSize': '1238'}]},
#     {'SymbolGroup': 'QQQ20240513376',
#      'Legs': [{'Sym': 'QQQ   240513C00376000',
#        'OptionType': 'C',
#        'Strk': '376',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '65.77',
#        'Ask': '66.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00376000',
#        'OptionType': 'P',
#        'Strk': '376',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '508'}]},
#     {'SymbolGroup': 'QQQ20240513377',
#      'Legs': [{'Sym': 'QQQ   240513C00377000',
#        'OptionType': 'C',
#        'Strk': '377',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '64.77',
#        'Ask': '65.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00377000',
#        'OptionType': 'P',
#        'Strk': '377',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '499'}]},
#     {'SymbolGroup': 'QQQ20240513378',
#      'Legs': [{'Sym': 'QQQ   240513C00378000',
#        'OptionType': 'C',
#        'Strk': '378',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '63.77',
#        'Ask': '64.17',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00378000',
#        'OptionType': 'P',
#        'Strk': '378',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '537'}]},
#     {'SymbolGroup': 'QQQ20240513379',
#      'Legs': [{'Sym': 'QQQ   240513C00379000',
#        'OptionType': 'C',
#        'Strk': '379',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '62.76',
#        'Ask': '63.18',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00379000',
#        'OptionType': 'P',
#        'Strk': '379',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '550'}]},
#     {'SymbolGroup': 'QQQ20240513380',
#      'Legs': [{'Sym': 'QQQ   240513C00380000',
#        'OptionType': 'C',
#        'Strk': '380',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '61.76',
#        'Ask': '62.19',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '10'},
#       {'Sym': 'QQQ   240513P00380000',
#        'OptionType': 'P',
#        'Strk': '380',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.14',
#        'Vol': '0',
#        'OI': '6',
#        'BidSize': '0',
#        'AskSize': '602'}]},
#     {'SymbolGroup': 'QQQ20240513381',
#      'Legs': [{'Sym': 'QQQ   240513C00381000',
#        'OptionType': 'C',
#        'Strk': '381',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '60.76',
#        'Ask': '61.19',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '2',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00381000',
#        'OptionType': 'P',
#        'Strk': '381',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '934'}]},
#     {'SymbolGroup': 'QQQ20240513382',
#      'Legs': [{'Sym': 'QQQ   240513C00382000',
#        'OptionType': 'C',
#        'Strk': '382',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '59.74',
#        'Ask': '60.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00382000',
#        'OptionType': 'P',
#        'Strk': '382',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '51',
#        'BidSize': '0',
#        'AskSize': '514'}]},
#     {'SymbolGroup': 'QQQ20240513383',
#      'Legs': [{'Sym': 'QQQ   240513C00383000',
#        'OptionType': 'C',
#        'Strk': '383',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '58.75',
#        'Ask': '59.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '2',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00383000',
#        'OptionType': 'P',
#        'Strk': '383',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '517'}]},
#     {'SymbolGroup': 'QQQ20240513384',
#      'Legs': [{'Sym': 'QQQ   240513C00384000',
#        'OptionType': 'C',
#        'Strk': '384',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '57.75',
#        'Ask': '58.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '2',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00384000',
#        'OptionType': 'P',
#        'Strk': '384',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '500'}]},
#     {'SymbolGroup': 'QQQ20240513385',
#      'Legs': [{'Sym': 'QQQ   240513C00385000',
#        'OptionType': 'C',
#        'Strk': '385',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '56.75',
#        'Ask': '57.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '2',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00385000',
#        'OptionType': 'P',
#        'Strk': '385',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '27',
#        'BidSize': '0',
#        'AskSize': '517'}]},
#     {'SymbolGroup': 'QQQ20240513386',
#      'Legs': [{'Sym': 'QQQ   240513C00386000',
#        'OptionType': 'C',
#        'Strk': '386',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '55.74',
#        'Ask': '56.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00386000',
#        'OptionType': 'P',
#        'Strk': '386',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '0',
#        'AskSize': '413'}]},
#     {'SymbolGroup': 'QQQ20240513387',
#      'Legs': [{'Sym': 'QQQ   240513C00387000',
#        'OptionType': 'C',
#        'Strk': '387',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '54.74',
#        'Ask': '55.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00387000',
#        'OptionType': 'P',
#        'Strk': '387',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.15',
#        'Vol': '0',
#        'OI': '2',
#        'BidSize': '0',
#        'AskSize': '572'}]},
#     {'SymbolGroup': 'QQQ20240513388',
#      'Legs': [{'Sym': 'QQQ   240513C00388000',
#        'OptionType': 'C',
#        'Strk': '388',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '53.74',
#        'Ask': '54.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00388000',
#        'OptionType': 'P',
#        'Strk': '388',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.03',
#        'Vol': '0',
#        'OI': '19',
#        'BidSize': '0',
#        'AskSize': '578'}]},
#     {'SymbolGroup': 'QQQ20240513389',
#      'Legs': [{'Sym': 'QQQ   240513C00389000',
#        'OptionType': 'C',
#        'Strk': '389',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '52.74',
#        'Ask': '53.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00389000',
#        'OptionType': 'P',
#        'Strk': '389',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.03',
#        'Vol': '0',
#        'OI': '80',
#        'BidSize': '0',
#        'AskSize': '515'}]},
#     {'SymbolGroup': 'QQQ20240513390',
#      'Legs': [{'Sym': 'QQQ   240513C00390000',
#        'OptionType': 'C',
#        'Strk': '390',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '51.74',
#        'Ask': '52.2',
#        'Lst': '49.19',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00390000',
#        'OptionType': 'P',
#        'Strk': '390',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.03',
#        'Vol': '0',
#        'OI': '106',
#        'BidSize': '0',
#        'AskSize': '429'}]},
#     {'SymbolGroup': 'QQQ20240513391',
#      'Legs': [{'Sym': 'QQQ   240513C00391000',
#        'OptionType': 'C',
#        'Strk': '391',
#        'Chg': '1.35',
#        'ChgPct': '2.65',
#        'Bid': '50.74',
#        'Ask': '51.2',
#        'Lst': '50.89',
#        'Vol': '2',
#        'OI': '2',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00391000',
#        'OptionType': 'P',
#        'Strk': '391',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '4',
#        'BidSize': '0',
#        'AskSize': '572'}]},
#     {'SymbolGroup': 'QQQ20240513392',
#      'Legs': [{'Sym': 'QQQ   240513C00392000',
#        'OptionType': 'C',
#        'Strk': '392',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '49.74',
#        'Ask': '50.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00392000',
#        'OptionType': 'P',
#        'Strk': '392',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '6',
#        'OI': '60',
#        'BidSize': '0',
#        'AskSize': '666'}]},
#     {'SymbolGroup': 'QQQ20240513393',
#      'Legs': [{'Sym': 'QQQ   240513C00393000',
#        'OptionType': 'C',
#        'Strk': '393',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '48.74',
#        'Ask': '49.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00393000',
#        'OptionType': 'P',
#        'Strk': '393',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.03',
#        'Vol': '0',
#        'OI': '4',
#        'BidSize': '0',
#        'AskSize': '513'}]},
#     {'SymbolGroup': 'QQQ20240513394',
#      'Legs': [{'Sym': 'QQQ   240513C00394000',
#        'OptionType': 'C',
#        'Strk': '394',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '47.74',
#        'Ask': '48.2',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00394000',
#        'OptionType': 'P',
#        'Strk': '394',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.3',
#        'Vol': '0',
#        'OI': '12',
#        'BidSize': '0',
#        'AskSize': '515'}]},
#     {'SymbolGroup': 'QQQ20240513395',
#      'Legs': [{'Sym': 'QQQ   240513C00395000',
#        'OptionType': 'C',
#        'Strk': '395',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '46.74',
#        'Ask': '47.21',
#        'Lst': '44.5',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00395000',
#        'OptionType': 'P',
#        'Strk': '395',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '94',
#        'BidSize': '0',
#        'AskSize': '508'}]},
#     {'SymbolGroup': 'QQQ20240513396',
#      'Legs': [{'Sym': 'QQQ   240513C00396000',
#        'OptionType': 'C',
#        'Strk': '396',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '45.75',
#        'Ask': '46.21',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '2',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00396000',
#        'OptionType': 'P',
#        'Strk': '396',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '14',
#        'OI': '25',
#        'BidSize': '0',
#        'AskSize': '645'}]},
#     {'SymbolGroup': 'QQQ20240513397',
#      'Legs': [{'Sym': 'QQQ   240513C00397000',
#        'OptionType': 'C',
#        'Strk': '397',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '44.75',
#        'Ask': '45.21',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '2',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00397000',
#        'OptionType': 'P',
#        'Strk': '397',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '273',
#        'BidSize': '0',
#        'AskSize': '608'}]},
#     {'SymbolGroup': 'QQQ20240513398',
#      'Legs': [{'Sym': 'QQQ   240513C00398000',
#        'OptionType': 'C',
#        'Strk': '398',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '43.74',
#        'Ask': '44.21',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00398000',
#        'OptionType': 'P',
#        'Strk': '398',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '0',
#        'OI': '211',
#        'BidSize': '0',
#        'AskSize': '425'}]},
#     {'SymbolGroup': 'QQQ20240513399',
#      'Legs': [{'Sym': 'QQQ   240513C00399000',
#        'OptionType': 'C',
#        'Strk': '399',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '42.74',
#        'Ask': '43.21',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00399000',
#        'OptionType': 'P',
#        'Strk': '399',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.04',
#        'Vol': '0',
#        'OI': '53',
#        'BidSize': '0',
#        'AskSize': '828'}]},
#     {'SymbolGroup': 'QQQ20240513400',
#      'Legs': [{'Sym': 'QQQ   240513C00400000',
#        'OptionType': 'C',
#        'Strk': '400',
#        'Chg': '1.42',
#        'ChgPct': '3.38',
#        'Bid': '41.75',
#        'Ask': '42.21',
#        'Lst': '42.07',
#        'Vol': '113',
#        'OI': '1',
#        'BidSize': '1',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00400000',
#        'OptionType': 'P',
#        'Strk': '400',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '244',
#        'BidSize': '0',
#        'AskSize': '862'}]},
#     {'SymbolGroup': 'QQQ20240513401',
#      'Legs': [{'Sym': 'QQQ   240513C00401000',
#        'OptionType': 'C',
#        'Strk': '401',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '40.75',
#        'Ask': '41.21',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '2',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00401000',
#        'OptionType': 'P',
#        'Strk': '401',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '248',
#        'BidSize': '0',
#        'AskSize': '393'}]},
#     {'SymbolGroup': 'QQQ20240513402',
#      'Legs': [{'Sym': 'QQQ   240513C00402000',
#        'OptionType': 'C',
#        'Strk': '402',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '39.75',
#        'Ask': '40.21',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '1',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00402000',
#        'OptionType': 'P',
#        'Strk': '402',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '458',
#        'BidSize': '0',
#        'AskSize': '898'}]},
#     {'SymbolGroup': 'QQQ20240513403',
#      'Legs': [{'Sym': 'QQQ   240513C00403000',
#        'OptionType': 'C',
#        'Strk': '403',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '38.75',
#        'Ask': '39.21',
#        'Lst': '39.07',
#        'Vol': '8',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00403000',
#        'OptionType': 'P',
#        'Strk': '403',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '0',
#        'OI': '594',
#        'BidSize': '0',
#        'AskSize': '348'}]},
#     {'SymbolGroup': 'QQQ20240513404',
#      'Legs': [{'Sym': 'QQQ   240513C00404000',
#        'OptionType': 'C',
#        'Strk': '404',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '37.75',
#        'Ask': '38.21',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '3',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00404000',
#        'OptionType': 'P',
#        'Strk': '404',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '120',
#        'OI': '105',
#        'BidSize': '0',
#        'AskSize': '337'}]},
#     {'SymbolGroup': 'QQQ20240513405',
#      'Legs': [{'Sym': 'QQQ   240513C00405000',
#        'OptionType': 'C',
#        'Strk': '405',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '36.76',
#        'Ask': '37.21',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '2',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   240513P00405000',
#        'OptionType': 'P',
#        'Strk': '405',
#        'Chg': '0.01',
#        'ChgPct': '50',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '3',
#        'OI': '82',
#        'BidSize': '0',
#        'AskSize': '329'}]},
#     {'SymbolGroup': 'QQQ20240513406',
#      'Legs': [{'Sym': 'QQQ   240513C00406000',
#        'OptionType': 'C',
#        'Strk': '406',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '35.76',
#        'Ask': '36.21',
#        'Lst': '17.89',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00406000',
#        'OptionType': 'P',
#        'Strk': '406',
#        'Chg': '0.01',
#        'ChgPct': '50',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.02',
#        'Vol': '42',
#        'OI': '264',
#        'BidSize': '0',
#        'AskSize': '322'}]},
#     {'SymbolGroup': 'QQQ20240513407',
#      'Legs': [{'Sym': 'QQQ   240513C00407000',
#        'OptionType': 'C',
#        'Strk': '407',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '34.76',
#        'Ask': '35.21',
#        'Lst': '17.24',
#        'Vol': '0',
#        'OI': '1',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00407000',
#        'OptionType': 'P',
#        'Strk': '407',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '483',
#        'OI': '108',
#        'BidSize': '0',
#        'AskSize': '374'}]},
#     {'SymbolGroup': 'QQQ20240513408',
#      'Legs': [{'Sym': 'QQQ   240513C00408000',
#        'OptionType': 'C',
#        'Strk': '408',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '33.75',
#        'Ask': '34.21',
#        'Lst': '32.71',
#        'Vol': '0',
#        'OI': '7',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00408000',
#        'OptionType': 'P',
#        'Strk': '408',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '439',
#        'OI': '661',
#        'BidSize': '0',
#        'AskSize': '349'}]},
#     {'SymbolGroup': 'QQQ20240513409',
#      'Legs': [{'Sym': 'QQQ   240513C00409000',
#        'OptionType': 'C',
#        'Strk': '409',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '32.75',
#        'Ask': '33.21',
#        'Lst': '16.1',
#        'Vol': '0',
#        'OI': '20',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00409000',
#        'OptionType': 'P',
#        'Strk': '409',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '335',
#        'OI': '11',
#        'BidSize': '0',
#        'AskSize': '327'}]},
#     {'SymbolGroup': 'QQQ20240513410',
#      'Legs': [{'Sym': 'QQQ   240513C00410000',
#        'OptionType': 'C',
#        'Strk': '410',
#        'Chg': '1.54',
#        'ChgPct': '4.76',
#        'Bid': '31.75',
#        'Ask': '32.21',
#        'Lst': '32.36',
#        'Vol': '9',
#        'OI': '2',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00410000',
#        'OptionType': 'P',
#        'Strk': '410',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '53',
#        'OI': '489',
#        'BidSize': '0',
#        'AskSize': '371'}]},
#     {'SymbolGroup': 'QQQ20240513411',
#      'Legs': [{'Sym': 'QQQ   240513C00411000',
#        'OptionType': 'C',
#        'Strk': '411',
#        'Chg': '3.36',
#        'ChgPct': '10.27',
#        'Bid': '30.75',
#        'Ask': '31.21',
#        'Lst': '32.72',
#        'Vol': '1',
#        'OI': '42',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00411000',
#        'OptionType': 'P',
#        'Strk': '411',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '242',
#        'OI': '408',
#        'BidSize': '0',
#        'AskSize': '403'}]},
#     {'SymbolGroup': 'QQQ20240513412',
#      'Legs': [{'Sym': 'QQQ   240513C00412000',
#        'OptionType': 'C',
#        'Strk': '412',
#        'Chg': '2.14',
#        'ChgPct': '7.21',
#        'Bid': '29.75',
#        'Ask': '30.21',
#        'Lst': '29.67',
#        'Vol': '2',
#        'OI': '24',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00412000',
#        'OptionType': 'P',
#        'Strk': '412',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '559',
#        'OI': '98',
#        'BidSize': '0',
#        'AskSize': '398'}]},
#     {'SymbolGroup': 'QQQ20240513413',
#      'Legs': [{'Sym': 'QQQ   240513C00413000',
#        'OptionType': 'C',
#        'Strk': '413',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '28.75',
#        'Ask': '29.21',
#        'Lst': '26.1',
#        'Vol': '0',
#        'OI': '22',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00413000',
#        'OptionType': 'P',
#        'Strk': '413',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '203',
#        'OI': '523',
#        'BidSize': '0',
#        'AskSize': '683'}]},
#     {'SymbolGroup': 'QQQ20240513414',
#      'Legs': [{'Sym': 'QQQ   240513C00414000',
#        'OptionType': 'C',
#        'Strk': '414',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '27.75',
#        'Ask': '28.21',
#        'Lst': '25.53',
#        'Vol': '0',
#        'OI': '60',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00414000',
#        'OptionType': 'P',
#        'Strk': '414',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.01',
#        'Lst': '0.01',
#        'Vol': '92',
#        'OI': '616',
#        'BidSize': '0',
#        'AskSize': '414'}]},
#     {'SymbolGroup': 'QQQ20240513415',
#      'Legs': [{'Sym': 'QQQ   240513C00415000',
#        'OptionType': 'C',
#        'Strk': '415',
#        'Chg': '1.52',
#        'ChgPct': '5.56',
#        'Bid': '26.75',
#        'Ask': '27.21',
#        'Lst': '27.36',
#        'Vol': '9',
#        'OI': '35',
#        'BidSize': '2',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00415000',
#        'OptionType': 'P',
#        'Strk': '415',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '26',
#        'OI': '462',
#        'BidSize': '0',
#        'AskSize': '986'}]},
#     {'SymbolGroup': 'QQQ20240513416',
#      'Legs': [{'Sym': 'QQQ   240513C00416000',
#        'OptionType': 'C',
#        'Strk': '416',
#        'Chg': '0.85',
#        'ChgPct': '3.27',
#        'Bid': '25.75',
#        'Ask': '26.21',
#        'Lst': '26',
#        'Vol': '4',
#        'OI': '68',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00416000',
#        'OptionType': 'P',
#        'Strk': '416',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '1651',
#        'OI': '171',
#        'BidSize': '0',
#        'AskSize': '1144'}]},
#     {'SymbolGroup': 'QQQ20240513417',
#      'Legs': [{'Sym': 'QQQ   240513C00417000',
#        'OptionType': 'C',
#        'Strk': '417',
#        'Chg': '2.54',
#        'ChgPct': '10.14',
#        'Bid': '24.75',
#        'Ask': '25.21',
#        'Lst': '25.05',
#        'Vol': '9',
#        'OI': '14',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00417000',
#        'OptionType': 'P',
#        'Strk': '417',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '1159',
#        'OI': '210',
#        'BidSize': '0',
#        'AskSize': '1258'}]},
#     {'SymbolGroup': 'QQQ20240513418',
#      'Legs': [{'Sym': 'QQQ   240513C00418000',
#        'OptionType': 'C',
#        'Strk': '418',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '23.76',
#        'Ask': '24.21',
#        'Lst': '11.46',
#        'Vol': '0',
#        'OI': '43',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00418000',
#        'OptionType': 'P',
#        'Strk': '418',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '1785',
#        'OI': '495',
#        'BidSize': '0',
#        'AskSize': '821'}]},
#     {'SymbolGroup': 'QQQ20240513419',
#      'Legs': [{'Sym': 'QQQ   240513C00419000',
#        'OptionType': 'C',
#        'Strk': '419',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '22.75',
#        'Ask': '23.2',
#        'Lst': '17.7',
#        'Vol': '0',
#        'OI': '49',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00419000',
#        'OptionType': 'P',
#        'Strk': '419',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.02',
#        'Vol': '2124',
#        'OI': '706',
#        'BidSize': '5',
#        'AskSize': '1288'}]},
#     {'SymbolGroup': 'QQQ20240513420',
#      'Legs': [{'Sym': 'QQQ   240513C00420000',
#        'OptionType': 'C',
#        'Strk': '420',
#        'Chg': '1.2',
#        'ChgPct': '5.44',
#        'Bid': '21.75',
#        'Ask': '22.2',
#        'Lst': '22.07',
#        'Vol': '19',
#        'OI': '38',
#        'BidSize': '10',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00420000',
#        'OptionType': 'P',
#        'Strk': '420',
#        'Chg': '0.01',
#        'ChgPct': '50',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.02',
#        'Vol': '506',
#        'OI': '1005',
#        'BidSize': '2',
#        'AskSize': '1383'}]},
#     {'SymbolGroup': 'QQQ20240513421',
#      'Legs': [{'Sym': 'QQQ   240513C00421000',
#        'OptionType': 'C',
#        'Strk': '421',
#        'Chg': '-0.08',
#        'ChgPct': '-0.4',
#        'Bid': '20.76',
#        'Ask': '21.2',
#        'Lst': '20.04',
#        'Vol': '3',
#        'OI': '74',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00421000',
#        'OptionType': 'P',
#        'Strk': '421',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '3',
#        'OI': '326',
#        'BidSize': '1',
#        'AskSize': '864'}]},
#     {'SymbolGroup': 'QQQ20240513422',
#      'Legs': [{'Sym': 'QQQ   240513C00422000',
#        'OptionType': 'C',
#        'Strk': '422',
#        'Chg': '3.17',
#        'ChgPct': '14.64',
#        'Bid': '19.76',
#        'Ask': '20.2',
#        'Lst': '21.66',
#        'Vol': '4',
#        'OI': '176',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00422000',
#        'OptionType': 'P',
#        'Strk': '422',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '4646',
#        'OI': '271',
#        'BidSize': '39',
#        'AskSize': '853'}]},
#     {'SymbolGroup': 'QQQ20240513423',
#      'Legs': [{'Sym': 'QQQ   240513C00423000',
#        'OptionType': 'C',
#        'Strk': '423',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '18.77',
#        'Ask': '19.2',
#        'Lst': '15.49',
#        'Vol': '0',
#        'OI': '96',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00423000',
#        'OptionType': 'P',
#        'Strk': '423',
#        'Chg': '-0.01',
#        'ChgPct': '-100',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '30',
#        'OI': '477',
#        'BidSize': '121',
#        'AskSize': '847'}]},
#     {'SymbolGroup': 'QQQ20240513424',
#      'Legs': [{'Sym': 'QQQ   240513C00424000',
#        'OptionType': 'C',
#        'Strk': '424',
#        'Chg': '1.28',
#        'ChgPct': '7.17',
#        'Bid': '17.77',
#        'Ask': '18.2',
#        'Lst': '17.85',
#        'Vol': '23',
#        'OI': '74',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00424000',
#        'OptionType': 'P',
#        'Strk': '424',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.02',
#        'Vol': '3401',
#        'OI': '583',
#        'BidSize': '723',
#        'AskSize': '825'}]},
#     {'SymbolGroup': 'QQQ20240513425',
#      'Legs': [{'Sym': 'QQQ   240513C00425000',
#        'OptionType': 'C',
#        'Strk': '425',
#        'Chg': '1.09',
#        'ChgPct': '6.33',
#        'Bid': '16.76',
#        'Ask': '17.2',
#        'Lst': '17.23',
#        'Vol': '27',
#        'OI': '527',
#        'BidSize': '10',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00425000',
#        'OptionType': 'P',
#        'Strk': '425',
#        'Chg': '-0.02',
#        'ChgPct': '-200',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '315',
#        'OI': '1135',
#        'BidSize': '25',
#        'AskSize': '824'}]},
#     {'SymbolGroup': 'QQQ20240513426',
#      'Legs': [{'Sym': 'QQQ   240513C00426000',
#        'OptionType': 'C',
#        'Strk': '426',
#        'Chg': '0.82',
#        'ChgPct': '5.13',
#        'Bid': '15.76',
#        'Ask': '16.2',
#        'Lst': '15.97',
#        'Vol': '73',
#        'OI': '84',
#        'BidSize': '10',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00426000',
#        'OptionType': 'P',
#        'Strk': '426',
#        'Chg': '-0.01',
#        'ChgPct': '-50',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.02',
#        'Vol': '2432',
#        'OI': '1551',
#        'BidSize': '265',
#        'AskSize': '1156'}]},
#     {'SymbolGroup': 'QQQ20240513427',
#      'Legs': [{'Sym': 'QQQ   240513C00427000',
#        'OptionType': 'C',
#        'Strk': '427',
#        'Chg': '1.58',
#        'ChgPct': '10.25',
#        'Bid': '14.77',
#        'Ask': '15.2',
#        'Lst': '15.41',
#        'Vol': '24',
#        'OI': '252',
#        'BidSize': '10',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00427000',
#        'OptionType': 'P',
#        'Strk': '427',
#        'Chg': '-0.03',
#        'ChgPct': '-300',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '386',
#        'OI': '2602',
#        'BidSize': '331',
#        'AskSize': '956'}]},
#     {'SymbolGroup': 'QQQ20240513428',
#      'Legs': [{'Sym': 'QQQ   240513C00428000',
#        'OptionType': 'C',
#        'Strk': '428',
#        'Chg': '0.84',
#        'ChgPct': '6',
#        'Bid': '13.76',
#        'Ask': '14.2',
#        'Lst': '14',
#        'Vol': '194',
#        'OI': '482',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00428000',
#        'OptionType': 'P',
#        'Strk': '428',
#        'Chg': '-0.01',
#        'ChgPct': '-50',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.02',
#        'Vol': '1679',
#        'OI': '3859',
#        'BidSize': '224',
#        'AskSize': '982'}]},
#     {'SymbolGroup': 'QQQ20240513429',
#      'Legs': [{'Sym': 'QQQ   240513C00429000',
#        'OptionType': 'C',
#        'Strk': '429',
#        'Chg': '1.05',
#        'ChgPct': '8.06',
#        'Bid': '12.77',
#        'Ask': '13.2',
#        'Lst': '13.03',
#        'Vol': '25',
#        'OI': '353',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00429000',
#        'OptionType': 'P',
#        'Strk': '429',
#        'Chg': '-0.02',
#        'ChgPct': '-100',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.02',
#        'Vol': '7262',
#        'OI': '874',
#        'BidSize': '622',
#        'AskSize': '883'}]},
#     {'SymbolGroup': 'QQQ20240513430',
#      'Legs': [{'Sym': 'QQQ   240513C00430000',
#        'OptionType': 'C',
#        'Strk': '430',
#        'Chg': '0.97',
#        'ChgPct': '8.1',
#        'Bid': '11.77',
#        'Ask': '12.21',
#        'Lst': '11.97',
#        'Vol': '121',
#        'OI': '341',
#        'BidSize': '1',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   240513P00430000',
#        'OptionType': 'P',
#        'Strk': '430',
#        'Chg': '-0.05',
#        'ChgPct': '-500',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.01',
#        'Vol': '4930',
#        'OI': '4242',
#        'BidSize': '1045',
#        'AskSize': '626'}]},
#     {'SymbolGroup': 'QQQ20240513431',
#      'Legs': [{'Sym': 'QQQ   240513C00431000',
#        'OptionType': 'C',
#        'Strk': '431',
#        'Chg': '1.04',
#        'ChgPct': '9.41',
#        'Bid': '10.93',
#        'Ask': '11.07',
#        'Lst': '11.05',
#        'Vol': '202',
#        'OI': '603',
#        'BidSize': '2',
#        'AskSize': '4'},
#       {'Sym': 'QQQ   240513P00431000',
#        'OptionType': 'P',
#        'Strk': '431',
#        'Chg': '-0.05',
#        'ChgPct': '-250',
#        'Bid': '0.01',
#        'Ask': '0.02',
#        'Lst': '0.02',
#        'Vol': '1224',
#        'OI': '1196',
#        'BidSize': '645',
#        'AskSize': '407'}]},
#     {'SymbolGroup': 'QQQ20240513432',
#      'Legs': [{'Sym': 'QQQ   240513C00432000',
#        'OptionType': 'C',
#        'Strk': '432',
#        'Chg': '1.05',
#        'ChgPct': '10.43',
#        'Bid': '9.94',
#        'Ask': '10.08',
#        'Lst': '10.07',
#        'Vol': '378',
#        'OI': '166',
#        'BidSize': '3',
#        'AskSize': '6'},
#       {'Sym': 'QQQ   240513P00432000',
#        'OptionType': 'P',
#        'Strk': '432',
#        'Chg': '-0.08',
#        'ChgPct': '-400',
#        'Bid': '0.02',
#        'Ask': '0.03',
#        'Lst': '0.02',
#        'Vol': '2530',
#        'OI': '974',
#        'BidSize': '1145',
#        'AskSize': '1447'}]},
#     {'SymbolGroup': 'QQQ20240513433',
#      'Legs': [{'Sym': 'QQQ   240513C00433000',
#        'OptionType': 'C',
#        'Strk': '433',
#        'Chg': '0.96',
#        'ChgPct': '10.65',
#        'Bid': '8.94',
#        'Ask': '9.07',
#        'Lst': '9.01',
#        'Vol': '216',
#        'OI': '607',
#        'BidSize': '3',
#        'AskSize': '4'},
#       {'Sym': 'QQQ   240513P00433000',
#        'OptionType': 'P',
#        'Strk': '433',
#        'Chg': '-0.12',
#        'ChgPct': '-600',
#        'Bid': '0.02',
#        'Ask': '0.03',
#        'Lst': '0.02',
#        'Vol': '2884',
#        'OI': '1610',
#        'BidSize': '864',
#        'AskSize': '396'}]},
#     {'SymbolGroup': 'QQQ20240513434',
#      'Legs': [{'Sym': 'QQQ   240513C00434000',
#        'OptionType': 'C',
#        'Strk': '434',
#        'Chg': '0.95',
#        'ChgPct': '11.83',
#        'Bid': '7.96',
#        'Ask': '8.09',
#        'Lst': '8.03',
#        'Vol': '244',
#        'OI': '447',
#        'BidSize': '4',
#        'AskSize': '4'},
#       {'Sym': 'QQQ   240513P00434000',
#        'OptionType': 'P',
#        'Strk': '434',
#        'Chg': '-0.14',
#        'ChgPct': '-350',
#        'Bid': '0.03',
#        'Ask': '0.04',
#        'Lst': '0.04',
#        'Vol': '9178',
#        'OI': '1703',
#        'BidSize': '1048',
#        'AskSize': '148'}]},
#     {'SymbolGroup': 'QQQ20240513435',
#      'Legs': [{'Sym': 'QQQ   240513C00435000',
#        'OptionType': 'C',
#        'Strk': '435',
#        'Chg': '0.77',
#        'ChgPct': '10.85',
#        'Bid': '6.97',
#        'Ask': '7.11',
#        'Lst': '7.1',
#        'Vol': '367',
#        'OI': '914',
#        'BidSize': '1',
#        'AskSize': '8'},
#       {'Sym': 'QQQ   240513P00435000',
#        'OptionType': 'P',
#        'Strk': '435',
#        'Chg': '-0.2',
#        'ChgPct': '-333.33',
#        'Bid': '0.06',
#        'Ask': '0.07',
#        'Lst': '0.06',
#        'Vol': '8293',
#        'OI': '3099',
#        'BidSize': '1',
#        'AskSize': '971'}]},
#     {'SymbolGroup': 'QQQ20240513436',
#      'Legs': [{'Sym': 'QQQ   240513C00436000',
#        'OptionType': 'C',
#        'Strk': '436',
#        'Chg': '0.03',
#        'ChgPct': '0.49',
#        'Bid': '5.92',
# ...
#        'BidSize': '62',
#        'AskSize': '62'},
#       {'Sym': 'QQQ   261218P00554780',
#        'OptionType': 'P',
#        'Strk': '554.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '110.5',
#        'Ask': '115.37',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218559.78',
#      'Legs': [{'Sym': 'QQQ   261218C00559780',
#        'OptionType': 'C',
#        'Strk': '559.78',
#        'Chg': '0.75',
#        'ChgPct': '2.34',
#        'Bid': '31',
#        'Ask': '34.03',
#        'Lst': '32',
#        'Vol': '2',
#        'OI': '22',
#        'BidSize': '1',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00559780',
#        'OptionType': 'P',
#        'Strk': '559.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '115.5',
#        'Ask': '120.35',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218560',
#      'Legs': [{'Sym': 'QQQ   261218C00560000',
#        'OptionType': 'C',
#        'Strk': '560',
#        'Chg': '0.82',
#        'ChgPct': '2.59',
#        'Bid': '29.5',
#        'Ask': '34.5',
#        'Lst': '31.7',
#        'Vol': '4',
#        'OI': '79',
#        'BidSize': '62',
#        'AskSize': '62'},
#       {'Sym': 'QQQ   261218P00560000',
#        'OptionType': 'P',
#        'Strk': '560',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '115.58',
#        'Ask': '120.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218564.78',
#      'Legs': [{'Sym': 'QQQ   261218C00564780',
#        'OptionType': 'C',
#        'Strk': '564.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '28',
#        'Ask': '32.59',
#        'Lst': '33.02',
#        'Vol': '0',
#        'OI': '4',
#        'BidSize': '62',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00564780',
#        'OptionType': 'P',
#        'Strk': '564.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '120.5',
#        'Ask': '125.35',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218569.78',
#      'Legs': [{'Sym': 'QQQ   261218C00569780',
#        'OptionType': 'C',
#        'Strk': '569.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '27',
#        'Ask': '31.5',
#        'Lst': '29.79',
#        'Vol': '0',
#        'OI': '5',
#        'BidSize': '61',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00569780',
#        'OptionType': 'P',
#        'Strk': '569.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '125.5',
#        'Ask': '130.35',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218570',
#      'Legs': [{'Sym': 'QQQ   261218C00570000',
#        'OptionType': 'C',
#        'Strk': '570',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '26.5',
#        'Ask': '31.13',
#        'Lst': '26.74',
#        'Vol': '0',
#        'OI': '40',
#        'BidSize': '62',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00570000',
#        'OptionType': 'P',
#        'Strk': '570',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '125.58',
#        'Ask': '130.5',
#        'Lst': '130.5',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218574.78',
#      'Legs': [{'Sym': 'QQQ   261218C00574780',
#        'OptionType': 'C',
#        'Strk': '574.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '25.5',
#        'Ask': '29.84',
#        'Lst': '23.7',
#        'Vol': '0',
#        'OI': '6',
#        'BidSize': '62',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00574780',
#        'OptionType': 'P',
#        'Strk': '574.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '130.5',
#        'Ask': '135.35',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218579.78',
#      'Legs': [{'Sym': 'QQQ   261218C00579780',
#        'OptionType': 'C',
#        'Strk': '579.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '24',
#        'Ask': '29',
#        'Lst': '26.58',
#        'Vol': '0',
#        'OI': '16',
#        'BidSize': '62',
#        'AskSize': '62'},
#       {'Sym': 'QQQ   261218P00579780',
#        'OptionType': 'P',
#        'Strk': '579.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '135.5',
#        'Ask': '140.35',
#        'Lst': '136.05',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218584.78',
#      'Legs': [{'Sym': 'QQQ   261218C00584780',
#        'OptionType': 'C',
#        'Strk': '584.78',
#        'Chg': '1.6',
#        'ChgPct': '6.43',
#        'Bid': '23',
#        'Ask': '28',
#        'Lst': '24.89',
#        'Vol': '1',
#        'OI': '1534',
#        'BidSize': '62',
#        'AskSize': '62'},
#       {'Sym': 'QQQ   261218P00584780',
#        'OptionType': 'P',
#        'Strk': '584.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '140.5',
#        'Ask': '145.35',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218589.78',
#      'Legs': [{'Sym': 'QQQ   261218C00589780',
#        'OptionType': 'C',
#        'Strk': '589.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '21.5',
#        'Ask': '26.5',
#        'Lst': '23',
#        'Vol': '0',
#        'OI': '8',
#        'BidSize': '62',
#        'AskSize': '62'},
#       {'Sym': 'QQQ   261218P00589780',
#        'OptionType': 'P',
#        'Strk': '589.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '145.5',
#        'Ask': '150.35',
#        'Lst': '171.94',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218594.78',
#      'Legs': [{'Sym': 'QQQ   261218C00594780',
#        'OptionType': 'C',
#        'Strk': '594.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '20.5',
#        'Ask': '25.5',
#        'Lst': '25.46',
#        'Vol': '0',
#        'OI': '54',
#        'BidSize': '62',
#        'AskSize': '62'},
#       {'Sym': 'QQQ   261218P00594780',
#        'OptionType': 'P',
#        'Strk': '594.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '150.5',
#        'Ask': '155.35',
#        'Lst': '157.1',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218599.78',
#      'Legs': [{'Sym': 'QQQ   261218C00599780',
#        'OptionType': 'C',
#        'Strk': '599.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '19.5',
#        'Ask': '24.5',
#        'Lst': '20.77',
#        'Vol': '0',
#        'OI': '80',
#        'BidSize': '62',
#        'AskSize': '62'},
#       {'Sym': 'QQQ   261218P00599780',
#        'OptionType': 'P',
#        'Strk': '599.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '155.5',
#        'Ask': '160.35',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218604.78',
#      'Legs': [{'Sym': 'QQQ   261218C00604780',
#        'OptionType': 'C',
#        'Strk': '604.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '18.5',
#        'Ask': '23',
#        'Lst': '19.84',
#        'Vol': '0',
#        'OI': '6',
#        'BidSize': '61',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00604780',
#        'OptionType': 'P',
#        'Strk': '604.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '160.5',
#        'Ask': '165.35',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218609.78',
#      'Legs': [{'Sym': 'QQQ   261218C00609780',
#        'OptionType': 'C',
#        'Strk': '609.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '17.5',
#        'Ask': '22',
#        'Lst': '23.06',
#        'Vol': '0',
#        'OI': '31',
#        'BidSize': '61',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00609780',
#        'OptionType': 'P',
#        'Strk': '609.78',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '165.5',
#        'Ask': '170.35',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '20',
#        'AskSize': '10'}]},
#     {'SymbolGroup': 'QQQ20261218615',
#      'Legs': [{'Sym': 'QQQ   261218C00615000',
#        'OptionType': 'C',
#        'Strk': '615',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '16.2',
#        'Ask': '20.82',
#        'Lst': '14.75',
#        'Vol': '0',
#        'OI': '882',
#        'BidSize': '12',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00615000',
#        'OptionType': 'P',
#        'Strk': '615',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '170.57',
#        'Ask': '175.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218620',
#      'Legs': [{'Sym': 'QQQ   261218C00620000',
#        'OptionType': 'C',
#        'Strk': '620',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '15.5',
#        'Ask': '19.56',
#        'Lst': '16.53',
#        'Vol': '0',
#        'OI': '26',
#        'BidSize': '61',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   261218P00620000',
#        'OptionType': 'P',
#        'Strk': '620',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '175.57',
#        'Ask': '180.5',
#        'Lst': '174',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218625',
#      'Legs': [{'Sym': 'QQQ   261218C00625000',
#        'OptionType': 'C',
#        'Strk': '625',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '14.5',
#        'Ask': '18.69',
#        'Lst': '14.4',
#        'Vol': '0',
#        'OI': '9',
#        'BidSize': '62',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   261218P00625000',
#        'OptionType': 'P',
#        'Strk': '625',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '180.57',
#        'Ask': '185.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218630',
#      'Legs': [{'Sym': 'QQQ   261218C00630000',
#        'OptionType': 'C',
#        'Strk': '630',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '13.5',
#        'Ask': '16.56',
#        'Lst': '13.7',
#        'Vol': '0',
#        'OI': '12',
#        'BidSize': '62',
#        'AskSize': '3'},
#       {'Sym': 'QQQ   261218P00630000',
#        'OptionType': 'P',
#        'Strk': '630',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '185.57',
#        'Ask': '190.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218635',
#      'Legs': [{'Sym': 'QQQ   261218C00635000',
#        'OptionType': 'C',
#        'Strk': '635',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '12.5',
#        'Ask': '17.5',
#        'Lst': '14.7',
#        'Vol': '0',
#        'OI': '148',
#        'BidSize': '62',
#        'AskSize': '62'},
#       {'Sym': 'QQQ   261218P00635000',
#        'OptionType': 'P',
#        'Strk': '635',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '190.57',
#        'Ask': '195.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218640',
#      'Legs': [{'Sym': 'QQQ   261218C00640000',
#        'OptionType': 'C',
#        'Strk': '640',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '12',
#        'Ask': '17',
#        'Lst': '13.33',
#        'Vol': '0',
#        'OI': '186',
#        'BidSize': '62',
#        'AskSize': '62'},
#       {'Sym': 'QQQ   261218P00640000',
#        'OptionType': 'P',
#        'Strk': '640',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '195.57',
#        'Ask': '200.5',
#        'Lst': '219.46',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218645',
#      'Legs': [{'Sym': 'QQQ   261218C00645000',
#        'OptionType': 'C',
#        'Strk': '645',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '11',
#        'Ask': '16',
#        'Lst': '12.7',
#        'Vol': '0',
#        'OI': '42',
#        'BidSize': '62',
#        'AskSize': '62'},
#       {'Sym': 'QQQ   261218P00645000',
#        'OptionType': 'P',
#        'Strk': '645',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '200.57',
#        'Ask': '205.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218650',
#      'Legs': [{'Sym': 'QQQ   261218C00650000',
#        'OptionType': 'C',
#        'Strk': '650',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '10.5',
#        'Ask': '13.5',
#        'Lst': '12.35',
#        'Vol': '0',
#        'OI': '121',
#        'BidSize': '62',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   261218P00650000',
#        'OptionType': 'P',
#        'Strk': '650',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '205.57',
#        'Ask': '210.5',
#        'Lst': '203.61',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218655',
#      'Legs': [{'Sym': 'QQQ   261218C00655000',
#        'OptionType': 'C',
#        'Strk': '655',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '10',
#        'Ask': '14.5',
#        'Lst': '12',
#        'Vol': '0',
#        'OI': '98',
#        'BidSize': '61',
#        'AskSize': '61'},
#       {'Sym': 'QQQ   261218P00655000',
#        'OptionType': 'P',
#        'Strk': '655',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '210.57',
#        'Ask': '215.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218660',
#      'Legs': [{'Sym': 'QQQ   261218C00660000',
#        'OptionType': 'C',
#        'Strk': '660',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '9.04',
#        'Ask': '14',
#        'Lst': '11.3',
#        'Vol': '0',
#        'OI': '4',
#        'BidSize': '60',
#        'AskSize': '68'},
#       {'Sym': 'QQQ   261218P00660000',
#        'OptionType': 'P',
#        'Strk': '660',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '215.57',
#        'Ask': '220.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218665',
#      'Legs': [{'Sym': 'QQQ   261218C00665000',
#        'OptionType': 'C',
#        'Strk': '665',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '8.54',
#        'Ask': '13.32',
#        'Lst': '10.78',
#        'Vol': '0',
#        'OI': '11',
#        'BidSize': '60',
#        'AskSize': '60'},
#       {'Sym': 'QQQ   261218P00665000',
#        'OptionType': 'P',
#        'Strk': '665',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '220.57',
#        'Ask': '225.5',
#        'Lst': '0',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]},
#     {'SymbolGroup': 'QQQ20261218670',
#      'Legs': [{'Sym': 'QQQ   261218C00670000',
#        'OptionType': 'C',
#        'Strk': '670',
#        'Chg': '-0.04',
#        'ChgPct': '-0.4',
#        'Bid': '10.08',
#        'Ask': '11',
#        'Lst': '10.1',
#        'Vol': '3',
#        'OI': '616',
#        'BidSize': '8',
#        'AskSize': '1'},
#       {'Sym': 'QQQ   261218P00670000',
#        'OptionType': 'P',
#        'Strk': '670',
#        'Chg': '0',
#        'ChgPct': '0',
#        'Bid': '225.57',
#        'Ask': '230.5',
#        'Lst': '238.89',
#        'Vol': '0',
#        'OI': '0',
#        'BidSize': '10',
#        'AskSize': '20'}]}]}],
#  'CurrentDateTime': '07:32:33 PM ET, 05/11/2024',
#  'InterestRate': '0.05243',
#  'IsDelayed': False,
#  'IsPartialData': False,
#  'ContractSpecs': {'UnderlyingType': 'ETF',
#   'ExerStyle': 'American',
#   'SetType': 'PM',
#   'Multi': '100',
#   'Deliverable': '100 QQQ',
#   'Cash': ''},
#  'Provider': 'SchwabMDS'}

# %%
data = []
underlying_last = float(options_chains_data["UnderlyingData"]["Last"])

for expiration in options_chains_data["Expirations"]:
    days_until_expiration = expiration["ExpirationGroup"]["DaysUntil"]
    expiration_month_day = expiration["ExpirationGroup"]["MonthAndDay"].split(" ")
    expiration_month = expiration_month_day[0]
    expiration_day = expiration_month_day[1]
    expiration_year = expiration["ExpirationGroup"]["Year"]
    expiration_date = datetime.strptime(f"{expiration_month} {expiration_day} {expiration_year}", "%b %d %Y")

    for chain in expiration["Chains"]:
        data_obj = {}
        data_obj["OPTION_ID"] = chain["SymbolGroup"]
        data_obj["UNDERLYING_LAST"] = underlying_last
        data_obj["EXPIRE_DATE"] = expiration_date
        data_obj["DTE"] = days_until_expiration

        for leg in chain["Legs"]:
            data_obj["STRIKE"] = float(leg["Strk"])
            data_obj["STRIKE_DISTANCE"] = abs(data_obj["STRIKE"] - underlying_last)
            data_obj["STRIKE_DISTANCE_PCT"] = data_obj["STRIKE_DISTANCE"] / underlying_last
            leg_prefix = leg["OptionType"] + "_"
            data_obj[leg_prefix + "ID"] = leg["Sym"]
            data_obj[leg_prefix + "BID"] = float(leg["Bid"])
            data_obj[leg_prefix + "ASK"] = float(leg["Ask"])
            data_obj[leg_prefix + "VOLUME"] = int(leg["Vol"])

        data.append(data_obj)

df_options_chains = pd.DataFrame(data=data)
df_options_chains
# Out:
#            OPTION_ID  UNDERLYING_LAST EXPIRE_DATE  DTE  STRIKE  \
# 0     QQQ20240513359           442.06  2024-05-13    2   359.0
# 1     QQQ20240513360           442.06  2024-05-13    2   360.0
# 2     QQQ20240513361           442.06  2024-05-13    2   361.0
# 3     QQQ20240513362           442.06  2024-05-13    2   362.0
# 4     QQQ20240513363           442.06  2024-05-13    2   363.0
# ...              ...              ...         ...  ...     ...
# 4143  QQQ20261218650           442.06  2026-12-18  951   650.0
# 4144  QQQ20261218655           442.06  2026-12-18  951   655.0
# 4145  QQQ20261218660           442.06  2026-12-18  951   660.0
# 4146  QQQ20261218665           442.06  2026-12-18  951   665.0
# 4147  QQQ20261218670           442.06  2026-12-18  951   670.0
#
#       STRIKE_DISTANCE  STRIKE_DISTANCE_PCT                   C_ID  C_BID  \
# 0               83.06             0.187893  QQQ   240513C00359000  82.77
# 1               82.06             0.185631  QQQ   240513C00360000  81.77
# 2               81.06             0.183369  QQQ   240513C00361000  80.77
# 3               80.06             0.181107  QQQ   240513C00362000  79.77
# 4               79.06             0.178845  QQQ   240513C00363000  78.77
# ...               ...                  ...                    ...    ...
# 4143           207.94             0.470389  QQQ   261218C00650000  10.50
# 4144           212.94             0.481699  QQQ   261218C00655000  10.00
# 4145           217.94             0.493010  QQQ   261218C00660000   9.04
# 4146           222.94             0.504321  QQQ   261218C00665000   8.54
# 4147           227.94             0.515631  QQQ   261218C00670000  10.08
#
#       C_ASK  C_VOLUME                   P_ID   P_BID   P_ASK  P_VOLUME
# 0     83.16         0  QQQ   240513P00359000    0.00    0.01        26
# 1     82.17         4  QQQ   240513P00360000    0.00    0.01         0
# 2     81.17         0  QQQ   240513P00361000    0.00    0.01         0
# 3     80.17         0  QQQ   240513P00362000    0.00    0.01         0
# 4     79.17         0  QQQ   240513P00363000    0.00    0.01         0
# ...     ...       ...                    ...     ...     ...       ...
# 4143  13.50         0  QQQ   261218P00650000  205.57  210.50         0
# 4144  14.50         0  QQQ   261218P00655000  210.57  215.50         0
# 4145  14.00         0  QQQ   261218P00660000  215.57  220.50         0
# 4146  13.32         0  QQQ   261218P00665000  220.57  225.50         0
# 4147  11.00         3  QQQ   261218P00670000  225.57  230.50         0
#
# [4148 rows x 15 columns]

# %%
from invaas.schwab.cnn_fear_greed_index import get_historical_cnn_fear_greed_index


def get_fear_greed_index_data():
    historical_period = 14
    df = pd.DataFrame(data=get_historical_cnn_fear_greed_index()["data"])
    df.set_index(
        pd.DatetimeIndex([pd.Timestamp(x, unit="ms", tz="UTC") for x in df.x]),
        inplace=True,
    )
    df.rename(columns={"y": "fear_greed_index"}, inplace=True)
    df.sort_index(inplace=True)
    df["fear_greed_index"] = df.fear_greed_index.fillna(method="ffill").astype(float)
    df["previous_max_fear_greed_index"] = (
        df["fear_greed_index"].rolling(window=historical_period, min_periods=historical_period).max()
    )
    df["previous_min_fear_greed_index"] = (
        df["fear_greed_index"].rolling(window=historical_period, min_periods=historical_period).min()
    )
    return (
        int(df.fear_greed_index.values[-1]),
        int(df.previous_max_fear_greed_index.values[-1]),
        int(df.previous_min_fear_greed_index.values[-1]),
    )


current_fear_greed_index, previous_max_fear_greed_index, previous_min_fear_greed_index = get_fear_greed_index_data()

print(f"Current fear greed index: {current_fear_greed_index}")
print(f"Previous max fear greed index: {previous_max_fear_greed_index}")
print(f"Previous min fear greed index: {previous_min_fear_greed_index}")
print()

good_call_buy = current_fear_greed_index >= previous_max_fear_greed_index - 2
good_put_buy = current_fear_greed_index <= previous_min_fear_greed_index + 2

print(f"Buy call: {good_call_buy}")
print(f"Buy put: {good_put_buy}")
# Out:
# Current fear greed index: 47
# Previous max fear greed index: 47
# Previous min fear greed index: 33
#
# Buy call: True
# Buy put: False

# %%
min_dte = 14
min_volume = 100
max_strike_distance_pct = 0.1
max_buy_price = 100

df_options_to_buy = df_options_chains.loc[
    (df_options_chains.DTE > min_dte)
    & (df_options_chains.STRIKE_DISTANCE_PCT < max_strike_distance_pct)
    & (
        (good_call_buy & (df_options_chains.C_VOLUME > min_volume) & (df_options_chains.C_ASK * 100 < max_buy_price))
        | (good_put_buy & (df_options_chains.P_VOLUME > min_volume) & (df_options_chains.P_ASK * 100 < max_buy_price))
    )
].sort_values(by="STRIKE_DISTANCE_PCT")
df_options_to_buy
# Out:
#               OPTION_ID  UNDERLYING_LAST EXPIRE_DATE  DTE  STRIKE  \
# 1503     QQQ20240531460           442.06  2024-05-31   20  460.00
# 1504     QQQ20240531465           442.06  2024-05-31   20  465.00
# 1613     QQQ20240607465           442.06  2024-06-07   27  465.00
# 1614     QQQ20240607470           442.06  2024-06-07   27  470.00
# 1907     QQQ20240621473           442.06  2024-06-21   41  473.00
# 1725     QQQ20240614475           442.06  2024-06-14   34  475.00
# 1910     QQQ20240621475           442.06  2024-06-21   41  475.00
# 1913     QQQ20240621478           442.06  2024-06-21   41  478.00
# 1915  QQQ20240621479.78           442.06  2024-06-21   41  479.78
# 1616     QQQ20240607480           442.06  2024-06-07   27  480.00
# 1916     QQQ20240621480           442.06  2024-06-21   41  480.00
# 1918     QQQ20240621482           442.06  2024-06-21   41  482.00
#
#       STRIKE_DISTANCE  STRIKE_DISTANCE_PCT                   C_ID  C_BID  \
# 1503            17.94             0.040583  QQQ   240531C00460000   0.90
# 1504            22.94             0.051893  QQQ   240531C00465000   0.40
# 1613            22.94             0.051893  QQQ   240607C00465000   0.87
# 1614            27.94             0.063204  QQQ   240607C00470000   0.44
# 1907            30.94             0.069990  QQQ   240621C00473000   0.90
# 1725            32.94             0.074515  QQQ   240614C00475000   0.48
# 1910            32.94             0.074515  QQQ   240621C00475000   0.73
# 1913            35.94             0.081301  QQQ   240621C00478000   0.53
# 1915            37.72             0.085328  QQQ   240621C00479780   0.43
# 1616            37.94             0.085825  QQQ   240607C00480000   0.11
# 1916            37.94             0.085825  QQQ   240621C00480000   0.42
# 1918            39.94             0.090350  QQQ   240621C00482000   0.34
#
#       C_ASK  C_VOLUME                   P_ID  P_BID  P_ASK  P_VOLUME
# 1503   0.91       304  QQQ   240531P00460000  18.02  18.45         8
# 1504   0.42       235  QQQ   240531P00465000  22.88  23.30         1
# 1613   0.89       129  QQQ   240607P00465000  22.96  23.27         2
# 1614   0.46       253  QQQ   240607P00470000  27.91  28.23         4
# 1907   0.92       403  QQQ   240621P00473000  30.93  31.21         0
# 1725   0.51       131  QQQ   240614P00475000  32.93  33.21         0
# 1910   0.74       479  QQQ   240621P00475000  32.93  33.21         0
# 1913   0.54       105  QQQ   240621P00478000  35.92  36.21         0
# 1915   0.45       110  QQQ   240621P00479780  37.70  37.99         0
# 1616   0.13       161  QQQ   240607P00480000  37.91  38.23         0
# 1916   0.44       432  QQQ   240621P00480000  37.92  38.21         5
# 1918   0.35       101  QQQ   240621P00482000  39.92  40.21         0

# %%
positions = task.schwab_api.get_balance_positions()
owned_option_positions = [
    x for x in positions["positionDetails"]["positions"] if x["securityType"] == "Option" and x["shares"] > 0
]
owned_call_options = [x for x in owned_option_positions if x["symbolDescription"].startswith("CALL")]
owned_put_options = [x for x in owned_option_positions if x["symbolDescription"].startswith("PUT")]
print(owned_call_options)
print(owned_put_options)
positions
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 3
#       1 positions = task.schwab_api.get_balance_positions()
#       2 owned_option_positions = [
# ----> 3     x for x in positions["positionDetails"]["positions"] if x["securityType"] == "Option" and x["shares"] > 0
#       4 ]
#       5 owned_call_options = [x for x in owned_option_positions if x["symbolDescription"].startswith("CALL")]
#       6 owned_put_options = [x for x in owned_option_positions if x["symbolDescription"].startswith("PUT")]
#
# KeyError: 'positions'

# %%
df_owned_options_chains = df_options_chains.loc[
    (df_options_chains.C_ID.isin(owned_call_options)) | (df_options_chains.P_ID.isin(owned_put_options))
]
df_owned_options_chains

# %%
task.schwab_api.get_balance_positions()
# task.schwab_api.trade(
#     ticker=df_owned_options_chains.C_ID.values[0], asset_class="Option", side="Sell", qty=1, dry_run=False
# )

# %%
task.schwab_api.get_transaction_history()
